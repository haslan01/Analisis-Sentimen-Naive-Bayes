# %%
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: pandas==1.3.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.16.0)

# %%
# !pip install swifter
# !pip install Sastrawi
# Out:
# Requirement already satisfied: swifter in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.3.4)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (8.0.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (2.1.0)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (2022.8.1)
# Requirement already satisfied: parso>0.4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (0.8.3)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (4.64.0)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (5.9.1)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (5.0.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (1.3.2)
# Requirement already satisfied: webencodings in c:\users\asus\.conda\envs\aslan\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: partd>=0.3.10 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.7.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus\appdata\roaming\python\python39\site-packages (from dask[dataframe]>=2.10.0->swifter) (5.4.1)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.23.2)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (4.0.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (3.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.15.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (8.4.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas>=1.0.0->swifter) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: colorama in c:\users\asus\.conda\envs\aslan\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.5)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.6.3)
# Requirement already satisfied: pyzmq>=17 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.3.4)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.13.0)
# Requirement already satisfied: decorator in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (63.4.1)
# Requirement already satisfied: pickleshare in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (3.0.30)
# Requirement already satisfied: stack-data in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.4.0)
# Requirement already satisfied: backcall in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Requirement already satisfied: locket in c:\users\asus\.conda\envs\aslan\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: entrypoints in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\asus\.conda\envs\aslan\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: asttokens in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.0.8)
# Requirement already satisfied: pure-eval in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: executing in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.10.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\asus\appdata\roaming\python\python39\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (227)
# Requirement already satisfied: Sastrawi in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.0.1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df = pd.read_csv(r'pelabelan-gabung.csv')
df.head()
# Out:
#    Unnamed: 0                                           Komentar    Label
# 0           1  Lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1           2  Jangan mendekati zina. Itu adalah aturan yang ...  negatif
# 2           3  The law is an art. Semakin rinci semakin mudah...   netral
# 3           4  TETAPKAN DULU APA YANG DIMAKSUD DENGAN KEKERAS...   netral
# 4           5        Lbih cock diterapkan dikemendikbud Dan DPR.   netral

# %%
del df['Unnamed: 0']
df.head()
# Out:
#                                             Komentar    Label
# 0  Lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  Jangan mendekati zina. Itu adalah aturan yang ...  negatif
# 2  The law is an art. Semakin rinci semakin mudah...   netral
# 3  TETAPKAN DULU APA YANG DIMAKSUD DENGAN KEKERAS...   netral
# 4        Lbih cock diterapkan dikemendikbud Dan DPR.   netral

# %%
#cleaning Text
def remove_punct(text):
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    text = re.sub(r'\b\w(1,2)\b', '', text)
    text = re.sub(r'\s\s+', ' ', text)
    text = re.sub(r"\d+", "", text)
    return text
df['Komentar'] = df['Komentar'].apply(remove_punct)

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
df['Komentar'] = df['Komentar'].str.lower()
df.head()
# Out:
#                                             Komentar    Label
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral

# %%
def replace_repeat_character(text):
    # Pattern to look for three or more repetitions of any character, including newlines (contoh goool -> gol).
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", text)

df['Komentar'] = df['Komentar'].apply(replace_repeat_character) 
df.head()
# Out:
#                                             Komentar    Label
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral

# %%
from nltk.tokenize import word_tokenize

def tokenize(text):
    return nltk.word_tokenize(text)
    
df['TOKENIZATION'] = df['Komentar'].apply(tokenize)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral
# 5  sekalian aja pakaian anak sekolah dan mahasisw...  negatif
# 6  inilah makanya para korban ragu utk melapor us...   netral
# 7  presenter suka motong percakapan narasumber jd...   netral
# 8  kami sebagai ormas islam mendukung permedikbud...  positif
# 9  negara kacau pejabatnya nyeleneh coba urus yg ...  negatif
#
#                                         TOKENIZATION
# 0  [lha, kekerasan, seksual, itu, kan, mmg, defin...
# 1  [jangan, mendekati, zina, itu, adalah, aturan,...
# 2  [the, law, is, an, art, semakin, rinci, semaki...
# 3  [tetapkan, dulu, apa, yang, dimaksud, dengan, ...
# 4  [lbih, cock, diterapkan, dikemendikbud, dan, dpr]
# 5  [sekalian, aja, pakaian, anak, sekolah, dan, m...
# 6  [inilah, makanya, para, korban, ragu, utk, mel...
# 7  [presenter, suka, motong, percakapan, narasumb...
# 8  [kami, sebagai, ormas, islam, mendukung, perme...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...

# %%
katabaku = csv.reader(
	open(r"kata_baku.csv"), delimiter=";") # ambil file csv kata baku menjadi array

kamus_katabaku = {} # empty dictionary untuk kamus kata baku
try:
    for row in katabaku : # membuat kamus kata baku dengan input kata tidak baku dan output kata bakunya
        kamus_katabaku[row[0]] = row[1]
except:
    pass

# %%
print(kamus_katabaku)
# Out:
# {'abjad': 'abjat', 'akta': 'akte', 'aktif': 'aktiv', 'aktivitas': 'aktifitas', 'amendemen': 'amandemen', 'andal': 'handal', 'analisis': 'analisa', 'antre': 'antri', 'asas': 'azas', 'apak': 'apek', 'apotek': 'apotik', 'aritmetika': 'aritmatika', 'atlet': 'atlit', 'atmosfer': 'atmosfir', 'cabai': 'cabay', 'camilan': 'cemilan', 'cendekia': 'cendikia', 'cenderamata': 'cinderamata', 'detail': 'detil', 'definisi': 'difinisi', 'diagnosis': 'diagnosa', 'embus': 'hembus', 'ekstra': 'extra', 'ekstrem': 'ekstrim', 'esai': 'esei', 'februari': 'febuari', 'fondasi': 'pondasi', 'formal': 'formil', 'frasa': 'frase', 'frekuensi': 'frekwensi', 'gizi': 'gisi', 'hafal': 'hapal', 'hakikat': 'hakekat', 'hipotesis': 'hipotesa', 'hierarki': 'hirarkhi', 'ijazah': 'ijasah', 'izin': 'ijin', 'imbau': 'himbau', 'isap': 'hisap', 'istri': 'isteri', 'jadwal': 'jadual', 'jenazah': 'jenasah', 'jenderal': 'jendral', 'justru': 'justeru', 'kafetaria': 'kafeteria', 'kalender': 'kalendar', 'karier': 'karir', 'katapel': 'ketapel', 'kategori': 'katagori', 'kedaluwarsa': 'kadaluwarsa', 'kendaraan': 'kenderaan', 'komplet': 'komplit', 'konferensi': 'konperensi', 'kongres': 'konggres', 'konkret': 'kongkret', 'kreativitas': 'kreatifitas', 'kualifikasi': 'kwalifikasi', 'kualitatif': 'kwalitatif', 'kuantitatif': 'kwantitatif', 'kualitas': 'kwalitet', 'kuitansi': 'kwitansi', 'lubang': 'lobang', 'makhluk': 'mahkluk', 'manajemen': 'managemen', 'masjid': 'mesjid', 'merek': 'merk', 'meterai': 'meterei', 'metode': 'metoda', 'miliar': 'milyar', 'misi': 'missi', 'modern': 'moderen', 'mubazir': 'mubadir', 'mulia': 'mulya', 'mungkir': 'pungkir', 'napas': 'nafas', 'narasumber': 'nara', 'nasihat': 'nasehat', 'objek': 'obyek', 'objektif': 'obyektif', 'paham': 'faham', 'parlemen': 'parlamen', 'paspor': 'pasport', 'peduli': 'perduli', 'pikir': 'fikir', 'praktik': 'praktek', 'provinsi': 'propinsi', 'rabu': 'rebo', 'risiko': 'resiko', 'sah': 'syah', 'sanggama': 'senggama', 'sekadar': 'sekedar', 'sekuler': 'sekular', 'seluler': 'selular', 'semadi': 'semedi', 'sentral': 'central', 'seprai': 'seprei', 'silakan': 'silahkan', 'sirkuler': 'sirkular', 'sistem': 'sistim', 'saksama': 'seksama', 'subjek': 'subyek', 'subjektif': 'subyektif', 'surga': 'syurga', 'survei': 'survey', 'tampak': 'nampak', 'teladan': 'tauladan', 'teknik': 'tekhnik', 'teknologi': 'tekhnologi', 'telanjur': 'terlanjur', 'telantar': 'terlantar', 'terampil': 'trampil', 'vila': 'villa', 'wakaf': 'waqaf', 'wujud': 'ujud', 'yudikatif': 'yudikatip', 'ubah': 'rubah', 'zaman': 'jaman', 'alpa': 'alfa', 'baik': 'bae', 'balas': 'bales', 'belum': 'blm', 'capai': 'capek', 'dalam': 'dalem', 'dapat': 'dpt', 'disahkan': 'disyahkan', 'hilang': 'ilang', 'ikhlas': 'ihlas', 'ingat': 'inget', 'itikad': 'itikat', 'jumat': "jum'at", 'karena': 'krn', 'kasier': 'kasir', 'karisma': 'kharisma', 'kepada': 'ke pada', 'kerap': 'kerab', 'kaidah': 'kaedah', 'khatulistiwa': 'katulistiwa', 'khawatir': 'kuatir', 'kuadrat': 'kwadrat', 'kuantum': 'kwantum', 'kuis': 'kuiz', 'lazim': 'lajim', 'losin': 'lusin', 'maaf': 'apologize', 'macam': 'macem', 'malas': 'males', 'manfaat': 'manpaat', 'nomor': 'nmr', 'materai': 'matere', 'mengesampingkan': 'mengenyampingkan', 'mengubah': 'merubah', 'padat': 'padet', 'pelanggan': 'langganan', 'pensil': 'pinsil', 'pertanggung jawaban': 'pertanggungjawab', 'pihak': 'fihak', 'populer': 'popular', 'rapat': 'rapet', 'sampai': 'sampek', 'selesai': 'selese', 'seperti': 'kayak', 'aksi': 'action', 'anarki': 'anarkhi', 'anggota': 'anggauta', 'biosfer': 'biosfir', 'cepat': 'cpt', 'debit': 'debet', 'devaluasi': 'defaluasi', 'doa': "do'a", 'diam': 'diem', 'daftar': 'daptar', 'dipersilakan': 'dipersilahkan', 'ekuivalen': 'ekwivalen', 'elite': 'elit', 'familier': 'familiar', 'glucose': 'glukosa', 'grup': 'group', 'genting': 'genteng', 'gubuk': 'gubug', 'hectare': 'hektar', 'heterogen': 'hetrogen', 'hipotek': 'hipotik', 'hanya': 'cuma', 'habis': 'abis', 'ideologi': 'idiologi', 'interogasi': 'interograsi', 'introspeksi': 'interospeksi', 'interupsi ...

# %%
def normalized_term(text):
    return [kamus_katabaku[term] if term in kamus_katabaku else term for term in text]
df['TOKENIZATION'] = df['TOKENIZATION'].apply(normalized_term) 
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral
# 5  sekalian aja pakaian anak sekolah dan mahasisw...  negatif
# 6  inilah makanya para korban ragu utk melapor us...   netral
# 7  presenter suka motong percakapan narasumber jd...   netral
# 8  kami sebagai ormas islam mendukung permedikbud...  positif
# 9  negara kacau pejabatnya nyeleneh coba urus yg ...  negatif
#
#                                         TOKENIZATION
# 0  [lha, kekerasan, seksual, itu, kan, mmg, defin...
# 1  [jngan, mendekati, zinah, itu, adalah, aturan,...
# 2  [the, law, is, an, art, semakin, rinci, semaki...
# 3  [tetapkan, dulu, aoa, yg, dimaksud, dgn, keker...
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [sekalian, aja, pakaian, anak, sekolah, dn, ma...
# 6  [inilah, makanya, para, korban, ragu, utk, mel...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [kami, sebagai, ormas, islam, mendukung, perme...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...

# %%
stopword =nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                 'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                 'krn', 'nya', 'nih', 'sih', 
                 'si', 'tau', 'tuh', 'utk', 'ya','sdh',
                 'aja', 'n', 't', 'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                 '&amp', 'yah', 'njir', 'wkwk', 'haha', 'hehe', 'rs', 'yaa',
                 'nii', 'bin', 'lahh', 'hmm', 'lieur', 'njarem', 'kale',
                 'hd', 'an', 'ob', 'bro', 'ud', 'iyaa', 'guys', 'doang',
                 'doank', 'eh', 'kek', 'or', 'kah', 'eso', 'tuh', 'dh', 'dnk',
                 'mh', 'ja', 'tu', 'anu', 'ni', 'ku', 'blz', 'gy', 'skg', 'eeh',
                 'pas','tar','bc','x','dong','d'])

# %%
word_list=['enggak','tidak','jangan','belum']
stopword = [word for word in stopword if word not in word_list] #make a copy of the word_list

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stopword]
    
df['STOP_REMOVAL'] = df['TOKENIZATION'].apply(remove_stopwords)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral
# 5  sekalian aja pakaian anak sekolah dan mahasisw...  negatif
# 6  inilah makanya para korban ragu utk melapor us...   netral
# 7  presenter suka motong percakapan narasumber jd...   netral
# 8  kami sebagai ormas islam mendukung permedikbud...  positif
# 9  negara kacau pejabatnya nyeleneh coba urus yg ...  negatif
#
#                                         TOKENIZATION  \
# 0  [lha, kekerasan, seksual, itu, kan, mmg, defin...
# 1  [jngan, mendekati, zinah, itu, adalah, aturan,...
# 2  [the, law, is, an, art, semakin, rinci, semaki...
# 3  [tetapkan, dulu, aoa, yg, dimaksud, dgn, keker...
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [sekalian, aja, pakaian, anak, sekolah, dn, ma...
# 6  [inilah, makanya, para, korban, ragu, utk, mel...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [kami, sebagai, ormas, islam, mendukung, perme...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...
#
#                                         STOP_REMOVAL
# 0  [lha, kekerasan, seksual, mmg, definisinya, hr...
# 1  [jngan, mendekati, zinah, aturan, dn, ndak, pa...
# 2    [the, law, is, art, rinci, gampang, dibelokkan]
# 3            [tetapkan, aoa, kekerasan, seksualitas]
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [pakaian, anak, sekolah, dn, mahasiswa, rok, h...
# 6  [korban, ragu, melapor, usulan, uu, perlindung...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [ormas, islam, mendukung, permedikbudristek, n...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import swifter

# implementasi pada data kita

# stemmed
def stemmed_wrapper(text):
    return stemmer.stem(text)

text_dict = {}

for document in df['STOP_REMOVAL']:
    for text in document:
        if text not in text_dict:
            text_dict[text] = ' '
            
print(len(text_dict))
print("------------------------")

for text in text_dict:
    text_dict[text] = stemmed_wrapper(text)
    print(text,":" ,text_dict[text])
    
print(text_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [text_dict[text] for text in document]
# Out:
# 1952
# ------------------------
# lha : lha
# kekerasan : keras
# seksual : seksual
# mmg : mmg
# definisinya : definisi
# hrs : hrs
# persetujuan : tuju
# korban : korban
# kemana : mana
# logika : logika
# nolak : nolak
# gimana : gimana
# melawan : lawan
# klw : klw
# ndak : ndak
# didefinisikan : definisi
# aoa : aoa
# jngan : jngan
# mendekati : dekat
# zinah : zinah
# aturan : atur
# dn : dn
# pasal : pasal
# uu : uu
# dll : dll
# demokrasi : demokrasi
# tdak : tdak
# layak : layak
# untk : untk
# isi : isi
# kepentingan : penting
# petinggi : petinggi
# kemaslahatan : maslahat
# masyarakatnya : masyarakat
# aq : aq
# bsa : bsa
# jadikan : jadi
# tameng : tameng
# oknum : oknum
# media : media
# skrang : skrang
# byk : byk
# ngomong : ngomong
# ngawur : ngawur
# the : the
# law : law
# is : is
# art : art
# rinci : rinci
# gampang : gampang
# dibelokkan : belok
# tetapkan : tetap
# seksualitas : seksualitas
# lbih : lbih
# cock : cock
# diterapkan : terap
# dikemendikbud : dikemendikbud
# dpr : dpr
# pakaian : pakai
# anak : anak
# sekolah : sekolah
# mahasiswa : mahasiswa
# rok : rok
# lutut : lutut
# ganti : ganti
# mentri : tri
# membubarkan : bubar
# jga : jga
# ragu : ragu
# melapor : lapor
# usulan : usul
# perlindungan : lindung
# hukum : hukum
# jd : jd
# polemik : polemik
# pdhal : pdhal
# tinggal : tinggal
# direvisi : revisi
# apologize : apologize
# diusulkn : diusulkn
# partai : partai
# gmn : gmn
# kbrnya : kbrnya
# presenter : presenter
# suka : suka
# motong : motong
# percakapan : cakap
# nara : nara
# ngeh : ngeh
# gitu : gitu
# ormas : ormas
# islam : islam
# mendukung : dukung
# permedikbudristek : permedikbudristek
# no : no
# menolak : tolak
# ayat : ayat
# permendikbud : permendikbud
# nadiem : nadiem
# menghilangkan : hilang
# negara : negara
# kacau : kacau
# pejabatnya : jabat
# nyeleneh : nyeleneh
# coba : coba
# urus : urus
# subtantif : subtantif
# dipecat : pecat
# ranah : ranah
# mendikbud : mendikbud
# kementerian : menteri
# perempuan : perempuan
# bnr : bnr
# revisi : revisi
# laksanakan : laksana
# berbicara : bicara
# idiologi : idiologi
# sbg : sbg
# muslim : muslim
# tp : tp
# fakta : fakta
# ttp : ttp
# hrus : hrus
# diterima : terima
# bicara : bicara
# memojokkan : pojok
# kotak : kotak
# amal : amal
# menganjurkan : anjur
# bersedekah : sedekah
# kbetulan : kbetulan
# mreka : mreka
# sesat : sesat
# adl : adl
# saudara : saudara
# qt : qt
# mjd : mjd
# isue : isue
# ksalahan : ksalahan
# bkn : bkn
# pnegak : pnegak
# masalh : masalh
# brsama : brsama
# dhadapi : dhadapi
# bgmn : bgmn
# mnertibkan : mnertibkan
# pemahamanya : pemahamanya
# tdk : tdk
# dr : dr
# menyedikitkan : sedikit
# mmbahas : mmbahas
# syurga : syurga
# imbalan : imbal
# neraka : neraka
# hukuman : hukum
# lbh : lbh
# dibahas : bahas
# mngenali : mngenali
# tuhan : tuhan
# konsekuensinya : konsekuensi
# mnganut : mnganut
# agama : agama
# brarti : brarti
# mngabdi : mngabdi
# pd : pd
# mmpertahankan : mmpertahankan
# imej : imej
# mngejar : mngejar
# duh : duh
# peraturan : atur
# sexual : sexual
# penzinahan : penzinahan
# inikan : ini
# berbeda : beda
# kl : kl
# kalimatx : kalimatx
# difahami : difahami
# undang : undang
# blm : blm
# bahasa : bahasa
# indonesia : indonesia
# bae : bae
# kayakx : kayakx
# namax : namax
# jls : jls
# setuju : tuju
# unsur : unsur
# jdi : jdi
# kalimat : kalimat
# seharusx : seharusx
# dihilangkan : hilang
# perdebatan : debat
# dpt : dpt
# atau pun : atau pun
# haram : haram
# kcuali : kcuali
# lawan : lawan
# anehny : anehny
# negeriku : negeri
# deh : deh
# permen : permen
# ancam : ancam
# tindakan : tindak
# tsbt : tsbt
# dasar : dasar
# trus : trus
# pelaku : laku
# nggak : nggak
# kenai : kena
# kampus : kampus
# kenanya : kena
# tindak : tindak
# a susila : a susila
# kena : kena
# sypa : sypa
# perbuatan : buat
# dlm : dlm
# wajar : wajar
# dicantumkan : cantum
# dmitrii : dmitrii
# senang : senang
# mesum : mesum
# marah : marah
# mencolek : colek
# meraba : raba
# raba : raba
# sangsinya : sangsi
# buka : buka
# baju : baju
# melanggar : langgar
# moril : moril
# kuhp : kuhp
# muhammad : muhammad
# thohir : thohir
# oke : oke
# sampek : sampek
# tsb : tsb
# bentrok : bentrok
# pornografi : pornografi
# berseks : seks
# bebas : bebas
# mematuhi : patuh
# membolehkannya : boleh
# sebutkan : sebut
# memeng : memeng
# ngerti : ngerti
# mengikuti : ikut
# ulama : ulama
# kadron : kadron
# otak : otak
# mesumnya : mesum
# dalem : dalem
# contoh : contoh
# kuhpnya : kuhpnya
# org : org
# persetubuhan : tubuh
# suami : suami
# istrinya : istri
# dipidana : pidana
# perzinaan : zina
# pidana : pidana
# penjara : penjara
# denda : denda
# katagori : katagori
# ii : ii
# menyentuh : sentuh
# mengusap : usap
# memegang : pegang
# memeluk : peluk
# mencium : cium
# menggosokkan : gosok
# tubuhnya : tubuh
# tubuh : tubuh
# membuka : buka
# dinyatakan : nyata
# gamblang : gamblang
# keambiguan : ambigu
# multitafsir : multitafsir
# sex : sex
# dilarang : larang
# didapati : dapat
# kegiatan : giat
# kayak : kayak
# menggesekkan : gesek
# kemaluan : malu
# syah : syah
# mengimplementasikan : implementasi
# walau pun : walau pun
# disalahkan : salah
# permendikbudnya : permendikbudnya
# ambigu : ambigu
# tertawa : tertawa
# argumenmu : argumen
# kutip : kutip
# salahsatu : salahsatu
# kontroversial : kontroversial
# sebagai mana : bagai mana
# meliputi : liput
# kesimpulan : simpul
# mengelompokan : kelompok
# mnjdi : mnjdi
# jenis : jenis
# apa bila : apa bila
# adakah : ada
# samasekali : samasekali
# mengatur : atur
# melegalkan : legal
# meng : meng
# ilegalkan : ilegal
# alias : alias
# diatur : atur
# konsekwensi : konsekwensi
# mengilegalkan : ilegal
# argumentum : argumentum
# contrario : contrario
# lu : lu
# berpikir : pikir
# diperbolehkan : boleh
# peemendikbud : peemendikbud
# elu : elu
# ga : ga
# dewangga : dewangga
# putera : putera
# frase : frase
# faham : faham
# peraturannya : atur
# menimbulkan : timbul
# kontradiksi : kontradiksi
# namanya : nama
# dilecehkan : leceh
# literatur : literatur
# dampaknya : dampak
# memanfaatkan : manfaat
# alesanya : alesanya
# kbbi : kbbi
# binatang : binatang
# menderita : derita
# mati : mati
# akibat : akibat
# kejadian : jadi
# jahat : jahat
# dah : dah
# mestinya : mesti
# menrisex : menrisex
# kegaduhan : gaduh
# mknya : mknya
# makul : makul
# dikasih : kasih
# kerohanian : rohani
# mlh : mlh
# dihapuus : dihapuus
# kuad : kuad
# iin : iin
# plis : plis
# pelecehan : leceh
# gabriella : gabriella
# indah : indah
# charista : charista
# yeess : yeess
# very : very
# true : true
# bang : bang
# baca : baca
# tpi : tpi
# langsung : langsung
# bacod : bacod
# pada hal : pada hal
# udah : udah
# dijelasin : dijelasin
# huruf : huruf
# dianggap : anggap
# mengalami : alami
# situasi : situasi
# dimana : mana
# mengancam : ancam
# memaksa : paksa
# menyalahgunakan : menyalahgunakan
# kedudukannya : duduk
# berlaku : laku
# pahami : paham
# konsep : konsep
# consent : consent
# sekedar : dar
# mulut : mulut
# bacot : bacot
# dewan : dewan
# permenpun : permen
# jk : jk
# moralnya : moral
# bejad : bejad
# buuk : buuk
# keluarga : keluarga
# menanamkan : tanam
# kurasa : rasa
# pengendali : kendali
# apapun : apa
# melarang : larang
# perkosaan : perkosa
# mk : mk
# pelakunya : laku
# lapor : lapor
# polisi : polisi
# ibuk : ibuk
# vissi : vissi
# missi : miss
# presiden : presiden
# menjabarkan : jabar
# kebijakkan : bijak
# shg : shg
# revolusi : revolusi
# mentalnya : mental
# jokowi : jokowi
# diganti : ganti
# dihapus : hapus
# kesempatan : sempat
# goreng : goreng
# gosong : gosong
# jatuh : jatuh
# segalasesuatu : segalasesuatu
# diserah : serah
# ke pada : ke pada
# ahlinya : ahli
# tunggulah : tunggu
# kehancuranya : kehancuranya
# host : host
# berpekulasi : las
# pergantian : ganti
# pembicara : bicara
# ikutlah : ikut
# allah : allah
# swt : swt
# atur : atur
# hdp : hdp
# rakyat : rakyat
# bawa : bawa
# senjata : senjata
# tajam : tajam
# api : api
# enak : enak
# bgt : bgt
# maen : maen
# pks : pks
# engkau : engkau
# harapan : harap
# wilayah : wilayah
# private : private
# perkara : perkara
# individu : individu
# pendidikan : didik
# mora : mora
# knp : knp
# menerapkan : terap
# entar : entar
# terapkan : terap
# olah : olah
# seizin : izin
# perempuannya : perempuan
# inget : inget
# panca sila : panca sila
# sila : sila
# ketuhanan : tuhan
# maha : maha
# esa : esa
# lo : lo
# pasangan : pasang
# agamanya : agama
# ngedukung : ngedukung
# mna : mna
# pelaksana : laksana
# ta'at : ta at
# syariat : syariat
# haruskah : harus
# tunggu : tunggu
# simak : simak
# penyelesaiannya : selesai
# pengadilan : adil
# macem : macem
# keonaran : onar
# cman : cman
# gaduh : gaduh
# mengalihkan : alih
# isu : isu
# goodbener : goodbener
# jekartah : jekartah
# anggauta : anggauta
# par : par
# tainya : tainya
# bermasalah : masalah
# formula : formula
# lg : lg
# diusut : usut
# kpk : kpk
# bagai mana : bagai mana
# sanak : sanak
# menuntut : tuntut
# hahaha : hahaha
# waswas : waswas
# anggotanya : anggota
# digaruk : garuk
# dalih : dalih
# lanjutkan : lanjut
# permendikbudristek : permendikbudristek
# robah : robah
# trgantung : trgantung
# anaknya : anak
# ortunya : ortunya
# penring : penring
# ortu : ortu
# mndidik : mndidik
# ahklak : ahklak
# utama : utama
# tr : tr
# bukti : bukti
# kjadian : kjadian
# ketat : ketat
# trjerumus : trjerumus
# orrunya : orrunya
# selamat : selamat
# hindar : hindar
# pr : pr
# gaulan : gaul
# bbas : bbas
# cewe : cewe
# alhamdulilah : alhamdulilah
# tamat : tamat
# kuliah : kuliah
# bidanan : bidan
# duanya : dua
# trlepas : trlepas
# prgaulan : prgaulan
# intinya : inti
# nasip : nasip
# rizqi : rizqi
# mnyikapi : mnyikapi
# kasih : kasih
# makan : makan
# jlan : jlan
# halal : halal
# koropsi : koropsi
# so : so
# oasti : oasti
# dampak : dampak
# salahkan : salah
# renungi : renung
# cari : cari
# jlanya : jlanya
# bener : bener
# kesimpulannya : simpul
# mengadvokasi : advokasi
# luas : luas
# terkait : kait
# legalitas : legalitas
# perzinahan : perzinahan
# konsensual : konsensual
# terbit : terbit
# dilegalisasi : legalisasi
# illegalisasi : illegalisasi
# hashirama : hashirama
# google : google
# azas : azas
# melarangnya : larang
# legal : legal
# jinah : jah
# perundangan : undang
# aturannya : atur
# klu : klu
# karna : karna
# banyaknya : banyak
# pelaporan : lapor
# darurat : darurat
# bikinlah : bikin
# perendikbud : perendikbud
# badan : badan
# slama : slama
# realita : realita
# justeru : justeru
# slalu : slalu
# rugika : rugika
# istrimu : istri
# anakmu : anak
# sy : sy
# gauli : gaul
# ridwan : ridwan
# basuki : basuki
# didasari : dasar
# terkena : kena
# sanksi : sanksi
# breakpoint : breakpoint
# tv : tv
# butuh : butuh
# narasimu : narasi
# lebar : lebar
# butuhkan : butuh
# hapuskan : hapus
# titik : titik
# ok : ok
# kecuali : kecuali
# susahnya : susah
# menghapus : hapus
# pemerkosaan : perkosa
# perbedaan : beda
# ngapain : ngapain
# anggaran : anggar
# bs : bs
# dikeluarkan : keluar
# hasil : hasil
# penelitian : teliti
# m : m
# indra : indra
# payung : payung
# gak : gak
# percaya : percaya
# pemerkosa : perkosa
# dikebiri : kebiri
# dikampus : kampus
# tujuan : tuju
# tuk : tuk
# menghindari : hindar
# dri : dri
# pelacur : lacur
# bedakan : beda
# pelacuran : lacur
# paksa : paksa
# salah : salah
# rugikan : rugi
# untungkan : untung
# poligami : poligami
# duluan : duluan
# tujuaannya : tujuaannya
# mencegah : cegah
# digoreng : goreng
# otaknya : otak
# dibersihkan : bersih
# usia : usia
# tumpul : tumpul
# politisi : politis
# dosen : dosen
# penjahat : jahat
# kelamin : kelamin
# dirajam : rajam
# dunia : dunia
# direndahkan : rendah
# suaramu : suara
# rektor : rektor
# berlagak : lagak
# dungu : dungu
# menempel : tempel
# nempelkan : nempelkan
# anumu : anu
# nadim : nadim
# ngurusin : ngurusin
# begituan : begitu
# pikirkan : pikir
# kebijakan : bijak
# meningkatkan : tingkat
# mutu : mutu
# perguruan : guru
# urusan : urus
# kasihkan : kasih
# pemegang : pegang
# pintu : pintu
# poin : poin
# kontro : kontro
# versi : versi
# multi : multi
# tapsir : tapsir
# direfisi : direfisi
# merinding : merinding
# dgr : dgr
# sek : sek
# perbolehkan : boleh
# ank : ank
# gadis : gadis
# semoga : moga
# jauhkan : jauh
# gg : gg
# keji : keji
# seboga : boga
# hati : hati
# putih : putih
# perkosa : perkosa
# pacar : pacar
# sampe : sampe
# hamil : hamil
# malu : malu
# bertagung : bertagung
# jawap : jawap
# cicipi : cicip
# eak : eak
# bendigan : bendigan
# putusin : putusin
# msh : msh
# terpaksa : paksa
# sngt : sngt
# dikhawatirkan : khawatir
# maksud : maksud
# rancangan : rancang
# memperkosa : perkosa
# isteri : isteri
# rame : rame
# mui : mui
# hpus : hpus
# do'a : do a
# terlibat : libat
# setan : setan
# selingkuh : selingkuh
# dihamili : hamil
# pemerintah : perintah
# legalkan : legal
# pemerintahan : perintah
# kehinaan : hina
# aamiin : aamiin
# sllu : sllu
# main : main
# tafsir : tafsir
# hancur : hancur
# dilegalkan : legal
# assalamualaikum : assalamualaikum
# ditandatangani : ditandatangani
# mendikbudristek : mendikbudristek
# seandainya : anda
# mahasiswi : mahasiswi
# tertutup : tutup
# ketauan : tau
# pelanggaran : langgar
# ditindak : tindak
# lanjuti : lanjut
# muaantaabb : muaantaabb
# skrng : skrng
# aman : aman
# sis : sis
# lw : lw
# pade : pade
# nga : nga
# ngas : ngas
# gaass : gaass
# bwahahaha : bwahahaha
# mas : mas
# kuatir : kuatir
# bertentangan : tentang
# menuai : tuai
# adzab : adzab
# didunia : dunia
# akhirat : akhirat
# fihak : fihak
# giatan : giat
# esek : esek
# pemaksaan : paksa
# brenti : brenti
# situ : situ
# tolak : tolak
# pzinaan : pzinaan
# dipaksakan : paksa
# disetujui : tuju
# cegah : cegah
# ditentang : tentang
# pencegahan : cegah
# difinisi : fisi
# ttg : ttg
# tempatnya : tempat
# ambiguan : ambigu
# korbannya : korban
# bagusnya : bagus
# perbaiki : baik
# mu : mu
# ummu : ummu
# nayla : nayla
# membolehkan : boleh
# permebdikbud : permebdikbud
# melindungi : lindung
# kejahatan : jahat
# guru : guru
# ustadz : ustadz
# senior : senior
# lingkungan : lingkung
# pake : pake
# kebencian : benci
# membuta : buta
# mata : mata
# umat : umat
# wkwkkw : wkwkkw
# marak : marak
# kepo : kepo
# bngt : bngt
# tangkap : tangkap
# menrisek : menrisek
# nasional : nasional
# maju : maju
# cerdas : cerdas
# merata : rata
# ranahnya : ranah
# menangani : tangan
# belah : belah
# julidz : julidz
# setahu : tahu
# terikat : ikat
# perkawinan : kawin
# single : single
# delik : delik
# aduan : adu
# proses : proses
# pengaduan : adu
# tertera : tera
# perluasan : luas
# bentuk : bentuk
# ruu : ruu
# temen : temen
# sekulib : sekulib
# protes : protes
# cpt : cpt
# sahkan : sahkan
# ribut : ribut
# ama : ama
# kaum : kaum
# kons : kons
# islamis : islamis
# capek : capek
# mulu : mulu
# akhsan : akhsan
# andi : andi
# prostitusi : prostitusi
# berlapis : lap
# korbanya : korbanya
# masi : mas
# dibawah : bawah
# umur : umur
# propinsi : propinsi
# kota : kota
# hukumanya : hukumanya
# gw : gw
# nanangin : nanangin
# nangin : nangin
# paksaan : paksa
# mikir : mikir
# legalin : legalin
# konteksnya : konteks
# beda : beda
# gabisa : gabisa
# larangan : larang
# setau : tau
# ngelarang : ngelarang
# maksudnya : maksud
# ketentuanya : ketentuanya
# gatau : gatau
# konsepnya : konsep
# iya : iya
# ambil : ambil
# ditangsel : tangsel
# juta : juta
# dikamar : kamar
# berulang : ulang
# kali : kali
# surat : surat
# perjanjianya : perjanjianya
# tergantung : gantung
# daerah : daerah
# mayoritas : mayoritas
# ralat : ralat
# benarkan : benar
# celah : celah
# manfaatkan : manfaat
# contohnya : contoh
# ayam : ayam
# standing : standing
# udahlah : udahlah
# debatin : debatin
# ngubah : ngubah
# posisi : posisi
# liat : liat
# twitter : twitter
# pengujian : uji
# materi : materi
# ma : ma
# kedepannya : depan
# pemendikbud : pemendikbud
# susi : sus
# tri : tri
# andarwati : andarwati
# mekanisme : mekanisme
# gk : gk
# menjerat : jerat
# itukan : itu
# bu : bu
# suruh : suruh
# teman : teman
# muncul : muncul
# memunculkan : muncul
# oh : oh
# rkuhp : rkuhp
# jalan : jalan
# tekanan : tekan
# mengajukan : aju
# warga : warga
# negaranya : negara
# berbuat : buat
# pembantu : bantu
# klausal : klausal
# mengikat : ikat
# komentar : komentar
# merubah : rubah
# kenyataan : nyata
# berusaha : usaha
# selesainya : selesai
# melundungi : melundungi
# hubungannya : hubung
# dilegalkannya : legal
# emang : emang
# disyahkan : syah
# ngadu : ngadu
# mangkrak : mangkrak
# menindak : tindak
# legowo : legowo
# halah : halah
# solusiable : solusiable
# spk : spk
# agamais : agamais
# diem : diem
# dipesantren : pesantren
# nikahin : nikahin
# maklum : maklum
# pemikiran : pikir
# tertinggal : tinggal
# bobrok : bobrok
# raja : raja
# bla : bla
# mucho : mucho
# texto : texto
# nikmatin : nikmatin
# perseteruan : seteru
# wkwkwkwk : wkwkwkwk
# berlakunya : laku
# ente : ente
# nanya : nanya
# pernyataan : nyata
# aduh : aduh
# males : males
# bahas : bahas
# komen : komen
# bales : bales
# hehehe : hehehe
# terpenting : penting
# mslh : mslh
# prbuatan : prbuatan
# kn : kn
# aturanny : aturanny
# sndri : sndri
# msing : msing
# kyak : kyak
# bocah : bocah
# paud : paud
# gede : gede
# bloon : bloon
# wonggemblung : wonggemblung
# seneng : neng
# yee : yee
# udeh : udeh
# hemat : hemat
# hotel : hotel
# dilindungi : lindung
# bwahahaahah : bwahahaahah
# rush : rush
# day : day
# gni : gni
# toge : toge
# dksih : dksih
# trs : trs
# hp : hp
# goblokny : goblokny
# natural : natural
# julian : juli
# yaelah : yaelah
# cuan : cuan
# tukang : tukang
# eceran : ecer
# kond : kond
# gas : gas
# stock : stock
# banyakin : banyakin
# ahahaaha : ahahaaha
# trnyta : trnyta
# drone : drone
# kelas : kelas
# ngoceh : ngoceh
# kadrun : kadrun
# meggunakan : meggunakan
# akal : akal
# sehat : sehat
# nyuri : nyuri
# berani : berani
# manusia : manusia
# bermoral : moral
# berahlaq : berahlaq
# ayo : ayo
# ikuti : ikut
# perintah : perintah
# tinggalkan : tinggal
# broow : broow
# dilanggar : langgar
# senjatanya : senjata
# memberantasnya : berantas
# nila : nila
# setitik : titik
# rusak : rusak
# susu : susu
# sebelanga : belanga
# liberal : liberal
# menghalalkan : halal
# kurikulum : kurikulum
# pendidikannya : didik
# ditambahi : tambah
# pelajaran : ajar
# merayu : rayu
# hr : hr
# merasukimu : rasuk
# turuut : turuut
# menyimaak : menyimaak
# gus : gus
# dur : dur
# repot : repot
# muhammadiyah : muhammadiyah
# ikadi : ikadi
# prof : prof
# cholis : cholis
# nafis : naf
# cabut : cabut
# th : th
# nu : nu
# suaranya : suara
# diwakili : wakil
# cholil : cholil
# turun : turun
# truskan : truskan
# baguslah : bagus
# dimcok : dimcok
# kalangan : kalang
# berzina : zina
# cecep : cecep
# bicaranya : bicara
# selangkangan : selangkang
# tangap : tangap
# kritik : kritik
# nonton : nonton
# bokep : bokep
# ruang : ruang
# sidang : sidang
# bwahaha : bwahaha
# membela : bela
# perempun : rem
# mprett : mprett
# urusin : urusin
# kadermu : kader
# kampanye : kampanye
# menerima : terima
# diskusikan : diskusi
# sensasi : sensasi
# jalankan : jalan
# uunya : uunya
# tindakannya : tindak
# diamati : amat
# kakehan : kakehan
# jepang : jepang
# spt : spt
# aborsi : aborsi
# efek : efek
# diluar : luar
# nikah : nikah
# dilawan : lawan
# dibrantas : dibrantas
# tanda : tanda
# jaman : jaman
# naudzubillah : naudzubillah
# innalilahi : innalilahi
# wa : wa
# inalilahi : inalilahi
# rooji : rooji
# uun : uun
# moga : moga
# oenggagas : oenggagas
# plaku : plaku
# mah : mah
# ditembak : tembak
# ngomongin : ngomongin
# pakek : pakek
# kode : kode
# etik : etik
# missal : missal
# disesuaikan : sesuai
# patokannya : patok
# nangkepnya : nangkepnya
# perbincangan : bincang
# konteks : konteks
# kurng : kurng
# diusulkan : usul
# kyk : kyk
# nunggu : nunggu
# bertambah : tambah
# selese : selese
# rifki : rifki
# fauzi : fauzi
# giliran : gilir
# ngusulin : ngusulin
# dikritisi : kritisi
# benaar : benaar
# ginian : ginian
# nyampe : nyampe
# nalarnya : nalar
# hahha : hahha
# oposisi : oposisi
# payah : payah
# lemot : lot
# ahirnya : ahirnya
# kaya : kaya
# terusan : terus
# islamabad : islamabad
# terbelakang : belakang
# riza : riza
# kun : kun
# azab : azab
# xmbelgedesh : xmbelgedesh
# mitos : mitos
# digaungkan : gaung
# kelompokmu : kelompok
# pondasi : pondasi
# khayalan : khayal
# teori : teori
# keliatan : liat
# buktinya : bukti
# perbandingan : banding
# jgn : jgn
# blue : blue
# next : next
# silahkan : silah
# pemimpinmu : pimpin
# kawannya : kawan
# mendahulukan : dahulu
# drpd : drpd
# make : make
# argumen : argumen
# praktis : praktis
# arab : arab
# bank : bank
# konvensional : konvensional
# ilegal : ilegal
# qur : qur
# riba : riba
# injil : injil
# ursury : ursury
# tetep : tetep
# dosa : dosa
# ilegalkannya : ilegal
# drun : drun
# menyebabkan : sebab
# penanganan : tangan
# digiring : giring
# pelegalan : legal
# kiamat : kiamat
# nnti : nnti
# hamll : hamll
# dluaar : dluaar
# nikaah : nikaah
# buru : buru
# sirii : siri
# ikutan : ikut
# celeng : celeng
# nyari : nyari
# pembenaran : benar
# pembelaan : bela
# pkoknya : pkoknya
# kitaa : kitaa
# fatwa : fatwa
# lurus : lurus
# wakl : wakl
# ketua : ketua
# llos : llos
# krna : krna
# mrasa : mrasa
# kuat : kuat
# bkuasa : bkuasa
# silaahkan : silaahkan
# apadaya : apadaya
# rakyt : rakyt
# hak : hak
# bdoa : bdoa
# jikaa : jikaa
# bnar : bnar
# ituu : ituu
# smogaa : smogaa
# cucu : cucu
# brulang : brulang
# dluar : dluar
# jlas : jlas
# mnghamili : mnghamili
# mlakukan : mlakukan
# ddpan : ddpan
# skalipun : skalipun
# dewi : dewi
# sriyati : sriyati
# ngedongeng : ngedongeng
# kyknya : kyknya
# taunya : tau
# teriak : teriak
# dukung : dukung
# lgi : lgi
# teriakin : teriakin
# substansi : substansi
# dibicarakan : bicara
# ckckck : ckckck
# kasian : kasi
# kalah : kalah
# debat : debat
# nyerang : nyerang
# personal : personal
# lgsg : lgsg
# kemakan : makan
# berita : berita
# gorengan : goreng
# khusus : khusus
# rekomendasi : rekomendasi
# dokter : dokter
# liar : liar
# nyalahin : nyalahin
# sepenuhnya : sepenuh
# syarat : syarat
# dinamakan : nama
# menyetujui : tuju
# kontra : kontra
# disitulah : situ
# permasalahannya : masalah
# keras : keras
# lembut : lembut
# utamakan : utama
# dian : dian
# chanel : chanel
# wafatnya : wafat
# nabi : nabi
# dikategorikan : kategori
# wafat : wafat
# kedepan : depan
# msk : msk
# lho : lho
# memangnya : memang
# bersalah : salah
# menunjukan : tunjuk
# nyumpahin : nyumpahin
# gini : gin
# ngucap : ngucap
# dzulfiqar : dzulfiqar
# menganggap : anggap
# farhan : farhan
# dihukum : hukum
# diamenyetujui : diamenyetujui
# bibir : bibir
# pacarnya : pacar
# kelaminnya : kelamin
# ditindaklanjuti : ditindaklanjuti
# hubungan : hubung
# nilai : nilai
# norma : norma
# akar : akar
# trmksh : trmksh
# wassalamu : wassalamu
# alaikum : alaikum
# permnedikbudristek : permnedikbudristek
# ulangi : ulang
# berfokus : fokus
# berlatar : latar
# penyelesaian : selesai
# keadilan : adil
# penyelesaina : penyelesaina
# membantu : bantu
# menyelesaikan : selesai
# studi : studi
# membicarakan : bicara
# dirugikan : rugi
# kerugian : rugi
# cerita : cerita
# bertujuan : tuju
# letaknya : letak
# saudaraku : saudara
# pebuatan : buat
# lahir : lahir
# latar : latar
# diatas : atas
# pandangan : pandang
# kodill : kodill
# chanell : chanell
# sebelumya : sebelumya
# bingung : bingung
# risikoberikhtilath : risikoberikhtilath
# minggu : minggu
# gue : gue
# sholat : sholat
# jum'at : jum at
# imam : imam
# khotbahnya : khotbah
# tabayun : tabayun
# klaim : klaim
# hadeh : hadeh
# nyesel : nyesel
# jumatan : jumat
# mengmangtap : mengmangtap
# kentu : kentu
# pola : pola
# sempit : sempit
# budaya : budaya
# open : open
# bo : bo
# ane : ane
# uin : uin
# paginya : pagi
# berkerudung : kerudung
# malamnya : malam
# warung : warung
# konyol : konyol
# tujuannya : tuju
# hoii : hoi
# sanksinya : sanksi
# penolakannya : tolak
# terdengar : dengar
# goblog : goblog
# fix : fix
# orng : orng
# kalau pun : kalau pun
# sesuai : sesuai
# napsu : napsu
# pasang : pasang
# peringatan : ingat
# kencing : kencing
# dianggep : dianggep
# bab : bab
# logikanya : logika
# whyyposisi : whyyposisi
# buset : buset
# suara : suara
# fattah : fattah
# wnf : wnf
# euy : euy
# ngritik : ngritik
# homo : homo
# pencabulan : cabul
# pondok : pondok
# kdrt : kdrt
# ayem : ayem
# nerbitin : nerbitin
# yng : yng
# perduli : duli
# dibantah : ban
# mentah : mentah
# acc : acc
# ustad : ustad
# habib : habib
# ngeres : ngeres
# samping : samping
# pacaran : pacar
# laporkan : lapor
# melakukkan : melakukkan
# kebiasaan : biasa
# nangiss : nangiss
# seringkali : seringkali
# fokus : fokus
# kesalah : salah
# fahaman : fahaman
# intrik : intrik
# politik : politik
# menjatuhkan : jatuh
# kesan : kesan
# burukk : burukk
# tokoh : tokoh
# publik : publik
# obyektif : obyektif
# menilai : nilai
# memahami : paham
# kemajuan : maju
# bangsa : bangsa
# unjuk : unjuk
# identitas : identitas
# didengarkan : dengar
# adana : adana
# garis : garis
# menutup : tutup
# mengarah : arah
# kearah : arah
# menaggulangi : menaggulangi
# pergaulan : gaul
# pemuda : pemuda
# nahh : nahh
# dipikirkan : pikir
# nntinya : nntinya
# berhubungan : hubung
# batasan : batas
# bergaul : gaul
# hidup : hidup
# sebebas : bebas
# bebasnya : bebas
# sungguh : sungguh
# beragama : agama
# sesk : sesk
# dibujuk : bujuk
# diperkosa : perkosa
# orangnya : orang
# culun : culun
# gtu : gtu
# audio : audio
# editingnya : editingnya
# jancukk : jancukk
# masak : masak
# pribadi : pribadi
# ijin : ijin
# solusi : solusi
# memprotes : protes
# membelokkan : belok
# cocok : cocok
# semudah : mudah
# nuntut : nuntut
# cetek : cetek
# digoyang : goyang
# lihat : lihat
# pariwisata : pariwisata
# adem : adem
# wisnutama : wisnutama
# hebat : hebat
# berkutik : kutik
# sekelilingnya : keliling
# tolol : tolol
# permasalahan : masalah
# perselingkuhan : selingkuh
# susah : susah
# memiliki : milik
# konsevatif : konsevatif
# fundamental : fundamental
# wkwkwwkwk : wkwkwwkwk
# opini : opini
# verbal : verbal
# non : non
# panjenengan : panjenengan
# ngasih : ngasih
# mengembangkan : kembang
# fikir : fikir
# dangkal : dangkal
# ppks : ppks
# terbalik : balik
# berargumen : argumen
# pengikut : ikut
# mendi : mendi
# borr : borr
# resiko : resiko
# udh : udh
# serah : serah
# bodoamat : bodoamat
# uninstal : uninstal
# diksi : diksi
# nama : nama
# syaratnya : syarat
# pernikahan : nikah
# menikah : meni
# dijerat : jerat
# dibilang : bilang
# ko : ko
# ditafsirkan : tafsir
# lulus : lulus
# ujian : uji
# matkul : matkul
# ulang : ulang
# temui : temu
# oyo : oyo
# pengalaman : alam
# mantan : mantan
# goa : goa
# ancem : ancem
# niatnya : niat
# jalannya : jalan
# keliru : keliru
# dipidanakan : pidana
# usahakan : usaha
# mendompleng : dompleng
# riil : riil
# urgent : urgent
# ks : ks
# skrg : skrg
# menghambat : hambat
# masyarakat : masyarakat
# dibuatkan : buat
# isinya : isi
# kriteria : kriteria
# dlsb : dlsb
# fokusnya : fokus
# permennya : permen
# korupsi : korupsi
# sapi : sapi
# berkedok : kedok
# holaqoh : holaqoh
# juz : juz
# amma : amma
# belajar : ajar
# om : om
# produk : produk
# novel : novel
# mengambil : ambil
# brng : brng
# pencurian : curi
# woahh : woahh
# parah : parah
# anjir : anjir
# diberitahukan : diberitahukan
# aldo : aldo
# binar : binar
# clear : clear
# dosennya : dosen
# depak : depak
# sm : sm
# kontak : kontak
# pisik : pisik
# menawarkan : tawar
# transaksi : transaksi
# ditawarin : ditawarin
# photo : photo
# telanjang : telanjang
# alat : alat
# kemampuan : mampu
# pemahaman : paham
# alluxes : alluxes
# ohh : ohh
# nawarin : nawarin
# dijadiin : dijadiin
# awi : awi
# asnawi : asnawi
# dlu : dlu
# laporin : laporin
# catt : catt
# calling : calling
# literasi : literasi
# diedukasi : edukasi
# aufa : aufa
# billah : billah
# tipe : tipe
# mikirnya : mikirnya
# memproses : proses
# positiv : positiv
# informasi : informasi
# berkaitan : kait
# dikaitkan : kait
# pro : pro
# dibebankan : beban
# berfikirnya : berfikirnya
# pasalnya : pasal
# sentuhan : sentuh
# ato : ato
# interface : interface
# pendapat : dapat
# sadar : sadar
# perbutan : perbutan
# membutuhkan : butuh
# judulnya : judul
# tlg : tlg
# dibaca : baca
# teliti : teliti
# dibolehkan : boleh
# ngeyel : ngeyel
# munkin : munkin
# makarim : makarim
# sukak : sukak
# wanita : wanita
# terbukti : bukti
# disetubuhin : disetubuhin
# laki : laki
# berat : berat
# ngasi : ngasi
# menjaga : jaga
# jakar : jakar
# pecat : pecat
# seumur : umur
# wanitanya : wanita
# ngenyel : ngenyel
# hadehh : hadehh
# sayangi : sayang
# ribet : ribet
# sono : sono
# usul : usul
# disangkut : sangkut
# pautkan : paut
# lingkup : lingkup
# dipisah : pisah
# gerbong : gerbong
# kereta : kereta
# tunggangi : tunggang
# lgbt : lgbt
# diperintahkan : perintah
# beliau : beliau
# tanggung : tanggung
# pendidiknya : didik
# semangat : semangat
# hargai : harga
# mslhx : mslhx
# adh : adh
# tertulis : tulis
# legalx : legalx
# tubuhmu : tubuh
# bungkus : bungkus
# lollipop : lollipop
# tergiur : giur
# bentuknya : bentuk
# tutup : tutup
# mahaciwi : mahaciwi
# ojk : ojk
# pinjol : pinjol
# pdhl : pdhl
# praktek : praktek
# bunga : bunga
# tinghi : tinghi
# ngga : ngga
# mikirin : mikirin
# lampau : lampau
# guwe : guwe
# pikirin : pikirin
# konotasi : konotasi
# tragis : tragis
# negri : negri
# disamain : disamain
# apps : apps
# install : install
# smartphone : smartphone
# hihihi : hihihi
# terkecuali : kecuali
# kaedah : kaedah
# kesopanan : sopan
# pertontonkan : tonton
# sekelas : kelas
# pesantren : pesantren
# merasakannya : rasa
# belok : belok
# narapidana : narapidana
# seprrti : seprrti
# comot : comot
# pandai : pandai
# musyawarah : musyawarah
# muhamdiah : muhamdiah
# deal : deal
# aj : aj
# ancur : ancur
# iman : iman
# tekan : tekan
# becus : becus
# ngajar : ngajar
# ngedidik : ngedidik
# murid : murid
# disen : sen
# babad : babad
# musnahkan : musnah
# kucing : kucing
# kawin : kawin
# menyerap : serap
# kontroversi : kontroversi
# negativ : negativ
# iyalah : iya
# lari : lari
# wani : wani
# piro : piro
# jg : jg
# doyan : doyan
# cabul : cabul
# terima : terima
# gara : gara
# menyedihkan : sedih
# pendidik : didik
# terdidik : didik
# blh : blh
# siswa : siswa
# smester : smester
# uang : uang
# dmester : dmester
# blhkan : blhkan
# ttap : ttap
# mask : mask
# bayar : bayar
# swasta : swasta
# kopit : kopit
# pemulihan : pulih
# ekonomi : ekonomi
# tua : tua
# mkn : mkn
# cm : cm
# mksh : mksh
# thn : thn
# byr : byr
# stengah : stengah
# seluru : seluru
# pilih : pilih
# blhlkan : blhlkan
# smseter : smseter
# mksih : mksih
# melancarkan : lancar
# bisnis : bisnis
# hormat : hormat
# mundur : mundur
# mhn : mhn
# disimak : simak
# istilah : istilah
# matang : matang
# nakarim : nakarim
# dibikin : bikin
# akalan : akal
# survey : survey
# rugi : rugi
# megang : megang
# tangan : tangan
# pundak : pundak
# mahasiswinya : mahasiswi
# genit : genit
# manggil : manggil
# syg : syg
# love : love
# you : you
# berdalih : dalih
# bergurau : gurau
# memfoto : foto
# gemeteran : gemeteran
# beraksi : aksi
# permendikbudristekdikti : permendikbudristekdikti
# syari : syar
# at : at
# menterinya : menteri
# amburadul : amburadul
# slesai : slesai
# gawat : gawat
# daruat : daruat
# karenahukum : karenahukum
# ingatkan : ingat
# memanusiakan : manusia
# beternak : ternak
# untung : untung
# lobang : lobang
# hidung : hidung
# pantat : pantat
# lumayan : lumayan
# hutang : hutang
# keluarganya : keluarga
# islami : islami
# dicomot : comot
# jaringan : jaring
# kecebong : kecebong
# bahagia : bahagia
# digerebek : gerebek
# ituh : ituh
# koteka : koteka
# myth : myth
# randir : randir
# zinahnya : zinahnya
# cebong : cebong
# ngotot : ngotot
# meledak : ledak
# populasi : populasi
# nie : nie
# dias : dias
# channel : channel
# memakai : pakai
# alihkan : alih
# suupaya : suupaya
# pemahamannya : paham
# muatan : muat
# mengandung : kandung
# beuh : beuh
# purnomo : purnomo
# ntar : ntar
# pembenturan : bentur
# hantar : hantar
# bersembunyi : sembunyi
# bayu : bayu
# hasanudin : hasanudin
# jerat : jerat
# mksd : mksd
# fungsi : fungsi
# fungsinya : fungsi
# benteng : benteng
# in : in
# other : other
# side : side
# scr : scr
# worth : worth
# it : it
# konfirmasi : konfirmasi
# patenkan : paten
# didalamnya : dalam
# penggunaan : guna
# otoritas : otoritas
# vidio : vidio
# memandang : pandang
# bersiul : siul
# bersenggolan : senggol
# menjalankan : jalan
# tugas : tugas
# fotonya : foto
# diambil : ambil
# menentukan : tentu
# merasakan : rasa
# btw : btw
# gaada : gaada
# kucingmasjid : kucingmasjid
# dimanapun : mana
# placur : placur
# berzinah : berzinah
# pembimbing : bimbing
# kebanyakan : banyak
# terusin : terusin
# dosenn : dosenn
# bercocok : cocok
# tanam : tanam
# kake : kake
# sugiono : sugiono
# merajalela : rajalela
# mengecrott : mengecrott
# crott : crott
# idham : idham
# coy : coy
# lihatlah : lihat
# kelakuan : laku
# sok : sok
# ajaran : ajar
# ulamanya : ulama
# jhon : jhon
# ghost : ghost
# ngapah : ngapah
# sosoh : sosoh
# dikit : dikit
# binik : bik
# bnyak : bnyak
# bolih : bolih
# cma : cma
# pembodohan : bodoh
# puih : puih
# bulsit : bulsit
# wiji : wiji
# asih : asih
# iri : iri
# memenuhi : penuh
# widi : widi
# sya : sya
# bani : bani
# hh : hh
# jjik : jjik
# mcm : mcm
# sekangkangan : kangkang
# ijab : ijab
# siri : siri
# sdah : sdah
# kelebihan : lebih
# gajian : gaji
# bintang : bintang
# faktanya : fakta
# nangkep : nangkep
# maknanya : makna
# sampaiin : sampaiin
# beradap : adap
# merevisi : revisi
# beradab : adab
# dicabut : cabut
# hitam : hitam
# abu : abu
# sibuk : sibuk
# bisanya : bisa
# habit : habit
# gagal : gagal
# dirayu : rayu
# mengaku : aku
# dipaksa : paksa
# jaya : jaya
# rahayu : rahayu
# diayomi : ayom
# diayemi : ayem
# pengaruh : pengaruh
# barat : barat
# enggak : enggak
# kesetaraan : tara
# gender : gender
# ramah : ramah
# majulah : maju
# indonesiaku : indonesia
# online : online
# jerit : jerit
# kesakitan : sakit
# merem : merem
# melek : melek
# nyirnyir : nyirnyir
# mrk : mrk
# kerjaannya : kerja
# mutarbalik : mutarbalik
# bodoh : bodoh
# mabok : mabok
# mesyumm : mesyumm
# parte : parte
# konthol : konthol
# pk : pk
# merujuk : rujuk
# etika : etika
# ngurus : ngurus
# mmbuat : mmbuat
# bumbui : bumbu
# sperti : sperti
# pendidikanlah : didik
# grnerasi : grnerasi
# muda : muda
# kemayu : kemayu
# anggap : anggap
# pemuas : muas
# boneka : boneka
# barbie : barbie
# dicolet : colet
# ngojek : ngojek
# acak : acak
# khan : khan
# puas : puas
# jaga : jaga
# bersekolah : sekolah
# jatuhnya : jatuh
# manipulatif : manipulatif
# trauma : trauma
# menghargai : harga
# wibawa : wibawa
# berfikir : berfikir
# ngelakuin : ngelakuin
# jessi : jessi
# complicated : complicated
# putus : putus
# dilandasi : landas
# solusinya : solusi
# dipajang : pajang
# zer : zer
# mosok : mosok
# emak : emak
# berjilbab : jilbab
# omongane : omongane
# rek : rek
# bayangin : bayangin
# nek : nek
# ibumu : ibu
# adikmu : adik
# perempuanmu : perempuan
# jamah : jamah
# wkwkkwkw : wkwkkwkw
# iye : iye
# ngaca : ngaca
# napa : napa
# woi : woi
# kalu : kalu
# ngatur : ngatur
# kekersan : kers
# data : data
# perspektif : perspektif
# nyata : nyata
# kompor : kompor
# judul : judul
# melindung : lindung
# merehabilitas : merehabilitas
# {'lha': 'lha', 'kekerasan': 'keras', 'seksual': 'seksual', 'mmg': 'mmg', 'definisinya': 'definisi', 'hrs': 'hrs', 'persetujuan': 'tuju', 'korban': 'korban', 'kemana': 'mana', 'logika': 'logika', 'nolak': 'nolak', 'gimana': 'gimana', 'melawan': 'lawan', 'klw': 'klw', 'ndak': 'ndak', 'didefinisikan': 'definisi', 'aoa': 'aoa', 'jngan': 'jngan', 'mendekati': 'dekat', 'zinah': 'zinah', 'aturan': 'atur', 'dn': 'dn', 'pasal': 'pasal', 'uu': 'uu', 'dll': 'dll', 'demokrasi': 'demokrasi', 'tdak': 'tdak', 'layak': 'layak', 'untk': 'untk', 'isi': 'isi', 'kepentingan': 'penting', 'petinggi': 'petinggi', 'kemaslahatan': 'maslahat', 'masyarakatnya': 'masyarakat', 'aq': 'aq', 'bsa': 'bsa', 'jadikan': 'jadi', 'tameng': 'tameng', 'oknum': 'oknum', 'media': 'media', 'skrang': 'skrang', 'byk': 'byk', 'ngomong': 'ngomong', 'ngawur': 'ngawur', 'the': 'the', 'law': 'law', 'is': 'is', 'art': 'art', 'rinci': 'rinci', 'gampang': 'gampang', 'dibelokkan': 'belok', 'tetapkan': 'tetap', 'seksualitas': 'seksualitas', 'lbih': 'lbih', 'cock': 'cock', 'diterapkan': 'terap', 'dikemendikbud': 'dikemendikbud', 'dpr': 'dpr', 'pakaian': 'pakai', 'anak': 'anak', 'sekolah': 'sekolah', 'mahasiswa': 'mahasiswa', 'rok': 'rok', 'lutut': 'lutut', 'ganti': 'ganti', 'mentri': 'tri', 'membubarkan': 'bubar', 'jga': 'jga', 'ragu': 'ragu', 'melapor': 'lapor', 'usulan': 'usul', 'perlindungan': 'lindung', 'hukum': 'hukum', 'jd': 'jd', 'polemik': 'polemik', 'pdhal': 'pdhal', 'tinggal': 'tinggal', 'direvisi': 'revisi', 'apologize': 'apologize', 'diusulkn': 'diusulkn', 'partai': 'partai', 'gmn': 'gmn', 'kbrnya': 'kbrnya', 'presenter': 'presenter', 'suka': 'suka', 'motong': 'motong', 'percakapan': 'cakap', 'nara': 'nara', 'ngeh': 'ngeh', 'gitu': 'gitu', 'ormas': 'ormas', 'islam': 'islam', 'mendukung': 'dukung', 'permedikbudristek': 'permedikbudristek', 'no': 'no', 'menolak': 'tolak', 'ayat': 'ayat', 'permendikbud': 'permendikbud', 'nadiem': 'nadiem', 'menghilangkan': 'hilang', 'negara': 'negara', 'kacau': 'kacau', 'pejabatnya': 'jabat', 'nyeleneh': 'nyeleneh', 'coba': 'coba', 'urus': 'urus', 'subtantif': 'subtantif', 'dipecat': 'pecat', 'ranah': 'ranah', 'mendikbud': 'mendikbud', 'kementerian': 'menteri', 'perempuan': 'perempuan', 'bnr': 'bnr', 'revisi': 'revisi', 'laksanakan': 'laksana', 'berbicara': 'bicara', 'idiologi': 'idiologi', 'sbg': 'sbg', 'muslim': 'muslim', 'tp': 'tp', 'fakta': 'fakta', 'ttp': 'ttp', 'hrus': 'hrus', 'diterima': 'terima', 'bicara': 'bicara', 'memojokkan': 'pojok', 'kotak': 'kotak', 'amal': 'amal', 'menganjurkan': 'anjur', 'bersedekah': 'sedekah', 'kbetulan': 'kbetulan', 'mreka': 'mreka', 'sesat': 'sesat', 'adl': 'adl', 'saudara': 'saudara', 'qt': 'qt', 'mjd': 'mjd', 'isue': 'isue', 'ksalahan': 'ksalahan', 'bkn': 'bkn', 'pnegak': 'pnegak', 'masalh': 'masalh', 'brsama': 'brsama', 'dhadapi': 'dhadapi', 'bgmn': 'bgmn', 'mnertibkan': 'mnertibkan', 'pemahamanya': 'pemahamanya', 'tdk': 'tdk', 'dr': 'dr', 'menyedikitkan': 'sedikit', 'mmbahas': 'mmbahas', 'syurga': 'syurga', 'imbalan': 'imbal', 'neraka': 'neraka', 'hukuman': 'hukum', 'lbh': 'lbh', 'dibahas': 'bahas', 'mngenali': 'mngenali', 'tuhan': 'tuhan', 'konsekuensinya': 'konsekuensi', 'mnganut': 'mnganut', 'agama': 'agama', 'brarti': 'brarti', 'mngabdi': 'mngabdi', 'pd': 'pd', 'mmpertahankan': 'mmpertahankan', 'imej': 'imej', 'mngejar': 'mngejar', 'duh': 'duh', 'peraturan': 'atur', 'sexual': 'sexual', 'penzinahan': 'penzinahan', 'inikan': 'ini', 'berbeda': 'beda', 'kl': 'kl', 'kalimatx': 'kalimatx', 'difahami': 'difahami', 'undang': 'undang', 'blm': 'blm', 'bahasa': 'bahasa', 'indonesia': 'indonesia', 'bae': 'bae', 'kayakx': 'kayakx', 'namax': 'namax', 'jls': 'jls', 'setuju': 'tuju', 'unsur': 'unsur', 'jdi': 'jdi', 'kalimat': 'kalimat', 'seharusx': 'seharusx', 'dihilangkan': 'hilang', 'perdebatan': 'debat', 'dpt': 'dpt', 'atau pun': 'atau pun', 'haram': 'haram', 'kcuali': 'kcuali', 'lawan': 'lawan', 'anehny': 'anehny', 'negeriku': 'negeri', 'deh': 'deh', 'permen': 'permen', 'ancam': 'ancam', 'tindakan': 'tinda ...
# ------------------------

# %%
df['STEMMER'] = df['STOP_REMOVAL'].apply(get_stemmed_term)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral
# 5  sekalian aja pakaian anak sekolah dan mahasisw...  negatif
# 6  inilah makanya para korban ragu utk melapor us...   netral
# 7  presenter suka motong percakapan narasumber jd...   netral
# 8  kami sebagai ormas islam mendukung permedikbud...  positif
# 9  negara kacau pejabatnya nyeleneh coba urus yg ...  negatif
#
#                                         TOKENIZATION  \
# 0  [lha, kekerasan, seksual, itu, kan, mmg, defin...
# 1  [jngan, mendekati, zinah, itu, adalah, aturan,...
# 2  [the, law, is, an, art, semakin, rinci, semaki...
# 3  [tetapkan, dulu, aoa, yg, dimaksud, dgn, keker...
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [sekalian, aja, pakaian, anak, sekolah, dn, ma...
# 6  [inilah, makanya, para, korban, ragu, utk, mel...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [kami, sebagai, ormas, islam, mendukung, perme...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...
#
#                                         STOP_REMOVAL  \
# 0  [lha, kekerasan, seksual, mmg, definisinya, hr...
# 1  [jngan, mendekati, zinah, aturan, dn, ndak, pa...
# 2    [the, law, is, art, rinci, gampang, dibelokkan]
# 3            [tetapkan, aoa, kekerasan, seksualitas]
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [pakaian, anak, sekolah, dn, mahasiswa, rok, h...
# 6  [korban, ragu, melapor, usulan, uu, perlindung...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [ormas, islam, mendukung, permedikbudristek, n...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...
#
#                                              STEMMER
# 0  [lha, keras, seksual, mmg, definisi, hrs, tuju...
# 1  [jngan, dekat, zinah, atur, dn, ndak, pasal, u...
# 2         [the, law, is, art, rinci, gampang, belok]
# 3                   [tetap, aoa, keras, seksualitas]
# 4        [lbih, cock, terap, dikemendikbud, dn, dpr]
# 5  [pakai, anak, sekolah, dn, mahasiswa, rok, hrs...
# 6  [korban, ragu, lapor, usul, uu, lindung, hukum...
# 7  [presenter, suka, motong, cakap, nara, jd, nge...
# 8  [ormas, islam, dukung, permedikbudristek, no, ...
# 9  [negara, kacau, jabat, nyeleneh, coba, urus, s...

# %%
def fit_stemmer(text):
     text = np.array(text)
     text = ' '.join(text)
     return text

df['Komentar_Final'] = df['STEMMER'].apply(lambda x: fit_stemmer(x))
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  lha kekerasan seksual itu kan mmg definisinya ...  positif
# 1  jangan mendekati zina itu adalah aturan yang p...  negatif
# 2  the law is an art semakin rinci semakin mudah ...   netral
# 3  tetapkan dulu apa yang dimaksud dengan kekeras...   netral
# 4        lbih cock diterapkan dikemendikbud dan dpr    netral
# 5  sekalian aja pakaian anak sekolah dan mahasisw...  negatif
# 6  inilah makanya para korban ragu utk melapor us...   netral
# 7  presenter suka motong percakapan narasumber jd...   netral
# 8  kami sebagai ormas islam mendukung permedikbud...  positif
# 9  negara kacau pejabatnya nyeleneh coba urus yg ...  negatif
#
#                                         TOKENIZATION  \
# 0  [lha, kekerasan, seksual, itu, kan, mmg, defin...
# 1  [jngan, mendekati, zinah, itu, adalah, aturan,...
# 2  [the, law, is, an, art, semakin, rinci, semaki...
# 3  [tetapkan, dulu, aoa, yg, dimaksud, dgn, keker...
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [sekalian, aja, pakaian, anak, sekolah, dn, ma...
# 6  [inilah, makanya, para, korban, ragu, utk, mel...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [kami, sebagai, ormas, islam, mendukung, perme...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...
#
#                                         STOP_REMOVAL  \
# 0  [lha, kekerasan, seksual, mmg, definisinya, hr...
# 1  [jngan, mendekati, zinah, aturan, dn, ndak, pa...
# 2    [the, law, is, art, rinci, gampang, dibelokkan]
# 3            [tetapkan, aoa, kekerasan, seksualitas]
# 4   [lbih, cock, diterapkan, dikemendikbud, dn, dpr]
# 5  [pakaian, anak, sekolah, dn, mahasiswa, rok, h...
# 6  [korban, ragu, melapor, usulan, uu, perlindung...
# 7  [presenter, suka, motong, percakapan, nara, jd...
# 8  [ormas, islam, mendukung, permedikbudristek, n...
# 9  [negara, kacau, pejabatnya, nyeleneh, coba, ur...
#
#                                              STEMMER  \
# 0  [lha, keras, seksual, mmg, definisi, hrs, tuju...
# 1  [jngan, dekat, zinah, atur, dn, ndak, pasal, u...
# 2         [the, law, is, art, rinci, gampang, belok]
# 3                   [tetap, aoa, keras, seksualitas]
# 4        [lbih, cock, terap, dikemendikbud, dn, dpr]
# 5  [pakai, anak, sekolah, dn, mahasiswa, rok, hrs...
# 6  [korban, ragu, lapor, usul, uu, lindung, hukum...
# 7  [presenter, suka, motong, cakap, nara, jd, nge...
# 8  [ormas, islam, dukung, permedikbudristek, no, ...
# 9  [negara, kacau, jabat, nyeleneh, coba, urus, s...
#
#                                       Komentar_Final
# 0  lha keras seksual mmg definisi hrs tuju korban...
# 1  jngan dekat zinah atur dn ndak pasal uu dll de...
# 2                 the law is art rinci gampang belok
# 3                        tetap aoa keras seksualitas
# 4               lbih cock terap dikemendikbud dn dpr
# 5  pakai anak sekolah dn mahasiswa rok hrs lutut ...
# 6  korban ragu lapor usul uu lindung hukum korban...
# 7      presenter suka motong cakap nara jd ngeh gitu
# 8  ormas islam dukung permedikbudristek no keras ...
# 9    negara kacau jabat nyeleneh coba urus subtantif

# %%
df.to_csv(r'PreProcessing.csv')

# %%
import pickle
pickle.dump(stopword,
            open('stopword.pkl', 'wb'),
            protocol=4)

# %%
import pickle
pickle.dump(kamus_katabaku,
            open('kamus_katabaku.pkl', 'wb'),
            protocol=4)
