# %%
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: pandas==1.3.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (2022.2.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.16.0)

# %%
# !pip install swifter
# !pip install Sastrawi
# Out:
# Requirement already satisfied: swifter in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.3.4)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (4.64.0)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (5.0.1)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (2022.8.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (8.0.1)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (5.9.1)
# Requirement already satisfied: parso>0.4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (0.8.3)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (2.1.0)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (1.3.2)
# Requirement already satisfied: six>=1.9.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\asus\.conda\envs\aslan\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus\appdata\roaming\python\python39\site-packages (from dask[dataframe]>=2.10.0->swifter) (5.4.1)
# Requirement already satisfied: partd>=0.3.10 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.7.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: numpy>=1.18 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.23.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (8.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (4.0.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (3.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.15.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas>=1.0.0->swifter) (2022.2.1)
# Requirement already satisfied: colorama in c:\users\asus\.conda\envs\aslan\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: nest-asyncio in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.3.4)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: debugpy>=1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.6.3)
# Requirement already satisfied: setuptools>=18.5 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (63.4.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.13.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (3.0.30)
# Requirement already satisfied: decorator in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.4.0)
# Requirement already satisfied: backcall in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Requirement already satisfied: locket in c:\users\asus\.conda\envs\aslan\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: entrypoints in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\asus\.conda\envs\aslan\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: asttokens in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.0.8)
# Requirement already satisfied: pure-eval in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: executing in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.10.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\asus\appdata\roaming\python\python39\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (227)
# Requirement already satisfied: Sastrawi in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.0.1)

# %%
# !pip install google
# Out:
# Requirement already satisfied: google in c:\users\asus\.conda\envs\aslan\lib\site-packages (3.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from google) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from beautifulsoup4->google) (2.3.2.post1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
df = pd.read_csv(r'komenBlabel dua.csv')
df.head()
# Out:
#    Unnamed: 0                                           Komentar    Label
# 0           1  Seharusnya ruu tentang perlindungan korban kek...  negatif
# 1           2  bahkan sekelas GoTo aja masih kelolosan, apala...  negatif
# 2           3           MENDIKBUD YG TDK FAHAM ADAB BANGSA TIMUR  negatif
# 3           4            Kirain digugat gara-gara data mining. 😂  negatif
# 4           5                     Narasi suka x y sama yg bebas2  negatif

# %%
del df['Unnamed: 0']
df.head()
# Out:
#                                             Komentar    Label
# 0  Seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas GoTo aja masih kelolosan, apala...  negatif
# 2           MENDIKBUD YG TDK FAHAM ADAB BANGSA TIMUR  negatif
# 3            Kirain digugat gara-gara data mining. 😂  negatif
# 4                     Narasi suka x y sama yg bebas2  negatif

# %%
#cleaning Text
def remove_punct(text):
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    text = re.sub(r'\b\w(1,2)\b', '', text)
    text = re.sub(r'\s\s+', ' ', text)
    text = re.sub(r"\d+", "", text)
    return text
df['Komentar'] = df['Komentar'].apply(remove_punct)

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
df['Komentar'] = df['Komentar'].str.lower()
df.head()
# Out:
#                                             Komentar    Label
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif

# %%
def replace_repeat_character(text):
    # Pattern to look for three or more repetitions of any character, including newlines (contoh goool -> gol).
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", text)

df['Komentar'] = df['Komentar'].apply(replace_repeat_character) 
df.head()
# Out:
#                                             Komentar    Label
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif

# %%
from nltk.tokenize import word_tokenize

def tokenize(text):
    return nltk.word_tokenize(text)
    
df['TOKENIZATION'] = df['Komentar'].apply(tokenize)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif
# 5                                    kawaall terooss  negatif
# 6                 meta juga gk kena masa go to kena   negatif
# 7  permasalahan kekerasan seksual udah lamaa bgt ...  negatif
# 8  tim narasi niat banget ngehapus  comment saya ...  negatif
# 9                                       goped bagus   positif
#
#                                         TOKENIZATION
# 0  [seharusnya, ruu, tentang, perlindungan, korba...
# 1  [bahkan, sekelas, goto, aja, masih, kelolosan,...
# 2   [mendikbud, yg, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                    [narasi, suka, sama, yg, bebas]
# 5                                 [kawaall, terooss]
# 6         [meta, juga, gk, kena, masa, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, banget, ngehapus, comment,...
# 9                                     [goped, bagus]

# %%
katabaku = csv.reader(
	open(r"kata_baku.csv"), delimiter=";") # ambil file csv kata baku menjadi array

kamus_katabaku = {} # empty dictionary untuk kamus kata baku
try:
    for row in katabaku : # membuat kamus kata baku dengan input kata tidak baku dan output kata bakunya
        kamus_katabaku[row[0]] = row[1]
except:
    pass

# %%
print(kamus_katabaku)
# Out:
# {'abjad': 'abjat', 'akta': 'akte', 'aktif': 'aktiv', 'aktivitas': 'aktifitas', 'amendemen': 'amandemen', 'andal': 'handal', 'analisis': 'analisa', 'antre': 'antri', 'asas': 'azas', 'apak': 'apek', 'apotek': 'apotik', 'aritmetika': 'aritmatika', 'atlet': 'atlit', 'atmosfer': 'atmosfir', 'cabai': 'cabay', 'camilan': 'cemilan', 'cendekia': 'cendikia', 'cenderamata': 'cinderamata', 'detail': 'detil', 'definisi': 'difinisi', 'diagnosis': 'diagnosa', 'embus': 'hembus', 'ekstra': 'extra', 'ekstrem': 'ekstrim', 'esai': 'esei', 'februari': 'febuari', 'fondasi': 'pondasi', 'formal': 'formil', 'frasa': 'frase', 'frekuensi': 'frekwensi', 'gizi': 'gisi', 'hafal': 'hapal', 'hakikat': 'hakekat', 'hipotesis': 'hipotesa', 'hierarki': 'hirarkhi', 'ijazah': 'ijasah', 'izin': 'ijin', 'imbau': 'himbau', 'isap': 'hisap', 'istri': 'isteri', 'jadwal': 'jadual', 'jenazah': 'jenasah', 'jenderal': 'jendral', 'justru': 'justeru', 'kafetaria': 'kafeteria', 'kalender': 'kalendar', 'karier': 'karir', 'katapel': 'ketapel', 'kategori': 'katagori', 'kedaluwarsa': 'kadaluwarsa', 'kendaraan': 'kenderaan', 'komplet': 'komplit', 'konferensi': 'konperensi', 'kongres': 'konggres', 'konkret': 'kongkret', 'kreativitas': 'kreatifitas', 'kualifikasi': 'kwalifikasi', 'kualitatif': 'kwalitatif', 'kuantitatif': 'kwantitatif', 'kualitas': 'kwalitet', 'kuitansi': 'kwitansi', 'lubang': 'lobang', 'makhluk': 'mahkluk', 'manajemen': 'managemen', 'masjid': 'mesjid', 'merek': 'merk', 'meterai': 'meterei', 'metode': 'metoda', 'miliar': 'milyar', 'misi': 'missi', 'modern': 'moderen', 'mubazir': 'mubadir', 'mulia': 'mulya', 'mungkir': 'pungkir', 'napas': 'nafas', 'narasumber': 'nara', 'nasihat': 'nasehat', 'objek': 'obyek', 'objektif': 'obyektif', 'paham': 'faham', 'parlemen': 'parlamen', 'paspor': 'pasport', 'peduli': 'perduli', 'pikir': 'fikir', 'praktik': 'praktek', 'provinsi': 'propinsi', 'rabu': 'rebo', 'risiko': 'resiko', 'sah': 'syah', 'sanggama': 'senggama', 'sekadar': 'sekedar', 'sekuler': 'sekular', 'seluler': 'selular', 'semadi': 'semedi', 'sentral': 'central', 'seprai': 'seprei', 'silakan': 'silahkan', 'sirkuler': 'sirkular', 'sistem': 'sistim', 'saksama': 'seksama', 'subjek': 'subyek', 'subjektif': 'subyektif', 'surga': 'syurga', 'survei': 'survey', 'tampak': 'nampak', 'teladan': 'tauladan', 'teknik': 'tekhnik', 'teknologi': 'tekhnologi', 'telanjur': 'terlanjur', 'telantar': 'terlantar', 'terampil': 'trampil', 'vila': 'villa', 'wakaf': 'waqaf', 'wujud': 'ujud', 'yudikatif': 'yudikatip', 'ubah': 'rubah', 'zaman': 'jaman', 'alpa': 'alfa', 'baik': 'bae', 'balas': 'bales', 'belum': 'blm', 'capai': 'capek', 'dalam': 'dalem', 'dapat': 'dpt', 'disahkan': 'disyahkan', 'hilang': 'ilang', 'ikhlas': 'ihlas', 'ingat': 'inget', 'itikad': 'itikat', 'jumat': "jum'at", 'karena': 'krn', 'kasier': 'kasir', 'karisma': 'kharisma', 'kepada': 'ke pada', 'kerap': 'kerab', 'kaidah': 'kaedah', 'khatulistiwa': 'katulistiwa', 'khawatir': 'kuatir', 'kuadrat': 'kwadrat', 'kuantum': 'kwantum', 'kuis': 'kuiz', 'lazim': 'lajim', 'losin': 'lusin', 'maaf': 'apologize', 'macam': 'macem', 'malas': 'males', 'manfaat': 'manpaat', 'nomor': 'nmr', 'materai': 'matere', 'mengesampingkan': 'mengenyampingkan', 'mengubah': 'merubah', 'padat': 'padet', 'pelanggan': 'langganan', 'pensil': 'pinsil', 'pertanggung jawaban': 'pertanggungjawab', 'pihak': 'fihak', 'populer': 'popular', 'rapat': 'rapet', 'sampai': 'sampek', 'selesai': 'selese', 'seperti': 'kayak', 'aksi': 'action', 'anarki': 'anarkhi', 'anggota': 'anggauta', 'biosfer': 'biosfir', 'cepat': 'cpt', 'debit': 'debet', 'devaluasi': 'defaluasi', 'doa': "do'a", 'diam': 'diem', 'daftar': 'daptar', 'dipersilakan': 'dipersilahkan', 'ekuivalen': 'ekwivalen', 'elite': 'elit', 'familier': 'familiar', 'glucose': 'glukosa', 'grup': 'group', 'genting': 'genteng', 'gubuk': 'gubug', 'hectare': 'hektar', 'heterogen': 'hetrogen', 'hipotek': 'hipotik', 'hanya': 'cuma', 'habis': 'abis', 'ideologi': 'idiologi', 'interogasi': 'interograsi', 'introspeksi': 'interospeksi', 'interupsi ...

# %%
def normalized_term(text):
    return [kamus_katabaku[term] if term in kamus_katabaku else term for term in text]
df['TOKENIZATION'] = df['TOKENIZATION'].apply(normalized_term) 
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif
# 5                                    kawaall terooss  negatif
# 6                 meta juga gk kena masa go to kena   negatif
# 7  permasalahan kekerasan seksual udah lamaa bgt ...  negatif
# 8  tim narasi niat banget ngehapus  comment saya ...  negatif
# 9                                       goped bagus   positif
#
#                                         TOKENIZATION
# 0  [seharusnya, ruu, tentang, perlindungan, korba...
# 1  [bahkan, sekelas, goto, aja, masih, kelolosan,...
# 2   [mendikbud, yg, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                    [narasi, suka, sama, yg, bebas]
# 5                                 [kawaall, terooss]
# 6          [meta, jga, gk, kena, masa, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]

# %%
stopword =nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                 'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                 'krn', 'nya', 'nih', 'sih', 
                 'si', 'tau', 'tuh', 'utk', 'ya','sdh',
                 'aja', 'n', 't', 'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                 '&amp', 'yah', 'njir', 'wkwk', 'haha', 'hehe', 'rs', 'yaa',
                 'nii', 'bin', 'lahh', 'hmm', 'lieur', 'njarem', 'kale',
                 'hd', 'an', 'ob', 'bro', 'ud', 'iyaa', 'guys', 'doang',
                 'doank', 'eh', 'kek', 'or', 'kah', 'eso', 'tuh', 'dh', 'dnk',
                 'mh', 'ja', 'tu', 'anu', 'ni', 'ku', 'blz', 'gy', 'skg', 'eeh',
                 'pas','tar','bc','x','dong','d'])

# %%
word_list=['enggak','tidak','jangan','belum']
stopword = [word for word in stopword if word not in word_list] #make a copy of the word_list

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stopword]
    
df['STOP_REMOVAL'] = df['TOKENIZATION'].apply(remove_stopwords)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif
# 5                                    kawaall terooss  negatif
# 6                 meta juga gk kena masa go to kena   negatif
# 7  permasalahan kekerasan seksual udah lamaa bgt ...  negatif
# 8  tim narasi niat banget ngehapus  comment saya ...  negatif
# 9                                       goped bagus   positif
#
#                                         TOKENIZATION  \
# 0  [seharusnya, ruu, tentang, perlindungan, korba...
# 1  [bahkan, sekelas, goto, aja, masih, kelolosan,...
# 2   [mendikbud, yg, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                    [narasi, suka, sama, yg, bebas]
# 5                                 [kawaall, terooss]
# 6          [meta, jga, gk, kena, masa, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]
#
#                                         STOP_REMOVAL
# 0  [ruu, perlindungan, korban, kekerasan, seksual...
# 1  [sekelas, goto, kelolosan, rempahan, rengginan...
# 2       [mendikbud, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                              [narasi, suka, bebas]
# 5                                 [kawaall, terooss]
# 6                [meta, jga, gk, kena, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import swifter

# implementasi pada data kita

# stemmed
def stemmed_wrapper(text):
    return stemmer.stem(text)

text_dict = {}

for document in df['STOP_REMOVAL']:
    for text in document:
        if text not in text_dict:
            text_dict[text] = ' '
            
print(len(text_dict))
print("------------------------")

for text in text_dict:
    text_dict[text] = stemmed_wrapper(text)
    print(text,":" ,text_dict[text])
    
print(text_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [text_dict[text] for text in document]
# Out:
# 1504
# ------------------------
# ruu : ruu
# perlindungan : lindung
# korban : korban
# kekerasan : keras
# seksual : seksual
# hrs : hrs
# legalkan : legal
# byk : byk
# mnjdi : mnjdi
# tersangka : sangka
# sekelas : kelas
# goto : goto
# kelolosan : lolos
# rempahan : rempah
# rengginang : rengginang
# kong : kong
# wan : wan
# mendikbud : mendikbud
# tdk : tdk
# faham : faham
# adab : adab
# bangsa : bangsa
# timur : timur
# kirain : kirain
# digugat : gugat
# gara : gara
# data : data
# mining : mining
# narasi : narasi
# suka : suka
# bebas : bebas
# kawaall : kawaall
# terooss : terooss
# meta : meta
# jga : jga
# gk : gk
# kena : kena
# go : go
# to : to
# permasalahan : masalah
# udah : udah
# lamaa : lamaa
# bgt : bgt
# jd : jd
# polemik : polemik
# speak : speak
# up : up
# medsos : medsos
# jg : jg
# stigma : stigma
# dn : dn
# disalahkan : salah
# gak : gak
# ngerti : ngerti
# knp : knp
# nyerang : nyerang
# seiring : iring
# berjalannya : jalan
# kasusnya : kasus
# bertambah : tambah
# menerus : terus
# tp : tp
# pks : pks
# bhkn : bhkn
# permendikbud : permendikbud
# ditentang : tentang
# sy : sy
# betapa : betapa
# ndak : ndak
# inginnya : ingin
# melindungi : lindung
# hati : hati
# aq : aq
# tim : tim
# niat : niat
# ngehapus : ngehapus
# comment : comment
# yak : yak
# goped : goped
# oke : oke
# kontranya : kontra
# gajelas : gajelas
# galiat : galiat
# urgensi : urgensi
# hadehh : hadehh
# semoga : moga
# terbaik : baik
# indonesia : indonesia
# tercintaku : cinta
# huhuhuhuu : huhuhuhuu
# sehat : sehat
# mba : mba
# cantiku : cantiku
# partai : partai
# getol : getol
# menolak : tolak
# gemes : gemes
# bngt : bngt
# gw : gw
# bsa : bsa
# melenyapkan : lenyap
# predator : predator
# kampus : kampus
# yes : yes
# melegalkan : legal
# sex : sex
# peraturnnya : peraturnnya
# untk : untk
# perkosa : perkosa
# klw : klw
# ga : ga
# masalh : masalh
# hadeeh : hadeeh
# berkerudung : kerudung
# gini : gin
# lbh : lbh
# bahas : bahas
# hersubeno : hersubeno
# arif : arif
# pemerkosa : perkosa
# org : org
# berkuasa : kuasa
# sllu : sllu
# membawa : bawa
# nama : nama
# dr : dr
# subtansi : subtansi
# kritikan : kritik
# tsb : tsb
# dosen : dosen
# belagu : belagu
# tai : tai
# kebelaguannya : kebelaguannya
# nolong : nolong
# kecakapan : cakap
# mahasiswanya : mahasiswa
# lapangan : lapang
# kerja : kerja
# wajah : wajah
# senyum : senyum
# cantik : cantik
# kakak : kakak
# ganti : ganti
# predatornya : predator
# muslim : muslim
# konservatif : konservatif
# setuju : tuju
# peraturan : atur
# syarat : syarat
# dihapus : hapus
# frase : frase
# persetujuan : tuju
# contoh : contoh
# pasal : pasal
# membuka : buka
# pakaian : pakai
# mahasiswa : mahasiswa
# mahasiswi : mahasiswi
# iyahh : iyahh
# aoa : aoa
# silahkan : silah
# dibolehkan : boleh
# legal : legal
# bahaya : bahaya
# bersetubuh : tubuh
# berzinah : berzinah
# tampilkan : tampil
# ambigu : ambigu
# arti : arti
# dilegalkan : legal
# dampak : dampak
# burukk : burukk
# infeksi : infeksi
# menular : tular
# merajelala : merajelala
# hiv : hiv
# anak : anak
# belajar : ajar
# mlh : mlh
# merintih : rintih
# melahirkan : lahir
# aborsi : aborsi
# keluarga : keluarga
# terjerat : jerat
# maksud : maksud
# merusak : rusak
# jadikan : jadi
# pedoman : pedoman
# manusia : manusia
# beradab : adab
# beragama : agama
# minoritas : minoritas
# nonton : nonton
# anisya : anisya
# azni : azni
# muaantaab : muaantaab
# skrng : skrng
# maen : maen
# aamaan : aamaan
# sis : sis
# slama : slama
# lw : lw
# nga : nga
# ngas : ngas
# hotel : hotel
# gas : gas
# bwahahaahaha : bwahahaahaha
# baca : baca
# dukung : dukung
# permen : permen
# udh : udh
# ngebet : ngebet
# tahan : tahan
# nikah : nikah
# nunggu : nunggu
# halal : halal
# kacau : kacau
# membaca : baca
# permendikbudnya : permendikbudnya
# diakhir : akhir
# ayatnya : ayat
# muncul : muncul
# namanya : nama
# dimunculkan : muncul
# liat : liat
# pola : pola
# sebutan : sebut
# dipelintir : pelintir
# alat : alat
# membebaskan : bebas
# pelaku : laku
# bingung : bingung
# syariat : syariat
# risikoberikhtilath : risikoberikhtilath
# uu : uu
# ite : ite
# karet : karet
# menyebabkan : sebab
# makrim : makrim
# mentri : tri
# otak : otak
# mesum : mesum
# perzinaan : zina
# ntah : ntah
# payung : payung
# hukum : hukum
# pelecehan : leceh
# menutup : tutup
# kesempatan : sempat
# tuk : tuk
# memangsa : mangsa
# keyakinan : yakin
# sono : sono
# asyiik : asyiik
# zinah : zinah
# bkn : bkn
# a susila : a susila
# bo : bo
# ayam : ayam
# khan : khan
# topp : topp
# markotop : markotop
# nadim : nadim
# mankrak : mankrak
# rim : rim
# ancur : ancur
# negara : negara
# inget : inget
# tiang : tiang
# wanita : wanita
# ahklaq : ahklaq
# kehancuran : hancur
# dpr : dpr
# dewan : dewan
# perwakilan : wakil
# rejim : rejim
# rakyat : rakyat
# menyetujui : tuju
# memaksa : paksa
# ancaman : ancam
# nilai : nilai
# didunia : dunia
# terkesan : kes
# bodoh : bodoh
# dlm : dlm
# fakta : fakta
# kejadiannya : jadi
# dijadikan : jadi
# pembelaan : bela
# bejad : bejad
# mentalnya : mental
# wkwkwkwk : wkwkwkwk
# bolehkan : boleh
# hobi : hobi
# berzinaa : berzinaa
# berteriak : teriak
# horee : horee
# kegirangan : girang
# good : good
# joob : joob
# nadiem : nadiem
# makariem : makariem
# bak : bak
# efi : efi
# pikiranx : pikiranx
# nyampek : nyampek
# kayak : kayak
# layak : layak
# bicarax : bicarax
# penampilanx : penampilanx
# kadrun : kadrun
# chat : chat
# kagak : kagak
# bhahaha : bhahaha
# drp : drp
# zholim : zholim
# seblm : seblm
# gulali : gulali
# hh : hh
# ngasih : ngasih
# buka : buka
# baju : baju
# hahh : hahh
# duuh : duuh
# parah : parah
# pacaran : pacar
# waswas : waswas
# berhubungan : hubung
# badan : badan
# merumuskan : rumus
# pura : pura
# gimana : gimana
# sepatutnya : patut
# masukan : masuk
# absorb : absorb
# jngan : jngan
# reaktif : reaktif
# defense : defense
# konteks : konteks
# munculnya : muncul
# suka rela : suka rela
# tpi : tpi
# intimidasi : intimidasi
# alangkah : alangkah
# bae : bae
# memaksimalkan : maksimal
# pencegahan : cegah
# buatlah : buat
# aturan : atur
# celah : celah
# aktifis : aktif
# anggauta : anggauta
# pemikirannya : pikir
# cerdas : cerdas
# buru : buru
# membiarkan : biar
# revisi : revisi
# mmg : mmg
# bnr : bnr
# mencegah : cegah
# intinya : inti
# belom : bom
# tua : tua
# dibawah : bawah
# umur : umur
# dihukum : hukum
# mati : mati
# karna : karna
# bentuk : bentuk
# perusak : usak
# alam : alam
# bumi : bumi
# rusak : rusak
# pembuat : buat
# nuntut : nuntut
# ilmu : ilmu
# msk : msk
# delik : delik
# atur : atur
# pisah : pisah
# haikal : haikal
# lo : lo
# ngak : ngak
# nyambung : nyambung
# sok : sok
# pintar : pintar
# agama : agama
# akhlak : akhlak
# terjaga : jaga
# jinah : jah
# hukumnya : hukum
# haram : haram
# selamat : selamat
# dunia : dunia
# akherat : akherat
# kuliahkan : kuliah
# disekolahkan : sekolah
# perguruan : guru
# islami : islami
# ribut : ribut
# urusan : urus
# selangkangan : selangkang
# anehny : anehny
# smpe : smpe
# ngaur : ngaur
# bener : bener
# melenceng : lenceng
# knpa : knpa
# pilihan : pilih
# presiden : presiden
# berbuat : buat
# kerusuhan : rusuh
# haah : haah
# enak : enak
# guwe : guwe
# hebat : hebat
# babe : babe
# ngaco : ngaco
# generasi : generasi
# penerus : terus
# kebanyakan : banyak
# ecchi : ecchi
# ama : ama
# hentai : hentai
# wkwkwk : wkwkwk
# mempersilahkan : silah
# bajunya : baju
# lepas : lepas
# mencari : cari
# keuntungan : untung
# musti : musti
# direvisi : revisi
# undang : undang
# undangnya : undang
# jgn : jgn
# sampe : sampe
# pemerintah : perintah
# macem : macem
# goa : goa
# gebukin : gebukin
# pejabat : jabat
# berprestasi : prestasi
# keruwetan : ruwet
# kpan : kpan
# pemerintahan : perintah
# jokowi : jokowi
# selese : selese
# maafkan : maaf
# mbak : mbak
# veni : veni
# blm : blm
# realita : realita
# sm : sm
# krng : krng
# seimbang : imbang
# pikiran : pikir
# kaum : kaum
# tidk : tidk
# pungkiri : pungkiri
# otaknya : otak
# melulu : melulu
# gila : gila
# bidadari : bidadari
# biadab : biadab
# wkk : wkk
# perempuan : perempuan
# genjot : genjot
# gembrot : gembrot
# kliatnya : kliatnya
# lom : lom
# pny : pny
# pacar : pacar
# pngen : pngen
# coba : coba
# lho : lho
# pade : pade
# kemarin : kemarin
# mata : mata
# najwa : najwa
# disitu : situ
# forumnya : forum
# berbobot : bobot
# nara : nara
# sesuai : sesuai
# substansi : substansi
# dibahas : bahas
# hasan : hasan
# dpt : dpt
# ciri : ciri
# khas : khas
# betawi : betawi
# garis : garis
# keturunan : turun
# allah : allah
# tokang : tokang
# ojol : ojol
# mintri : mintri
# akibatnx : akibatnx
# innalillahi : innalillahi
# weinnalillahi : weinnalillahi
# rojion : rojion
# zinai : zina
# istrinya : istri
# putih : putih
# menjajahkan : jajah
# udahlah : udahlah
# bu : bu
# lihat : lihat
# berdasarkan : dasar
# gendeng : gendeng
# koruptor : koruptor
# asu : asu
# sila : sila
# masum : masum
# feminism : feminism
# didenger : didenger
# logical : logical
# fallacy : fallacy
# hiraukan : hirau
# jalnkan : jalnkan
# insaallh : insaallh
# genderasi : genderasi
# dipatuhi : patuh
# mendikbut : mendikbut
# disyahkan : syah
# menag : menag
# hancur : hancur
# bunting : bunting
# pertanyaannya : tanya
# isteri : isteri
# bersedia : sedia
# setubuhi : tubuh
# tinggal : tinggal
# negri : negri
# memahamai : memahamai
# bahasa : bahasa
# sukakan : suka
# permendikbudristek : permendikbudristek
# dimusyawarahkan : musyawarah
# tokoh : tokoh
# masyarakat : masyarakat
# kebijakan : bijak
# memperkecil : kecil
# keresahan : resah
# timbul : timbul
# budaya : budaya
# bergeser : geser
# skrg : skrg
# sj : sj
# dipayungi : payung
# gass : gass
# sampek : sampek
# iblis : iblis
# do : do
# goalkan : goalkan
# liberal : liberal
# sungsang : sungsang
# kasih : kasih
# peljaran : peljaran
# luruskan : lurus
# salah : salah
# posisinya : posisi
# forum : forum
# bermimpi : mimpi
# ketemu : ketemu
# nabi : nabi
# muhammad : muhammad
# saw : saw
# assalamualaikum : assalamualaikum
# no : no
# dalem : dalem
# ditangani : tangan
# mendikbudristek : mendikbudristek
# apologize : apologize
# seandainya : anda
# menggosokkan : gosok
# kelaminnya : kelamin
# tubuh : tubuh
# tersembunyi : sembunyi
# perbuatan : buat
# ketauan : tau
# ditindak : tindak
# lanjuti : lanjut
# mengurusi : urus
# akibat : akibat
# hubungan : hubung
# kegiatan : giat
# bertentangan : tentang
# norma : norma
# akar : akar
# membahas : bahas
# tindakan : tindak
# trmksh : trmksh
# wassalamu : wassalamu
# alaikum : alaikum
# kunci : kunci
# sorga : sorga
# dihalalkan : halal
# poligami : poligami
# hajkal : hajkal
# suci : suci
# gerombolan : gerombol
# munafik : munafik
# usut : usut
# kuhp : kuhp
# tafirnya : tafirnya
# permendikti : permendikti
# heran : heran
# isu : isu
# apapun : apa
# tv : tv
# one : one
# msti : msti
# haekal : haekal
# buset : buset
# universiti : universiti
# nggk : nggk
# dah : dah
# edan : edan
# neng : neng
# endut : endut
# larinya : lari
# wkwjwk : wkwjwk
# keliatan : liat
# mvk : mvk
# wawasan : wawas
# hei : hei
# istilah : istilah
# kumpul : kumpul
# kebo : kebo
# kos : kos
# kosan : kosan
# mengatur : atur
# kehidupan : hidup
# berkaitan : kait
# hipnotis : hipnotis
# menawarkan : tawar
# melayani : layan
# etika : etika
# menerima : terima
# ngeres : ngeres
# memanfat : memanfat
# azas : azas
# manpaat : manpaat
# ha : ha
# kal : kal
# hassan : hassan
# peranakan : ana
# arab : arab
# yaman : yaman
# tukang : tukang
# gaduhh : gaduhh
# ang : ang
# keladi : keladi
# jaga : jaga
# mulut : mulut
# kau : kau
# somplakk : somplakk
# modal : modal
# kondom : kondom
# landasan : landas
# dasar : dasar
# bukti : bukti
# tambahan : tambah
# lahir : lahir
# bayi : bayi
# usia : usia
# muda : muda
# men : men
# rialita : rialita
# ayah : ayah
# intim : intim
# kandung : kandung
# mertua : mertua
# selingkuh : selingkuh
# ma : ma
# mantu : mantu
# peluang : peluang
# tutup : tutup
# pendukung : dukung
# jubir : jubir
# berargumen : argumen
# ngalor : ngalor
# ngidul : ngidul
# keluarganya : keluarga
# cetek : cetek
# revolusi : revolusi
# aklaq : aklaq
# ilmunya : ilmu
# paaspasan : paaspasan
# segitu : segitu
# nongol : nongol
# maklum : maklum
# hostnya : hostnya
# culun : culun
# fakboy : fakboy
# be : be
# like : like
# horrayy : horrayy
# ngundang : ngundang
# ko : ko
# alloh : alloh
# dateng : dateng
# pad : pad
# sayah : sayah
# boong : boong
# resmiin : resmiin
# apalgi : apalgi
# remikan : remi
# koplk : koplk
# kowe : kowe
# tmpat : tmpat
# pro : pro
# khilafah : khilafah
# berkoar : koar
# koar : koar
# so : so
# pinter : pinter
# spt : spt
# penipu : tipu
# ulung : ulung
# cendana : cendana
# tinggalkan : tinggal
# hayo : hayo
# mengambil : ambil
# ngga : ngga
# terima : terima
# mngambil : mngambil
# sbuah : sbuah
# keputusan : putus
# ajak : ajak
# brunding : brunding
# kpda : kpda
# mngerti : mngerti
# kebaikan : baik
# brsama : brsama
# ampun : ampun
# kuning : kuning
# sngat : sngat
# sopan : sopan
# pahanya : paha
# diangkat : angkat
# koplak : koplak
# ne : ne
# gmn : gmn
# mahasiwanya : mahasiwanya
# ular : ular
# beludak : beludak
# diajak : ajak
# diskusi : diskusi
# trgantung : trgantung
# manusianya : manusia
# lh : lh
# gembar : gembar
# gembor : gembor
# menganut : anut
# ideology : ideology
# eka : eka
# ketuhanan : tuhan
# bekebudayaan : bekebudayaan
# pada hal : pada hal
# darurat : darurat
# kejadian : jadi
# viral : viral
# skr : skr
# peri laku : peri laku
# kalangan : kalang
# fasal : fasal
# menghapus : hapus
# politik : politik
# maha : maha
# esa : esa
# mengganti : ganti
# berkebudayaan : budaya
# panca sila : panca sila
# harga : harga
# membingungkan : bingung
# endonesa : endonesa
# ngustad : ngustad
# sampah : sampah
# pitar : pitar
# dimna : dimna
# pengertian : erti
# menghlalkn : menghlalkn
# busukmu : busuk
# menggoreng : goreng
# berita : berita
# lokalisasi : lokalisasi
# pendidikan : didik
# sek : sek
# hantar : hantar
# siswa : siswa
# siswi : siswi
# leluasa : leluasa
# gitu : gitu
# non : non
# peraturanya : peraturanya
# menabrak : tabrak
# ahirnya : ahirnya
# gaduh : gaduh
# menghargai : harga
# mayoritas : mayoritas
# umat : umat
# islam : islam
# didalam : dalam
# ajaranya : ajaranya
# larang : larang
# tetep : tetep
# perzinahan : perzinahan
# fikir : fikir
# bag : bag
# gampang : gampang
# dlu : dlu
# ngapain : ngapain
# nyuruh : nyuruh
# cureek : cureek
# curek : curek
# jdi : jdi
# greget : greget
# ky : ky
# duka : duka
# bagas : bagas
# gemuk : gemuk
# bela : bela
# hak : hak
# hadeehh : hadeehh
# ngotot : ngotot
# buntelan : buntel
# kentut : kentut
# berjasa : jasa
# menciptakan : cipta
# mutu : mutu
# berebut : rebut
# nyata : nyata
# bertubrukan : tubruk
# kuncinya : kunci
# akal : akal
# akalan : akal
# bokbrok : bokbrok
# wkwkwkwkkw : wkwkwkwkkw
# bolong : bolong
# gagal : gagal
# semi : semi
# fungsi : fungsi
# mentrinya : tri
# adem : adem
# mantap : mantap
# babey : babey
# monafik : monafik
# jurus : jurus
# dikerahkan : kerah
# menegakkan : tegak
# benang : benang
# basah : basah
# wajib : wajib
# cwe : cwe
# gendut : gendut
# doyan : doyan
# grepe : grepe
# kali : kali
# mantaf : mantaf
# venny : venny
# pertahankan : tahan
# prinsip : prinsip
# perjuangan : juang
# dkk : dkk
# titik : titik
# umpamanya : umpama
# bertahan : tahan
# ego : ego
# pribadi : pribadi
# mendukung : dukung
# kegigihan : gigih
# bravo : bravo
# veny : veny
# hahaha : hahaha
# konyol : konyol
# kaya : kaya
# artisnya : artis
# tvone : tvone
# acara : acara
# sumbernya : sumber
# provokator : provokator
# bohong : bohong
# artis : artis
# klas : klas
# cewek : cewek
# agamanya : agama
# rx : rx
# masyaallah : masyaallah
# babeh : babeh
# memgusulkan : memgusulkan
# mencermiinkan : mencermiinkan
# muka : muka
# niatnya : niat
# tujuannya : tuju
# kl : kl
# emang : emang
# isinya : isi
# masi : mas
# multi : multi
# tafsir : tafsir
# pd : pd
# dasarnya : dasar
# meminimalisir : meminimalisir
# kesalahannya : salah
# permedikbud : permedikbud
# kontra : kontra
# disalah : salah
# artikan : arti
# saran : saran
# suruh : suruh
# cabut : cabut
# arah : arah
# dsb : dsb
# siregar : siregar
# dinikahkan : nikah
# koq : koq
# dungu : dungu
# yaakk : yaakk
# ngelindungi : ngelindungi
# hadeuuhh : hadeuuhh
# maluin : maluin
# ngampuss : ngampuss
# al : al
# quran : quran
# tuntunan : tuntun
# aneeh : aneeh
# buzzer : buzzer
# dosennya : dosen
# pdip : pdip
# sekular : sekular
# vera : vera
# hasil : hasil
# langkah : langkah
# mnangani : mnangani
# sanksinya : sanksi
# diperberat : berat
# diperkejam : kejam
# hukumannya : hukum
# maju : maju
# mundur : mundur
# proyeknya : proyek
# anggaran : anggar
# keluarkan : keluar
# kemendikbud : kemendikbud
# nanya : nanya
# goblog : goblog
# dipiara : piara
# hasaan : hasaan
# ngibul : ngibul
# pake : pake
# brpa : brpa
# lagh : lagh
# pencabulan : cabul
# bisnis : bisnis
# rampok : rampok
# haduhh : haduhh
# keberatan : berat
# dmn : dmn
# belah : belah
# fihak : fihak
# yogya : yogya
# mui : mui
# sineng : seng
# ngk : ngk
# kayaky : kayaky
# sam : sam
# prermpuan : prermpuan
# betina : betina
# hukuman : hukum
# tafsirnya : tafsir
# jilbab : jilbab
# isi : isi
# bertolak : tolak
# argumennya : argumen
# penegasan : tegas
# harysnya : harysnya
# memunculkan : muncul
# ambiguitas : ambiguitas
# jls : jls
# gokil : gokil
# gedenya : gede
# kecuali : kecuali
# kemampuannya : mampu
# berpikir : pikir
# brati : brati
# korperatif : korperatif
# kesalahan : salah
# terhormat : hormat
# anaknya : anak
# ttp : ttp
# kalah : kalah
# jumbo : jumbo
# berusahalah : usaha
# menyempurnakan : sempurna
# memperbaiki : baik
# krg : krg
# sempurna : sempurna
# konsepnya : konsep
# sekejap : kejap
# perasaan : asa
# napsu : napsu
# syahwat : syahwat
# perut : perut
# maak : maak
# sexual : sexual
# kader : kader
# pdi : pdi
# buta : buta
# dikampus : kampus
# nonmus : nonmus
# maunya : mau
# barat : barat
# kiblat : kiblat
# merka : merka
# mengundangkan : undang
# berpengalaman : alam
# atau pun : atau pun
# bismillahirrahmanirrahim : bismillahirrahmanirrahim
# rambu : rambu
# ditaat : taat
# dilaksanakan : laksana
# lantas : lantas
# ketangkep : ketangkep
# memakai : pakai
# jngankan : jngankan
# murid : murid
# ngaji : ngaji
# vc : vc
# kyak : kyak
# difikiran : difikiran
# duo : duo
# astaghfirullah : astaghfirullah
# naudzubillah : naudzubillah
# iyyuuhh : iyyuuhh
# ayo : ayo
# suara : suara
# kbnaran : kbnaran
# dngan : dngan
# lantang : lantang
# jngn : jngn
# kndorr : kndorr
# pa : pa
# bgtu : bgtu
# teteh : teteh
# manggil : manggil
# ust : ust
# mainnya : main
# dimana : mana
# rahasia : rahasia
# nggak : nggak
# pelanggaran : langgar
# jekas : jekas
# tertulis : tulis
# pancasilais : pancasilais
# multitafsir : multitafsir
# sesimple : sesimple
# terkait : kait
# implementasi : implementasi
# pemen : pen
# dipungkiri : dipungkiri
# mesti : mesti
# penjelasan : jelas
# terintimidasi : intimidasi
# kronologi : kronologi
# pembuktiannya : bukti
# kalimat : kalimat
# dannkata : dannkata
# kepastian : pasti
# case : case
# pastinya : pasti
# bijaklah : bijak
# menetapkan : tetap
# menentukan : tentu
# vani : vani
# alibi : alibi
# kedok : kedok
# permendibud : permendibud
# logika : logika
# ngawur : ngawur
# aturannya : atur
# buk : buk
# nalarnya : nalar
# berbanding : banding
# lurus : lurus
# bobotnya : bobot
# paksa : paksa
# ancam : ancam
# sanggup : sanggup
# melwan : melwan
# kadang : kadang
# dibunuh : bunuh
# rela : rela
# dibawa : bawa
# kemana : mana
# kenyataannya : nyata
# ngomong : ngomong
# anti : anti
# berzina : zina
# penanggulangan : tanggulang
# liar : liar
# kesadaran : sadar
# save : save
# arigatoguzaimasu : arigatoguzaimasu
# kerasukkan : rasuk
# syetan : syetan
# kepepet : pepet
# mengelak : elak
# ajaib : ajaib
# dosa : dosa
# dipanggang : panggang
# api : api
# neraka : neraka
# bertobatlah : tobat
# jalan : jalan
# hikal : hikal
# msh : msh
# diundang : undang
# rame : rame
# sikafer : sikafer
# munafiq : munafiq
# dzubaedah : dzubaedah
# lengan : lengan
# paha : paha
# hilangkan : hilang
# salahnya : salah
# gede : gede
# bh : bh
# narsum : narsum
# apasaja : apasaja
# wlaupun : wlaupun
# dtg : dtg
# kepakaran : pakar
# mengantisipasi : antisipasi
# meski pun : meski pun
# lu : lu
# miris : miris
# bocil : bocil
# jaman : jaman
# now : now
# apasalahnya : apasalahnya
# ditahan : tahan
# proses : proses
# gadis : gadis
# diperlakukan : laku
# senonoh : senonoh
# laki : laki
# alesanya : alesanya
# murah : murah
# bersikap : sikap
# bagai mana : bagai mana
# kalbu : kalbu
# menterinya : menteri
# diknasristek : diknasristek
# kemanusiaan : manusia
# diterbitkan : terbit
# sunguh : sunguh
# mengenaskan : enas
# dibuang : buang
# kedalam : dalam
# tong : tong
# sanksi : sanksi
# pelakunya : laku
# pria : pria
# lelakinya : lelaki
# bersuami : suam
# lingkungan : lingkung
# berani : berani
# sikapnya : sikap
# bertindak : tindak
# bab : bab
# pokonamah : pokonamah
# teas : teas
# neh : neh
# stempel : stempel
# kesemuanya : semua
# dungurockygarong : dungurockygarong
# aduh : aduh
# jebakan : jebak
# betmen : betmen
# ngilangin : ngilangin
# jejak : jejak
# pcr : pcr
# kenceng : kenceng
# kyk : kyk
# junjungannya : junjung
# watak : watak
# cebong : cebong
# susah : susah
# memilah : mem
# ngomongnya : ngomongnya
# blepotan : blepot
# meindungi : meindungi
# bong : bong
# sekoilah : sekoi
# nanggulangin : nanggulangin
# beda : beda
# kalu : kalu
# mutar : mutar
# muter : muter
# kebelinger : kebelinger
# tersesat : sesat
# dihutan : hut
# utan : utan
# binatang : binatang
# dijumpainya : jumpa
# komen : komen
# muak : muak
# sumber : sumber
# ogah : ogah
# pengen : ken
# ketawa : ketawa
# pemahamannya : paham
# dangkal : dangkal
# tandanya : tanda
# dijajah : jajah
# dibentuk : bentuk
# berjalan : jalan
# bernaman : bernaman
# ruwetnesia : ruwetnesia
# kayaknya : kayak
# dipikirnya : pikir
# nasi : nasi
# padang : padang
# dicampur : campur
# coklat : coklat
# strobery : strobery
# kebayang : bayang
# ancuran : ancuran
# dalih : dalih
# sexsual : sexsual
# dipidana : pidana
# idiot : idiot
# mah : mah
# sekolahnya : sekolah
# lulusan : lulus
# slb : slb
# otoritas : otoritas
# brti : brti
# cabul : cabul
# kemakan : makan
# omongan : omong
# sndri : sndri
# teriak : teriak
# nmnya : nmnya
# krinten : krinten
# vz : vz
# konsep : konsep
# kristen : kristen
# hancurkan : hancur
# langsung : langsung
# membela : bela
# kemaksiatan : maksiat
# sampean : sampean
# mbk : mbk
# digilir : gilir
# menjual : jual
# kehormatanx : kehormatanx
# cegah : cegah
# makax : makax
# rubah : rubah
# berjilbab : jilbab
# tuli : tuli
# cek : cek
# deh : deh
# prosen : prosen
# dikota : kota
# kemaluannya : malu
# tersegel : segel
# menjamah : jamah
# ihlas : ihlas
# dijamah : jamah
# ato : ato
# terpaksa : paksa
# dhohirnya : dhohirnya
# ngeyel : ngeyel
# dilarang : larang
# gausah : gausah
# ngeles : ngeles
# kesana : kesana
# kemari : kemari
# cucu : cucu
# pki : pki
# ygai : ygai
# menghancurkan : hancur
# moril : moril
# fikirkan : fikirkan
# perlakukan : laku
# koreksi : koreksi
# beradap : adap
# merevisi : revisi
# untung : untung
# lobang : lobang
# hidung : hidung
# pantat : pantat
# lumayan : lumayan
# bayar : bayar
# hutang : hutang
# gawat : gawat
# daruat : daruat
# karenahukum : karenahukum
# makarim : makarim
# ke pada : ke pada
# dianggap : anggap
# ingatkan : ingat
# memanusiakan : manusia
# beternak : ternak
# pelacur : lacur
# slesai : slesai
# sekolah : sekolah
# amburadul : amburadul
# permendikbudristekdikti : permendikbudristekdikti
# membolehkan : boleh
# tujuan : tuju
# melawan : lawan
# syari : syar
# at : at
# megang : megang
# tangan : tangan
# pundak : pundak
# mahasiswinya : mahasiswi
# ijin : ijin
# genit : genit
# syg : syg
# love : love
# you : you
# berdalih : dalih
# memegang : pegang
# bergurau : gurau
# memfoto : foto
# gemeteran : gemeteran
# beraksi : aksi
# pidana : pidana
# nakarim : nakarim
# dibikin : bikin
# survey : survey
# korbannya : korban
# rugi : rugi
# peraturannya : atur
# mhn : mhn
# disimak : simak
# komentar : komentar
# matang : matang
# hormat : hormat
# melancarkan : lancar
# usul : usul
# klu : klu
# blh : blh
# ujian : uji
# smester : smester
# uang : uang
# dmester : dmester
# blhkan : blhkan
# ttap : ttap
# mask : mask
# swasta : swasta
# situasi : situasi
# kopit : kopit
# pemulihan : pulih
# ekonomi : ekonomi
# lg : lg
# cari : cari
# mkn : mkn
# cm : cm
# mksh : mksh
# thn : thn
# byr : byr
# stengah : stengah
# seluru : seluru
# pilih : pilih
# blhlkan : blhlkan
# smseter : smseter
# mksih : mksih
# menyedihkan : sedih
# pendidik : didik
# terdidik : didik
# menyerap : serap
# disetujui : tuju
# tameng : tameng
# kontroversi : kontroversi
# negativ : negativ
# iyalah : iya
# lari : lari
# wani : wani
# piro : piro
# prostitusi : prostitusi
# kucing : kucing
# kawin : kawin
# mna : mna
# iman : iman
# ahklak : ahklak
# tekan : tekan
# becus : becus
# ngajar : ngajar
# ngedidik : ngedidik
# melanggar : langgar
# pecat : pecat
# kasian : kasi
# disen : sen
# oknum : oknum
# babad : babad
# musnahkan : musnah
# musyawarah : musyawarah
# nu : nu
# muhamdiah : muhamdiah
# deal : deal
# aj : aj
# comot : comot
# efek : efek
# pandai : pandai
# terapkan : terap
# pemaksaan : paksa
# alias : alias
# pemerkosaan : perkosa
# benarkan : benar
# terkecuali : kecuali
# senang : senang
# permennya : permen
# kaedah : kaedah
# kesopanan : sopan
# pertontonkan : tonton
# disamain : disamain
# apps : apps
# install : install
# smartphone : smartphone
# hihihi : hihihi
# riil : riil
# konotasi : konotasi
# menghalalkan : halal
# tragis : tragis
# ojk : ojk
# pinjol : pinjol
# pdhl : pdhl
# praktek : praktek
# bunga : bunga
# tinghi : tinghi
# dirugikan : rugi
# mikirin : mikirin
# lampau : lampau
# pikirin : pikirin
# tubuhmu : tubuh
# bungkus : bungkus
# lollipop : lollipop
# tergiur : giur
# bentuknya : bentuk
# mahaciwi : mahaciwi
# semangat : semangat
# hargai : harga
# mslhx : mslhx
# adh : adh
# legalx : legalx
# diperintahkan : perintah
# beliau : beliau
# tanggung : tanggung
# pendidiknya : didik
# tunggangi : tunggang
# ulama : ulama
# kadron : kadron
# memahami : paham
# lgbt : lgbt
# dipisah : pisah
# kelas : kelas
# khusus : khusus
# gerbong : gerbong
# kereta : kereta
# ngenyel : ngenyel
# mengarah : arah
# hadeh : hadeh
# sayangi : sayang
# ribet : ribet
# ngomongin : ngomongin
# disangkut : sangkut
# pautkan : paut
# ruang : ruang
# lingkup : lingkup
# wanitanya : wanita
# diem : diem
# terbukti : bukti
# disetubuhin : disetubuhin
# berat : berat
# walau pun : walau pun
# ngasi : ngasi
# brng : brng
# menjaga : jaga
# jakar : jakar
# guru : guru
# polisi : polisi
# seumur : umur
# hidup : hidup
# dajal : dajal
# munkin : munkin
# sukak : sukak
# bacot : bacot
# mas : mas
# judulnya : judul
# tlg : tlg
# dibaca : baca
# teliti : teliti
# pendapat : dapat
# sadar : sadar
# tekanan : tekan
# perbutan : perbutan
# membutuhkan : butuh
# {'ruu': 'ruu', 'perlindungan': 'lindung', 'korban': 'korban', 'kekerasan': 'keras', 'seksual': 'seksual', 'hrs': 'hrs', 'legalkan': 'legal', 'byk': 'byk', 'mnjdi': 'mnjdi', 'tersangka': 'sangka', 'sekelas': 'kelas', 'goto': 'goto', 'kelolosan': 'lolos', 'rempahan': 'rempah', 'rengginang': 'rengginang', 'kong': 'kong', 'wan': 'wan', 'mendikbud': 'mendikbud', 'tdk': 'tdk', 'faham': 'faham', 'adab': 'adab', 'bangsa': 'bangsa', 'timur': 'timur', 'kirain': 'kirain', 'digugat': 'gugat', 'gara': 'gara', 'data': 'data', 'mining': 'mining', 'narasi': 'narasi', 'suka': 'suka', 'bebas': 'bebas', 'kawaall': 'kawaall', 'terooss': 'terooss', 'meta': 'meta', 'jga': 'jga', 'gk': 'gk', 'kena': 'kena', 'go': 'go', 'to': 'to', 'permasalahan': 'masalah', 'udah': 'udah', 'lamaa': 'lamaa', 'bgt': 'bgt', 'jd': 'jd', 'polemik': 'polemik', 'speak': 'speak', 'up': 'up', 'medsos': 'medsos', 'jg': 'jg', 'stigma': 'stigma', 'dn': 'dn', 'disalahkan': 'salah', 'gak': 'gak', 'ngerti': 'ngerti', 'knp': 'knp', 'nyerang': 'nyerang', 'seiring': 'iring', 'berjalannya': 'jalan', 'kasusnya': 'kasus', 'bertambah': 'tambah', 'menerus': 'terus', 'tp': 'tp', 'pks': 'pks', 'bhkn': 'bhkn', 'permendikbud': 'permendikbud', 'ditentang': 'tentang', 'sy': 'sy', 'betapa': 'betapa', 'ndak': 'ndak', 'inginnya': 'ingin', 'melindungi': 'lindung', 'hati': 'hati', 'aq': 'aq', 'tim': 'tim', 'niat': 'niat', 'ngehapus': 'ngehapus', 'comment': 'comment', 'yak': 'yak', 'goped': 'goped', 'oke': 'oke', 'kontranya': 'kontra', 'gajelas': 'gajelas', 'galiat': 'galiat', 'urgensi': 'urgensi', 'hadehh': 'hadehh', 'semoga': 'moga', 'terbaik': 'baik', 'indonesia': 'indonesia', 'tercintaku': 'cinta', 'huhuhuhuu': 'huhuhuhuu', 'sehat': 'sehat', 'mba': 'mba', 'cantiku': 'cantiku', 'partai': 'partai', 'getol': 'getol', 'menolak': 'tolak', 'gemes': 'gemes', 'bngt': 'bngt', 'gw': 'gw', 'bsa': 'bsa', 'melenyapkan': 'lenyap', 'predator': 'predator', 'kampus': 'kampus', 'yes': 'yes', 'melegalkan': 'legal', 'sex': 'sex', 'peraturnnya': 'peraturnnya', 'untk': 'untk', 'perkosa': 'perkosa', 'klw': 'klw', 'ga': 'ga', 'masalh': 'masalh', 'hadeeh': 'hadeeh', 'berkerudung': 'kerudung', 'gini': 'gin', 'lbh': 'lbh', 'bahas': 'bahas', 'hersubeno': 'hersubeno', 'arif': 'arif', 'pemerkosa': 'perkosa', 'org': 'org', 'berkuasa': 'kuasa', 'sllu': 'sllu', 'membawa': 'bawa', 'nama': 'nama', 'dr': 'dr', 'subtansi': 'subtansi', 'kritikan': 'kritik', 'tsb': 'tsb', 'dosen': 'dosen', 'belagu': 'belagu', 'tai': 'tai', 'kebelaguannya': 'kebelaguannya', 'nolong': 'nolong', 'kecakapan': 'cakap', 'mahasiswanya': 'mahasiswa', 'lapangan': 'lapang', 'kerja': 'kerja', 'wajah': 'wajah', 'senyum': 'senyum', 'cantik': 'cantik', 'kakak': 'kakak', 'ganti': 'ganti', 'predatornya': 'predator', 'muslim': 'muslim', 'konservatif': 'konservatif', 'setuju': 'tuju', 'peraturan': 'atur', 'syarat': 'syarat', 'dihapus': 'hapus', 'frase': 'frase', 'persetujuan': 'tuju', 'contoh': 'contoh', 'pasal': 'pasal', 'membuka': 'buka', 'pakaian': 'pakai', 'mahasiswa': 'mahasiswa', 'mahasiswi': 'mahasiswi', 'iyahh': 'iyahh', 'aoa': 'aoa', 'silahkan': 'silah', 'dibolehkan': 'boleh', 'legal': 'legal', 'bahaya': 'bahaya', 'bersetubuh': 'tubuh', 'berzinah': 'berzinah', 'tampilkan': 'tampil', 'ambigu': 'ambigu', 'arti': 'arti', 'dilegalkan': 'legal', 'dampak': 'dampak', 'burukk': 'burukk', 'infeksi': 'infeksi', 'menular': 'tular', 'merajelala': 'merajelala', 'hiv': 'hiv', 'anak': 'anak', 'belajar': 'ajar', 'mlh': 'mlh', 'merintih': 'rintih', 'melahirkan': 'lahir', 'aborsi': 'aborsi', 'keluarga': 'keluarga', 'terjerat': 'jerat', 'maksud': 'maksud', 'merusak': 'rusak', 'jadikan': 'jadi', 'pedoman': 'pedoman', 'manusia': 'manusia', 'beradab': 'adab', 'beragama': 'agama', 'minoritas': 'minoritas', 'nonton': 'nonton', 'anisya': 'anisya', 'azni': 'azni', 'muaantaab': 'muaantaab', 'skrng': 'skrng', 'maen': 'maen', 'aamaan': 'aamaan', 'sis': 'sis', 'slama': 'slama', 'lw': 'lw', 'nga': 'nga', 'ngas': 'ngas', 'hotel': 'hotel', 'gas': 'gas', 'bwahahaahaha': 'bwahahaahaha', 'baca': ...
# ------------------------

# %%
df['STEMMER'] = df['STOP_REMOVAL'].apply(get_stemmed_term)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif
# 5                                    kawaall terooss  negatif
# 6                 meta juga gk kena masa go to kena   negatif
# 7  permasalahan kekerasan seksual udah lamaa bgt ...  negatif
# 8  tim narasi niat banget ngehapus  comment saya ...  negatif
# 9                                       goped bagus   positif
#
#                                         TOKENIZATION  \
# 0  [seharusnya, ruu, tentang, perlindungan, korba...
# 1  [bahkan, sekelas, goto, aja, masih, kelolosan,...
# 2   [mendikbud, yg, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                    [narasi, suka, sama, yg, bebas]
# 5                                 [kawaall, terooss]
# 6          [meta, jga, gk, kena, masa, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]
#
#                                         STOP_REMOVAL  \
# 0  [ruu, perlindungan, korban, kekerasan, seksual...
# 1  [sekelas, goto, kelolosan, rempahan, rengginan...
# 2       [mendikbud, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                              [narasi, suka, bebas]
# 5                                 [kawaall, terooss]
# 6                [meta, jga, gk, kena, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]
#
#                                              STEMMER
# 0  [ruu, lindung, korban, keras, seksual, hrs, le...
# 1  [kelas, goto, lolos, rempah, rengginang, kong,...
# 2       [mendikbud, tdk, faham, adab, bangsa, timur]
# 3          [kirain, gugat, gara, gara, data, mining]
# 4                              [narasi, suka, bebas]
# 5                                 [kawaall, terooss]
# 6                [meta, jga, gk, kena, go, to, kena]
# 7  [masalah, keras, seksual, udah, lamaa, bgt, jd...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]

# %%
def fit_stemmer(text):
     text = np.array(text)
     text = ' '.join(text)
     return text

df['Komentar_Final'] = df['STEMMER'].apply(lambda x: fit_stemmer(x))
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  seharusnya ruu tentang perlindungan korban kek...  negatif
# 1  bahkan sekelas goto aja masih kelolosan apalag...  negatif
# 2           mendikbud yg tdk faham adab bangsa timur  negatif
# 3              kirain digugat gara gara data mining   negatif
# 4                          narasi suka sama yg bebas  negatif
# 5                                    kawaall terooss  negatif
# 6                 meta juga gk kena masa go to kena   negatif
# 7  permasalahan kekerasan seksual udah lamaa bgt ...  negatif
# 8  tim narasi niat banget ngehapus  comment saya ...  negatif
# 9                                       goped bagus   positif
#
#                                         TOKENIZATION  \
# 0  [seharusnya, ruu, tentang, perlindungan, korba...
# 1  [bahkan, sekelas, goto, aja, masih, kelolosan,...
# 2   [mendikbud, yg, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                    [narasi, suka, sama, yg, bebas]
# 5                                 [kawaall, terooss]
# 6          [meta, jga, gk, kena, masa, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]
#
#                                         STOP_REMOVAL  \
# 0  [ruu, perlindungan, korban, kekerasan, seksual...
# 1  [sekelas, goto, kelolosan, rempahan, rengginan...
# 2       [mendikbud, tdk, faham, adab, bangsa, timur]
# 3        [kirain, digugat, gara, gara, data, mining]
# 4                              [narasi, suka, bebas]
# 5                                 [kawaall, terooss]
# 6                [meta, jga, gk, kena, go, to, kena]
# 7  [permasalahan, kekerasan, seksual, udah, lamaa...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]
#
#                                              STEMMER  \
# 0  [ruu, lindung, korban, keras, seksual, hrs, le...
# 1  [kelas, goto, lolos, rempah, rengginang, kong,...
# 2       [mendikbud, tdk, faham, adab, bangsa, timur]
# 3          [kirain, gugat, gara, gara, data, mining]
# 4                              [narasi, suka, bebas]
# 5                                 [kawaall, terooss]
# 6                [meta, jga, gk, kena, go, to, kena]
# 7  [masalah, keras, seksual, udah, lamaa, bgt, jd...
# 8  [tim, narasi, niat, bgt, ngehapus, comment, aq...
# 9                                       [goped, oke]
#
#                                       Komentar_Final
# 0  ruu lindung korban keras seksual hrs legal byk...
# 1        kelas goto lolos rempah rengginang kong wan
# 2              mendikbud tdk faham adab bangsa timur
# 3                 kirain gugat gara gara data mining
# 4                                  narasi suka bebas
# 5                                    kawaall terooss
# 6                        meta jga gk kena go to kena
# 7  masalah keras seksual udah lamaa bgt jd polemi...
# 8        tim narasi niat bgt ngehapus comment aq yak
# 9                                          goped oke

# %%
df.to_csv(r'PreProcessing dua.csv')

# %%
import pickle
pickle.dump(stopword,
            open('stopword dua.pkl', 'wb'),
            protocol=4)

# %%
import pickle
pickle.dump(kamus_katabaku,
            open('kamus_katabaku dua.pkl', 'wb'),
            protocol=4)
