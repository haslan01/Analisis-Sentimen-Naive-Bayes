# %%
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: pandas==1.3.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (1.23.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas==1.3.2) (2022.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.16.0)

# %%
# !pip install swifter
# !pip install Sastrawi
# Out:
# Requirement already satisfied: swifter in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.3.4)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (2022.8.1)
# Requirement already satisfied: psutil>=5.6.6 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (5.9.1)
# Requirement already satisfied: bleach>=3.1.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (5.0.1)
# Requirement already satisfied: pandas>=1.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (1.3.2)
# Requirement already satisfied: tqdm>=4.33.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (4.64.0)
# Requirement already satisfied: parso>0.4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (0.8.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (8.0.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from swifter) (2.1.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\asus\.conda\envs\aslan\lib\site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (21.3)
# Requirement already satisfied: partd>=0.3.10 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.3.0)
# Requirement already satisfied: toolz>=0.8.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.0)
# Requirement already satisfied: fsspec>=0.6.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (2022.7.1)
# Requirement already satisfied: numpy>=1.18 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from dask[dataframe]>=2.10.0->swifter) (1.23.2)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (5.3.0)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (8.4.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (4.0.2)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (3.0.2)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipywidgets>=7.0.0->swifter) (6.15.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from pandas>=1.0.0->swifter) (2022.2.1)
# Requirement already satisfied: colorama in c:\users\asus\.conda\envs\aslan\lib\site-packages (from tqdm>=4.33.0->swifter) (0.4.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.1)
# Requirement already satisfied: debugpy>=1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.6.3)
# Requirement already satisfied: nest-asyncio in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (1.5.5)
# Requirement already satisfied: tornado>=6.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.13.0)
# Requirement already satisfied: stack-data in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.4.0)
# Requirement already satisfied: backcall in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (3.0.30)
# Requirement already satisfied: jedi>=0.16 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (63.4.1)
# Requirement already satisfied: decorator in c:\users\asus\.conda\envs\aslan\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from packaging>=20.0->dask[dataframe]>=2.10.0->swifter) (3.0.9)
# Requirement already satisfied: locket in c:\users\asus\.conda\envs\aslan\lib\site-packages (from partd>=0.3.10->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: entrypoints in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: wcwidth in c:\users\asus\.conda\envs\aslan\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: executing in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.10.0)
# Requirement already satisfied: pure-eval in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\asus\.conda\envs\aslan\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.0.8)
# Requirement already satisfied: pywin32>=1.0 in c:\users\asus\.conda\envs\aslan\lib\site-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (303)
# Requirement already satisfied: Sastrawi in c:\users\asus\.conda\envs\aslan\lib\site-packages (1.0.1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
import string
import re
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import nltk
import csv
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
import pandas as pd
df = pd.read_csv(r'matanajwa1.csv')
df.head()
# Out:
#    Unnamed: 0                                           Komentar    Label
# 0           1  Jebak matta dosen dengan paha mulus... Pasti k...  negatif
# 1           2  Makanyaa gak usah kuliah,mending kayak gua"men...  negatif
# 2           3  As Salam, sebagian besar nyaris lebih dari 70%...  negatif
# 3           4  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4           5  Terkadang saya heran, ditempat menuntut ilmu t...  positif

# %%
del df['Unnamed: 0']
df.head()
# Out:
#                                             Komentar    Label
# 0  Jebak matta dosen dengan paha mulus... Pasti k...  negatif
# 1  Makanyaa gak usah kuliah,mending kayak gua"men...  negatif
# 2  As Salam, sebagian besar nyaris lebih dari 70%...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  Terkadang saya heran, ditempat menuntut ilmu t...  positif

# %%
#cleaning Text
def remove_punct(text):
    text = re.sub(r'[^a-zA-Z0-9]', ' ', str(text))
    text = re.sub(r"\b[a-zA-Z]\b", "", text)
    text = re.sub(r'\b\w(1,2)\b', '', text)
    text = re.sub(r'\s\s+', ' ', text)
    text = re.sub(r"\d+", "", text)
    return text
df['Komentar'] = df['Komentar'].apply(remove_punct)

# %%
# ------ Case Folding --------
# gunakan fungsi Series.str.lower() pada Pandas
df['Komentar'] = df['Komentar'].str.lower()
df.head()
# Out:
#                                             Komentar    Label
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif

# %%
def replace_repeat_character(text):
    # Pattern to look for three or more repetitions of any character, including newlines (contoh goool -> gol).
    pattern = re.compile(r"(.)\1{1,}", re.DOTALL)
    return pattern.sub(r"\1\1", text)

df['Komentar'] = df['Komentar'].apply(replace_repeat_character) 
df.head()
# Out:
#                                             Komentar    Label
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif

# %%
from nltk.tokenize import word_tokenize

def tokenize(text):
    return nltk.word_tokenize(text)
    
df['TOKENIZATION'] = df['Komentar'].apply(tokenize)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif
# 5                   bebas sekarang oey wkk hmm hikss  positif
# 6                              sukses terus mba njwa  positif
# 7  update aja ni dosennya divonis bebas sama peng...  positif
# 8                         ketika iblis cosplay dosen  negatif
# 9                         gua tonjok kalau jadi dia   negatif
#
#                                         TOKENIZATION
# 0  [jebak, matta, dosen, dengan, paha, mulus, pas...
# 1  [makanyaa, gak, usah, kuliah, mending, kayak, ...
# 2  [as, salam, sebagian, besar, nyaris, lebih, da...
# 3  [orang, orang, seperti, ini, ga, ush, dipanggi...
# 4  [terkadang, saya, heran, ditempat, menuntut, i...
# 5            [bebas, sekarang, oey, wkk, hmm, hikss]
# 6                         [sukses, terus, mba, njwa]
# 7  [update, aja, ni, dosennya, divonis, bebas, sa...
# 8                    [ketika, iblis, cosplay, dosen]
# 9                    [gua, tonjok, kalau, jadi, dia]

# %%
katabaku = csv.reader(
	open(r"kata_baku.csv"), delimiter=";") # ambil file csv kata baku menjadi array

kamus_katabaku = {} # empty dictionary untuk kamus kata baku
try:
    for row in katabaku : # membuat kamus kata baku dengan input kata tidak baku dan output kata bakunya
        kamus_katabaku[row[0]] = row[1]
except:
    pass

# %%
print(kamus_katabaku)
# Out:
# {'abjad': 'abjat', 'akta': 'akte', 'aktif': 'aktiv', 'aktivitas': 'aktifitas', 'amendemen': 'amandemen', 'andal': 'handal', 'analisis': 'analisa', 'antre': 'antri', 'asas': 'azas', 'apak': 'apek', 'apotek': 'apotik', 'aritmetika': 'aritmatika', 'atlet': 'atlit', 'atmosfer': 'atmosfir', 'cabai': 'cabay', 'camilan': 'cemilan', 'cendekia': 'cendikia', 'cenderamata': 'cinderamata', 'detail': 'detil', 'definisi': 'difinisi', 'diagnosis': 'diagnosa', 'embus': 'hembus', 'ekstra': 'extra', 'ekstrem': 'ekstrim', 'esai': 'esei', 'februari': 'febuari', 'fondasi': 'pondasi', 'formal': 'formil', 'frasa': 'frase', 'frekuensi': 'frekwensi', 'gizi': 'gisi', 'hafal': 'hapal', 'hakikat': 'hakekat', 'hipotesis': 'hipotesa', 'hierarki': 'hirarkhi', 'ijazah': 'ijasah', 'izin': 'ijin', 'imbau': 'himbau', 'isap': 'hisap', 'istri': 'isteri', 'jadwal': 'jadual', 'jenazah': 'jenasah', 'jenderal': 'jendral', 'justru': 'justeru', 'kafetaria': 'kafeteria', 'kalender': 'kalendar', 'karier': 'karir', 'katapel': 'ketapel', 'kategori': 'katagori', 'kedaluwarsa': 'kadaluwarsa', 'kendaraan': 'kenderaan', 'komplet': 'komplit', 'konferensi': 'konperensi', 'kongres': 'konggres', 'konkret': 'kongkret', 'kreativitas': 'kreatifitas', 'kualifikasi': 'kwalifikasi', 'kualitatif': 'kwalitatif', 'kuantitatif': 'kwantitatif', 'kualitas': 'kwalitet', 'kuitansi': 'kwitansi', 'lubang': 'lobang', 'makhluk': 'mahkluk', 'manajemen': 'managemen', 'masjid': 'mesjid', 'merek': 'merk', 'meterai': 'meterei', 'metode': 'metoda', 'miliar': 'milyar', 'misi': 'missi', 'modern': 'moderen', 'mubazir': 'mubadir', 'mulia': 'mulya', 'mungkir': 'pungkir', 'napas': 'nafas', 'narasumber': 'nara', 'nasihat': 'nasehat', 'objek': 'obyek', 'objektif': 'obyektif', 'paham': 'faham', 'parlemen': 'parlamen', 'paspor': 'pasport', 'peduli': 'perduli', 'pikir': 'fikir', 'praktik': 'praktek', 'provinsi': 'propinsi', 'rabu': 'rebo', 'risiko': 'resiko', 'sah': 'syah', 'sanggama': 'senggama', 'sekadar': 'sekedar', 'sekuler': 'sekular', 'seluler': 'selular', 'semadi': 'semedi', 'sentral': 'central', 'seprai': 'seprei', 'silakan': 'silahkan', 'sirkuler': 'sirkular', 'sistem': 'sistim', 'saksama': 'seksama', 'subjek': 'subyek', 'subjektif': 'subyektif', 'surga': 'syurga', 'survei': 'survey', 'tampak': 'nampak', 'teladan': 'tauladan', 'teknik': 'tekhnik', 'teknologi': 'tekhnologi', 'telanjur': 'terlanjur', 'telantar': 'terlantar', 'terampil': 'trampil', 'vila': 'villa', 'wakaf': 'waqaf', 'wujud': 'ujud', 'yudikatif': 'yudikatip', 'ubah': 'rubah', 'zaman': 'jaman', 'alpa': 'alfa', 'baik': 'bae', 'balas': 'bales', 'belum': 'blm', 'capai': 'capek', 'dalam': 'dalem', 'dapat': 'dpt', 'disahkan': 'disyahkan', 'hilang': 'ilang', 'ikhlas': 'ihlas', 'ingat': 'inget', 'itikad': 'itikat', 'jumat': "jum'at", 'karena': 'krn', 'kasier': 'kasir', 'karisma': 'kharisma', 'kepada': 'ke pada', 'kerap': 'kerab', 'kaidah': 'kaedah', 'khatulistiwa': 'katulistiwa', 'khawatir': 'kuatir', 'kuadrat': 'kwadrat', 'kuantum': 'kwantum', 'kuis': 'kuiz', 'lazim': 'lajim', 'losin': 'lusin', 'maaf': 'apologize', 'macam': 'macem', 'malas': 'males', 'manfaat': 'manpaat', 'nomor': 'nmr', 'materai': 'matere', 'mengesampingkan': 'mengenyampingkan', 'mengubah': 'merubah', 'padat': 'padet', 'pelanggan': 'langganan', 'pensil': 'pinsil', 'pertanggung jawaban': 'pertanggungjawab', 'pihak': 'fihak', 'populer': 'popular', 'rapat': 'rapet', 'sampai': 'sampek', 'selesai': 'selese', 'seperti': 'kayak', 'aksi': 'action', 'anarki': 'anarkhi', 'anggota': 'anggauta', 'biosfer': 'biosfir', 'cepat': 'cpt', 'debit': 'debet', 'devaluasi': 'defaluasi', 'doa': "do'a", 'diam': 'diem', 'daftar': 'daptar', 'dipersilakan': 'dipersilahkan', 'ekuivalen': 'ekwivalen', 'elite': 'elit', 'familier': 'familiar', 'glucose': 'glukosa', 'grup': 'group', 'genting': 'genteng', 'gubuk': 'gubug', 'hectare': 'hektar', 'heterogen': 'hetrogen', 'hipotek': 'hipotik', 'hanya': 'cuma', 'habis': 'abis', 'ideologi': 'idiologi', 'interogasi': 'interograsi', 'introspeksi': 'interospeksi', 'interupsi ...

# %%
def normalized_term(text):
    return [kamus_katabaku[term] if term in kamus_katabaku else term for term in text]
df['TOKENIZATION'] = df['TOKENIZATION'].apply(normalized_term) 
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif
# 5                   bebas sekarang oey wkk hmm hikss  positif
# 6                              sukses terus mba njwa  positif
# 7  update aja ni dosennya divonis bebas sama peng...  positif
# 8                         ketika iblis cosplay dosen  negatif
# 9                         gua tonjok kalau jadi dia   negatif
#
#                                         TOKENIZATION
# 0  [jebak, matta, dosen, dgn, paha, mulus, pasti,...
# 1  [makanyaa, gak, usah, kuliah, mending, kayak, ...
# 2  [as, salam, sebagian, besar, nyaris, lbh, dari...
# 3  [org, org, kayak, ini, ga, ush, dipanggil, bel...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5            [bebas, sekarang, oey, wkk, hmm, hikss]
# 6                         [sukses, terus, mba, njwa]
# 7  [update, aja, ni, dosennya, divonis, bebas, sa...
# 8                    [ketika, iblis, cosplay, dosen]
# 9                      [goa, tonjok, klw, jadi, dia]

# %%
stopword =nltk.corpus.stopwords.words('indonesian')
stopword.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                 'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                 'krn', 'nya', 'nih', 'sih', 
                 'si', 'tau', 'tuh', 'utk', 'ya','sdh',
                 'aja', 'n', 't', 'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                 '&amp', 'yah', 'njir', 'wkwk', 'haha', 'hehe', 'rs', 'yaa',
                 'nii', 'bin', 'lahh', 'hmm', 'lieur', 'njarem', 'kale',
                 'hd', 'an', 'ob', 'bro', 'ud', 'iyaa', 'guys', 'doang',
                 'doank', 'eh', 'kek', 'or', 'kah', 'eso', 'tuh', 'dh', 'dnk',
                 'mh', 'ja', 'tu', 'anu', 'ni', 'ku', 'blz', 'gy', 'skg', 'eeh',
                 'pas','tar','bc','x','dong','d'])

# %%
word_list=['enggak','tidak','jangan','belum']
stopword = [word for word in stopword if word not in word_list] #make a copy of the word_list

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stopword]
    
df['STOP_REMOVAL'] = df['TOKENIZATION'].apply(remove_stopwords)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif
# 5                   bebas sekarang oey wkk hmm hikss  positif
# 6                              sukses terus mba njwa  positif
# 7  update aja ni dosennya divonis bebas sama peng...  positif
# 8                         ketika iblis cosplay dosen  negatif
# 9                         gua tonjok kalau jadi dia   negatif
#
#                                         TOKENIZATION  \
# 0  [jebak, matta, dosen, dgn, paha, mulus, pasti,...
# 1  [makanyaa, gak, usah, kuliah, mending, kayak, ...
# 2  [as, salam, sebagian, besar, nyaris, lbh, dari...
# 3  [org, org, kayak, ini, ga, ush, dipanggil, bel...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5            [bebas, sekarang, oey, wkk, hmm, hikss]
# 6                         [sukses, terus, mba, njwa]
# 7  [update, aja, ni, dosennya, divonis, bebas, sa...
# 8                    [ketika, iblis, cosplay, dosen]
# 9                      [goa, tonjok, klw, jadi, dia]
#
#                                         STOP_REMOVAL
# 0  [jebak, matta, dosen, paha, mulus, ketahuan, d...
# 1  [makanyaa, gak, kuliah, mending, kayak, goa, m...
# 2  [as, salam, lbh, media, pertunjukan, film, men...
# 3  [org, org, kayak, ga, ush, dipanggil, beliau, ...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5                           [bebas, oey, wkk, hikss]
# 6                                [sukses, mba, njwa]
# 7     [update, dosennya, divonis, bebas, pengadilan]
# 8                            [iblis, cosplay, dosen]
# 9                                 [goa, tonjok, klw]

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()
import swifter

# implementasi pada data kita

# stemmed
def stemmed_wrapper(text):
    return stemmer.stem(text)

text_dict = {}

for document in df['STOP_REMOVAL']:
    for text in document:
        if text not in text_dict:
            text_dict[text] = ' '
            
print(len(text_dict))
print("------------------------")

for text in text_dict:
    text_dict[text] = stemmed_wrapper(text)
    print(text,":" ,text_dict[text])
    
print(text_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [text_dict[text] for text in document]
# Out:
# 1957
# ------------------------
# jebak : jebak
# matta : matta
# dosen : dosen
# paha : paha
# mulus : mulus
# ketahuan : tahu
# predator : predator
# makanyaa : makanyaa
# gak : gak
# kuliah : kuliah
# mending : mending
# kayak : kayak
# goa : goa
# mengangkat : angkat
# senjata : senjata
# dn : dn
# menjaga : jaga
# persatuan : satu
# bangsa : bangsa
# negara : negara
# mikir : mikir
# klw : klw
# itwuu : itwuu
# membuang : buang
# buang : buang
# bayangkan : bayang
# lu : lu
# lihat : lihat
# sii : sii
# pemalas : malas
# contoh : contoh
# abang : abang
# cuman : cuman
# ketemu : ketemu
# susah : susah
# payah : payah
# aoa : aoa
# ndak : ndak
# perduli : duli
# kasian : kasi
# capek : capek
# kripsi : kripsi
# haduhh : haduhh
# seandainyaa : seandainyaa
# universiti : universiti
# asrama : asrama
# militer : militer
# auti : auti
# tijak : tijak
# twuu : twuu
# manusia : manusia
# ad : ad
# ampun : ampun
# udah : udah
# permainkan : main
# lbh : lbh
# bae : bae
# pilih : pilih
# kuliahan : kuliah
# sejenis : jenis
# kampus : kampus
# kedinasan : dinas
# disiplin : disiplin
# paksa : paksa
# males : males
# berbuat : buat
# pemimpin : pimpin
# nyaa : nyaa
# komandan : komandan
# ttp : ttp
# tendang : tendang
# ditampar : tampar
# menyuruh : suruh
# bermental : mental
# org : org
# bodoh : bodoh
# menampar : tampar
# jga : jga
# mengendalikan : kendali
# psikologi : psikologi
# bsa : bsa
# mnjdi : mnjdi
# pemberani : berani
# melawan : lawan
# saran : saran
# aq : aq
# msk : msk
# tni : tni
# polri : polri
# pilihlahh : pilihlahh
# akpol : akpol
# akmil : akmil
# tamat : tamat
# merasakan : rasa
# pemuda : pemuda
# pemudi : pemudi
# terbaik : baik
# as : as
# salam : salam
# media : media
# pertunjukan : tunjuk
# film : film
# menceritakan : cerita
# percintaan : cinta
# berfikir : berfikir
# religious : religious
# ketakwaan : takwa
# berpuasa : puasa
# senen : senen
# kamis : kamis
# pintu : pintu
# gerbangnya : gerbang
# kasis : kas
# menjelek : jelek
# jelekkan : jelek
# aa : aa
# gym : gym
# nastiar : nastiar
# memiliki : milik
# isteri : isteri
# suku : suku
# memilih : pilih
# tenaga : tenaga
# pendidik : didik
# berpengalaman : alam
# dalem : dalem
# berpacaran : pacar
# belajar : ajar
# berguru : guru
# guru : guru
# salah : salah
# fokus : fokus
# ke pada : ke pada
# menyalahkan : salah
# peri laku : peri laku
# burukk : burukk
# don : don
# juan : juan
# publik : publik
# figur : figur
# menyambung : sambung
# lagu : lagu
# baju : baju
# alhamdulilallah : alhamdulilallah
# untk : untk
# pake : pake
# hr : hr
# raya : raya
# fitri : fitri
# pacar : pacar
# punyap : punyap
# un : un
# puasa : puasa
# syawalnya : syawal
# pamerin : pamerin
# punyapun : punya
# kamisnya : kamis
# selamat : selamat
# menerapkandisiplin : menerapkandisiplin
# merdeka : merdeka
# liberty : liberty
# wassalamu : wassalamu
# alaikum : alaikum
# wr : wr
# wb : wb
# ga : ga
# ush : ush
# dipanggil : panggil
# beliau : beliau
# sex : sex
# dihormati : hormat
# terkadang : terkadang
# heran : heran
# ditempat : tempat
# menuntut : tuntut
# ilmu : ilmu
# pelecehan : leceh
# negri : negri
# kaya : kaya
# adat : adat
# istiadat : istiadat
# alamnya : alam
# apologize : apologize
# sopan : sopan
# kenyataan : nyata
# bebas : bebas
# oey : oey
# wkk : wkk
# hikss : hikss
# sukses : sukses
# mba : mba
# njwa : njwa
# update : update
# dosennya : dosen
# divonis : vonis
# pengadilan : adil
# iblis : iblis
# cosplay : cosplay
# tonjok : tonjok
# sy : sy
# mhn : mhn
# nazwa : nazwa
# supir : supir
# perusahaan : usaha
# nanya : nanya
# emng : emng
# upah : upah
# khusus : khusus
# ntb : ntb
# kabupaten : kabupaten
# dompu : dompu
# karna : karna
# byk : byk
# karyawan : karyawan
# mengeluh : keluh
# tanggapi : tanggap
# serius : serius
# assalamualaikum : assalamualaikum
# swasta : swasta
# emang : emang
# brapa : brapa
# gaji : gaji
# nusa : nusa
# tenggara : tenggara
# barat : barat
# tanggapin : tanggapin
# gausah : gausah
# asstaghfirullah : asstaghfirullah
# dosenn : dosenn
# kekerasan : keras
# kadang : kadang
# faktor : faktor
# munkin : munkin
# sja : sja
# norma : norma
# sosial : sosial
# mahasiswa : mahasiswa
# interaksi : interaksi
# berpenampilan : tampil
# transparan : transparan
# berpakaian : pakai
# sikap : sikap
# hrs : hrs
# obyektif : obyektif
# menilai : nilai
# jngan : jngan
# sisi : sisi
# kesadaran : sadar
# pendidikan : didik
# indonesia : indonesia
# agama : agama
# perlakukan : laku
# terapkan : terap
# intinya : inti
# seksual : seksual
# kebanyakan : banyak
# syahwat : syahwat
# merusak : rusak
# pikiran : pikir
# elektronik : elektronik
# gambar : gambar
# berbau : bau
# pornografi : pornografi
# terbukti : bukti
# pecat : pecat
# halo : halo
# dhea : dhea
# anggraini : anggraini
# ijin : ijin
# vidio : vidio
# pembuatan : buat
# bersuara : suara
# terima : terima
# kasih : kasih
# naluri : naluri
# lelaki : lelaki
# wanita : wanita
# coba : coba
# nikah : nikah
# nggak : nggak
# ngorbanin : ngorbanin
# perempuan : perempuan
# depannya : depan
# asupan : asupan
# dr : dr
# rmh : rmh
# jd : jd
# buas : buas
# edukasi : edukasi
# memuaskan : muas
# oke : oke
# akibat : akibat
# ikhtilath : ikhtilath
# pergaulan : gaul
# terjaga : jaga
# kantor : kantor
# spt : spt
# perselingkuhan : selingkuh
# dsb : dsb
# miris : miris
# knp : knp
# sekolahin : sekolahin
# anak : anak
# australia : australia
# dari pada : dari pada
# indo : indo
# apain : apain
# hukum : hukum
# gajelas : gajelas
# tumbal : tumbal
# darurat : darurat
# blm : blm
# selese : selese
# sampek : sampek
# berharap : harap
# mata : mata
# najwa : najwa
# mendorong : dorong
# peraturan : atur
# skripsi : skripsi
# tesis : tesis
# sop : sop
# bimbingan : bimbing
# ditentukan : tentu
# mangkir : mangkir
# jadual : jadual
# konsekwensi : konsekwensi
# pembimbing : bimbing
# arahan : arah
# petunjuk : tunjuk
# draft : draft
# diserahkan : serah
# dimana : mana
# lokasi : lokasi
# daring : daring
# luring : luring
# kepastian : pasti
# daridulu : daridulu
# ringkus : ringkus
# ayam : ayam
# mbak : mbak
# nana : nana
# tlg : tlg
# jg : jg
# dikawal : kawal
# subang : subang
# pembunuhan : bunuh
# dlm : dlm
# bagasi : bagasi
# bln : bln
# terungkap : ungkap
# febri : febri
# ansyah : ansyah
# scr : scr
# verbal : verbal
# bnr : bnr
# menjurus : jurus
# atasan : atas
# bawahan : bawah
# pilot : pilot
# pramugari : pramugari
# dokter : dokter
# perawat : awat
# dll : dll
# alumni : alumni
# uns : uns
# dpt : dpt
# dibawa : bawa
# hotel : hotel
# temannya : teman
# diperlakukan : laku
# senonoh : senonoh
# laki : laki
# mirisnya : miris
# kelainan : lain
# homo : homo
# eksekusi : eksekusi
# tidur : tidur
# dirumah : rumah
# krna : krna
# dirumahnya : rumah
# tertidur : tidur
# langsung : langsung
# terbangun : bangun
# alhasil : alhasil
# waswas : waswas
# bersujud : sujud
# memohon : mohon
# melaporkannya : lapor
# fihak : fihak
# berwajib : wajib
# kasihan : kasihan
# mengancamnya : ancam
# melakukannya : laku
# atau pun : atau pun
# laporkan : lapor
# usut : usut
# dijadikan : jadi
# kehomoannya : homo
# teman : teman
# junior : junior
# korban : korban
# berani : berani
# tsb : tsb
# tnggal : tnggal
# diem : diem
# hikmah : hikmah
# ambil : ambil
# gampang : gampang
# percaya : percaya
# kenal : kenal
# dsana : dsana
# mengaku : aku
# open : open
# minder : minder
# berusaha : usaha
# mempertahankan : tahan
# egonya : ego
# legalitas : legalitas
# lgbt : lgbt
# pikirkan : pikir
# normal : normal
# dilindungi : lindung
# mengandalkan : andal
# hawa : hawa
# napsu : napsu
# bejad : bejad
# pekanbaru : pekanbaru
# jgak : jgak
# pengakuan : aku
# pangil : pangil
# smua : smua
# kotor : kotor
# hukuman : hukum
# layak : layak
# untung : untung
# nadim : nadim
# kisanak : kisanak
# ngelurusin : ngelurusin
# dunguan : dungu
# zinah : zinah
# dilegalkan : legal
# kapasitas : kapasitas
# ko : ko
# mn : mn
# tri : tri
# miriiss : miriiss
# episode : episode
# titipan : titip
# meniadakan : tiada
# sehat : sehat
# bangku : bangku
# sd : sd
# sma : sma
# smp : smp
# tangannya : tangan
# nakal : nakal
# pegang : pegang
# mm : mm
# makasih : makasih
# kk : kk
# trmksh : trmksh
# shihab : shihab
# tim : tim
# smg : smg
# berkah : berkah
# bahagia : bahagia
# sllu : sllu
# bahas : bahas
# uu : uu
# berantas : berantas
# bos : bos
# assourcing : assourcing
# satunya : satu
# memanfaatkan : manfaat
# jabatannya : jabat
# cahaya : cahaya
# ngapain : ngapain
# dihotel : hotel
# dosenpaksamahasiswakerjaintugasberlebih : dosenpaksamahasiswakerjaintugasberlebih
# kak : kak
# didaerah : daerah
# sumut : sumut
# medan : medan
# tebing : tebing
# mlh : mlh
# parah : parah
# respon : respon
# prtama : prtama
# ngalamin : ngalamin
# bgini : bgini
# refleknya : refleknya
# kaget : kaget
# trus : trus
# teriak : teriak
# marah : marah
# bingung : bingung
# cranya : cranya
# gimna : gimna
# ngeri : ngeri
# nangis : nang
# penyintas : sintas
# dirahasiakan : rahasia
# suara : suara
# sesenggukan : sengguk
# nampaknya : nampaknya
# trenyuh : trenyuh
# nasib : nasib
# apapun : apa
# berujung : ujung
# dilarang : larang
# copy : copy
# nyata : nyata
# anime : anime
# suka : suka
# adegan : adegan
# gini : gin
# dunia : dunia
# ih : ih
# amit : amit
# hayoloh : hayoloh
# undang : undang
# anger : anger
# sepakati : sepakat
# pada hal : pada hal
# udh : udh
# tindak : tindak
# negatifnya : negatif
# otak : otak
# uang : uang
# mama : mama
# lelet : lelet
# kirim : kirim
# istilah : istilah
# baiknya : baik
# aturan : atur
# direvisi : revisi
# melindungi : lindung
# tpi : tpi
# nama : nama
# tdk : tdk
# peluang : peluang
# prostitusi : prostitusi
# bertumbuh : tumbuh
# pesat : pesat
# nauzubillahiminzalik : nauzubillahiminzalik
# perbuatan : buat
# berpendidikan : didik
# bgt : bgt
# mentang : mentang
# pnya : pnya
# jabatan : jabat
# ksian : ksi
# kpintaran : kpintaran
# kcerdasan : kcerdasan
# jijik : jijik
# bener : bener
# gk : gk
# sekolah : sekolah
# resiko : resiko
# busehh : busehh
# dah : dah
# inget : inget
# tlol : tlol
# dirumh : dirumh
# wajah : wajah
# lembaga : lembaga
# diindonesia : indonesia
# dewasa : dewasa
# super : super
# penentu : tentu
# nasif : nasif
# didiknya : didik
# shg : shg
# mhswa : mhswa
# sumber : sumber
# pelampiasan : lampias
# semangat : semangat
# kakak : kakak
# jawa : jawa
# timur : timur
# umumkan : umum
# rekomenkan : rekomenkan
# macem : macem
# ayo : ayo
# lha : lha
# mahasiwi : mahasiwi
# lecehkan : leceh
# rekam : rekam
# bukti : bukti
# iming : iming
# luluskan : lulus
# predaktor : predaktor
# tuhan : tuhan
# cuek : cuek
# spp : spp
# bayar : bayar
# yng : yng
# gilaa : gilaa
# phk : phk
# hormat : hormat
# proficiat : proficiat
# ruang : ruang
# narasi : narasi
# ditunggu : tunggu
# semoga : moga
# paska : paska
# segmen : segmen
# berwenang : wenang
# mengambil : ambil
# langkah : langkah
# menyikapi : sikap
# kemanusiaan : manusia
# panik : panik
# cek : cek
# hp : hp
# suami : suami
# bu : bu
# kwalitas : kwalitas
# honorer : honorer
# nyogok : nyogok
# kunyuuk : kunyuuk
# edaan : edaan
# tangkap : tangkap
# kya : kya
# gitu : gitu
# trending : trending
# mesum : mesum
# cowok : cowok
# cewe : cewe
# cpt : cpt
# cowo : cowo
# persulit : sulit
# inti : inti
# kejadian : jadi
# berilmu : beril
# berakhlak : akhlak
# sidik : sidik
# jari : jari
# megang : megang
# mahasiswi : mahasiswi
# tingkat : tingkat
# moralitas : moralitas
# nmr : nmr
# mentri : tri
# terkait : kait
# jual : jual
# bli : bli
# ijasah : ijasah
# stim : stim
# lpi : lpi
# makassar : makassar
# manalah : mana
# dihapuskan : hapus
# terkecuali : kecuali
# gaada : gaada
# disitu : situ
# bagai mana : bagai mana
# sek : sek
# gaakan : gaakan
# dibasmitapi : dibasmitapi
# pekerjakan : kerja
# barulah : baru
# aman : aman
# penjarakan : penjara
# dugaanku : duga
# ttng : ttng
# bermoral : moral
# kejahatan : jahat
# dialami : alami
# kesempatan : sempat
# terbesar : besar
# menutup : tutup
# diperbolehkan : boleh
# uninstal : uninstal
# ganti : ganti
# susahnya : susah
# tantangan : tantang
# mencegah : cegah
# sok : sok
# akademisi : akademisi
# mutlak : mutlak
# bagaimana pun : bagaimana pun
# ruangan : ruang
# tumpukan : tumpu
# seakan : akan
# membedakannya : beda
# sampah : sampah
# alumnus : alumnus
# menarik : tarik
# membuka : buka
# hasil : hasil
# kerjanya : kerja
# anggauta : anggauta
# dpr : dpr
# mengesahkan : kesah
# wedeni : wedeni
# lek : lek
# mek : mek
# penjara : penjara
# ae : ae
# sue : sue
# merambat : rambat
# ng : ng
# tk : tk
# bayi : bayi
# kumpuli : kumpul
# killer : killer
# ujian : uji
# wkwkkw : wkwkkw
# sanksi : sanksi
# unsri : unsri
# sadar : sadar
# kejam : kejam
# haloo : haloo
# kabarr : kabarr
# kebirii : kebiri
# nggk : nggk
# denger : denger
# kabar : kabar
# brlakunyaa : brlakunyaa
# hancur : hancur
# kepercayaan : percaya
# masyarakat : masyarakat
# kerena : rena
# ulah : ulah
# kakek : kakek
# sugiono : sugiono
# no : no
# nilai : nilai
# rektor : rektor
# kebijakan : bijak
# cctv : cctv
# meminimalisir : meminimalisir
# tindakan : tindak
# anehny : anehny
# goreng : goreng
# emg : emg
# enk : enk
# bercocok : cocok
# tanam : tanam
# lgi : lgi
# nanem : nanem
# cabe : cabe
# kriting : kriting
# achh : achh
# smaa : smaa
# nara : nara
# menyalurkan : salur
# blg : blg
# gmna : gmna
# pembahasan : bahas
# emank : emank
# gue : gue
# bravo : bravo
# nafsuan : nafsu
# skrg : skrg
# prnah : prnah
# jdi : jdi
# slj : slj
# dri : dri
# la'nat : la nat
# binatang : binatang
# gtu : gtu
# ajah : ajah
# ngomongnya : ngomongnya
# penjahat : jahat
# kebal : kebal
# keluarganya : keluarga
# rusak : rusak
# citra : citra
# lamaa : lamaa
# duhh : duhh
# pindah : pindah
# planet : planet
# sungguh : sungguh
# memilukan : milu
# hadir : hadir
# kuningan : kuningan
# nurmenfast : nurmenfast
# namanya : nama
# ngaku : ngaku
# membuktikan : bukti
# meski pun : meski pun
# urusan : urus
# sulit : sulit
# dibuktikan : bukti
# kali : kali
# keadilan : adil
# ketar : ketar
# ketir : tir
# kedok : kedok
# kebongkar : bongkar
# next : next
# tukang : tukang
# palak : palak
# barter : barter
# tiket : tiket
# pesawat : pesawat
# potong : potong
# titid : titid
# melecehkan : leceh
# mendidik : didik
# menghancurkan : hancur
# siswi : siswi
# hati : hati
# dibimbing : bimbing
# recorder : recorder
# senyum : senyum
# cocok : cocok
# masukin : masukin
# ring : ring
# diajakin : diajakin
# baku : baku
# hantam : hantam
# enaknya : enak
# pengen : ken
# kawin : kawin
# tinggal : tinggal
# mahasiswinya : mahasiswi
# menjijikkan : jijik
# unri : unri
# ugm : ugm
# unsriwijaya : unsriwijaya
# setuju : tuju
# ngerii : ngeri
# ilang : ilang
# trauma : trauma
# berpapasan : papas
# pakaian : pakai
# kyk : kyk
# dikti : dikti
# evaluasi : evaluasi
# lagii : lagi
# nich : nich
# nidn : nidn
# soale : soale
# fakultas : fakultas
# tekhnik : tekhnik
# geodesi : geodesi
# unwim : unwim
# proper : proper
# enake : enake
# jidat : jidat
# attitude : attitude
# oon : oon
# moril : moril
# bobrok : bobrok
# ngedidik : ngedidik
# banyaknya : banyak
# chat : chat
# wa : wa
# bacot : bacot
# nyeletuk : nyeletuk
# presentasi : presentasi
# ngomong : ngomong
# yo : yo
# akhlak : akhlak
# deh : deh
# hebatnya : hebat
# akreditasi : akreditasi
# dinikah : dini
# siri : siri
# simpanan : simpan
# selingkuh : selingkuh
# nanno : nanno
# tertangkap : tangkap
# desen : desen
# tega : tega
# uda : uda
# lupa : lupa
# lahir : lahir
# darimana : darimana
# dugaan : duga
# temen : temen
# ketakutan : takut
# lapor : lapor
# gada : gada
# wal : wal
# bk : bk
# bersangkutan : sangkut
# disarankan : saran
# surat : surat
# kaleng : kaleng
# dikirimkan : kirim
# kotak : kotak
# ahirnya : ahirnya
# oknum : oknum
# pengajar : ajar
# dibina : bina
# suruh : suruh
# bernama : nama
# syukurnya : syukur
# utu : utu
# mengakui : aku
# tindakannya : tindak
# sangek : sangek
# istrinya : istri
# tod : tod
# dituntut : tuntut
# babe : babe
# haikal : haikal
# permen : permen
# dikbud : dikbud
# daud : daud
# makan : makan
# produk : produk
# berbasis : bas
# hewani : hewani
# telor : telor
# susu : susu
# daging : daging
# insya : insya
# allah : allah
# manjur : manjur
# menurunkan : turun
# buktikan : bukti
# menikah : meni
# beliin : beliin
# gimana : gimana
# tanda : tanda
# tangan : tangan
# nawarin : nawarin
# ketiga : tiga
# disetiap : tiap
# kelas : kelas
# btw : btw
# degan : degan
# cerita : cerita
# goblog : goblog
# mon : mon
# kasar : kasar
# nahan : nahan
# emosi : emosi
# gw : gw
# adeknya : adeknya
# napsuan : napsuan
# kampusnya : kampus
# lawan : lawan
# jenis : jenis
# liatin : liatin
# muridnya : murid
# wajar : wajar
# temenku : temenku
# disuruh : suruh
# dtg : dtg
# periksa : periksa
# uas : uas
# sekelas : kelas
# libur : libur
# dtgnya : dtgnya
# berdua : dua
# abis : abis
# nerima : nerima
# pura : pura
# ditelpon : telpon
# pulang : pulang
# rencanainnya : rencanainnya
# berangkat : berangkat
# nunjukin : nunjukin
# vulgar : vulgar
# berhati : hati
# gelagat : gelagat
# engga : engga
# pakaiannya : pakai
# manuzia : manuzia
# pastii : pasti
# nafsunya : nafsu
# pengaruh : pengaruh
# setan : setan
# makanan : makan
# menambah : tambah
# nabati : nabati
# bahasa : bahasa
# perguruan : guru
# gelar : gelar
# professor : professor
# kelakuanya : kelakuanya
# aib : aib
# penuntutnya : tuntut
# akhirat : akhirat
# swt : swt
# membalas : balas
# bejadnya : bejadnya
# nikab : nikab
# dilecehkan : leceh
# mengalami : alami
# mengenakkan : enak
# kesurupan : surup
# transgender : transgender
# silahkan : silah
# trik : trik
# diatas : atas
# islam : islam
# memuliakan : mulia
# jagalah : jaga
# tutup : tutup
# aurat : aurat
# genit : genit
# fitnah : fitnah
# adlh : adlh
# menangis : menang
# teror : teror
# kemarin : kemarin
# liat : liat
# berita : berita
# yatim : yatim
# pukulin : pukulin
# berdarah : darah
# cewek : cewek
# betapa : betapa
# lemahnya : lemah
# perlindungan : lindung
# anaknya : anak
# bullying : bullying
# bnyak : bnyak
# jablay : jablay
# bnyk : bnyk
# prawan : prawan
# lg : lg
# ky : ky
# mah : mah
# jaman : jaman
# baheula : baheula
# bela : bela
# pelaku : laku
# alesanya : alesanya
# rahasia : rahasia
# murtad : murtad
# liberal : liberal
# kebebasan : bebas
# dikampus : kampus
# garis : garis
# biayaya : biayaya
# menyebabkan : sebab
# najwashihab : najwashihab
# matanajwa : matanajwa
# when : when
# become : become
# nosense : nosense
# ok : ok
# yahud : yahud
# gila : gila
# dasar : dasar
# kau : kau
# rakus : rakus
# robek : robek
# perawannya : perawan
# sodomi : sodomi
# pns : pns
# mati : mati
# diluar : luar
# momentnya : momentnya
# intelek : intelek
# the : the
# lhedek : lhedek
# pengajarnya : ajar
# duwitan : duwitan
# dikuasai : asai
# kebusukan : busuk
# dibenahi : benah
# dibubarkan : bubar
# sj : sj
# ketua : ketua
# mui : mui
# ketinggalan : tinggal
# adek : adek
# sampe : sampe
# bunuh : bunuh
# klu : klu
# hayooloohh : hayooloohh
# dikampusku : kampus
# dlu : dlu
# bgitu : bgitu
# kyaknya : kyaknya
# fakta : fakta
# saksi : saksi
# bawa : bawa
# revisian : revisi
# rumahnya : rumah
# pdhal : pdhal
# jam : jam
# sore : sore
# wkwkwkw : wkwkwkw
# malang : malang
# daerahku : daerah
# jni : jni
# modusnya : modus
# sebenernya : sebenernya
# wajib : wajib
# waspada : waspada
# kalangan : kalang
# pejabat : jabat
# ustad : ustad
# ngerti : ngerti
# jaga : jaga
# kesalahan : salah
# pemakaian : pakai
# mangsa : mangsa
# terpelihara : pelihara
# perkara : perkara
# maksud : maksud
# firman : firman
# surah : surah
# al : al
# ahzab : ahzab
# nabi : nabi
# isterimu : isterimu
# perempuanmu : perempuan
# mukmin : mukmin
# menutupkan : tutup
# hijabnya : hijab
# tubuh : tubuh
# dikenali : nali
# diganggu : ganggu
# maha : maha
# pengampun : kam
# penyayang : sayang
# jilbab : jilbab
# dirayu : rayu
# merayu : rayu
# skarang : skarang
# ne : ne
# tunggu : tunggu
# jebol : jebol
# penyelidikan : lidi
# khasus : khasus
# speak : speak
# up : up
# budaya : budaya
# cok : cok
# disekolah : seko
# menengah : tengah
# mantan : mantan
# smk : smk
# a susila : a susila
# iman : iman
# tipis : tipis
# barang kali : barang kali
# pria : pria
# telat : telat
# penasaran : penasaran
# bersifat : sifat
# expired : expired
# astagfirllah : astagfirllah
# pt : pt
# meresahkan : resah
# membayakan : baya
# generasi : generasi
# perhatian : perhati
# pemerintah : perintah
# sell : sell
# lindungan : lindung
# amiin : amiin
# robbal : robbal
# alamin : alamin
# daerah : daerah
# tua : tua
# utama : utama
# pantes : pantes
# bahaya : bahaya
# berkedok : kedok
# bolpen : bolpen
# microfon : microfon
# ngerekam : ngerekam
# ajar : ajar
# jgnkan : jgnkan
# olah raga : olah raga
# ganjen : ganjen
# polisi : polisi
# pinter : pinter
# berabad : abad
# kelakuan : laku
# nol : nol
# nilainya : nilai
# ah : ah
# perbedaan : beda
# dikeluarkan : keluar
# posisi : posisi
# diisi : isi
# berlatar : latar
# beda : beda
# pendahulunya : dahulu
# staf : staf
# perizinan : izin
# komenin : komenin
# photo : photo
# profil : profil
# cantik : cantik
# tuwir : tuwir
# pesantren : pesantren
# amann : amann
# dimatiin : dimatiin
# punah : punah
# bayaran : bayar
# semahal : mahal
# membiayai : biaya
# nonton : nonton
# bokep : bokep
# efeknya : efek
# merugikan : rugi
# another : another
# person : person
# by : by
# ownself : ownself
# atw : atw
# senantiasa : senantiasa
# cemas : cemas
# hawatir : hawatir
# was : was
# tjd : tjd
# pd : pd
# na : na
# udzubillahimindzalik : udzubillahimindzalik
# jgn : jgn
# konkrit : konkrit
# bentuk : bentuk
# manapun : mana
# spy : spy
# jera : jera
# sesuai : sesuai
# berat : berat
# akibatnya : akibat
# dirasakan : rasa
# pisik : pisik
# psikis : psikis
# madrasah : madrasah
# gurunya : guru
# pahaku : paha
# memberontak : berontak
# drop : drop
# mengulang : ulang
# berikutnyaa : berikutnyaa
# parahnyaa : parahnyaa
# lulus : lulus
# matkul : matkul
# sikopet : sikopet
# idih : idih
# tante : tante
# kayaknya : kayak
# twitter : twitter
# ngaji : ngaji
# tabok : tabok
# andai : andai
# jujur : jujur
# salim : salim
# diperuntukkan : untuk
# keluarga : keluarga
# kpd : kpd
# dikenal : kenal
# faham : faham
# knapa : knapa
# salaman : salam
# santun : santun
# sekokah : seko
# mengelus : elus
# elus : elus
# area : area
# tali : tali
# bra : bra
# punggung : punggung
# fikir : fikir
# syg : syg
# ucapan : ucap
# bajingan : bajing
# sebutan : sebut
# adlah : adlah
# komputer : komputer
# kepala : kepala
# mencari : cari
# siswa : siswa
# mencium : cium
# pipi : pipi
# matematika : matematika
# menahan : tahan
# tmn : tmn
# kosong : kosong
# mendekati : dekat
# apakan : apa
# math : math
# ditambah : tambah
# tertutup : tutup
# diringkus : ringkus
# habizz : habizz
# ortu : ortu
# mengedukasi : edukasi
# bhw : bhw
# bntuk : bntuk
# non : non
# kaitannya : kait
# otaknya : otak
# berhenti : henti
# pantat : pantat
# keliatan : liat
# puber : puber
# sdg : sdg
# ttg : ttg
# pelajaran : ajar
# sebelah : belah
# berubah : ubah
# merinding : merinding
# cm : cm
# ngga : ngga
# merubah : rubah
# korupsi : korupsi
# bedanya : beda
# kebiri : kebiri
# sisain : sisain
# ulahnya : ulah
# dkelas : dkelas
# dbiarin : dbiarin
# giliran : gilir
# ngelakuin : ngelakuin
# lngsung : lngsung
# dpanggil : dpanggil
# ngadep : ngadep
# ngadepnya : ngadepnya
# ngajak : ngajak
# perpustakaan : pustaka
# sepi : sepi
# dlontarkan : dlontarkan
# lo : lo
# perawan : perawan
# jomblo : jomblo
# senggang : senggang
# dsuruh : dsuruh
# mijitin : mijitin
# bahu : bahu
# dahlah : dah
# ngebatin : ngebatin
# sndiri : sndiri
# pgn : pgn
# peluk : peluk
# post : post
# muka : muka
# abistu : abistu
# poster : poster
# gedhee : gedhee
# puan : puan
# pojok : pojok
# jalan : jalan
# let : let
# anyone : anyone
# knows : knows
# sensor : sensor
# membantu : bantu
# berkat : berkat
# viralnya : viralnya
# perlahan : perlahan
# titik : titik
# terang : terang
# ampas : ampas
# emot : emot
# cium : cium
# adakah : ada
# profesi : profesi
# semcm : semcm
# perekrutannya : rekrut
# psikotes : psikotes
# menganalisa : menganalisa
# jer : jer
# kejadiannya : jadi
# porno : porno
# bule : bule
# ditingkat : tingkat
# virus : virus
# menular : tular
# buta : buta
# tuli : tuli
# sya : sya
# memperjuangkan : juang
# hak : hak
# terjun : terjun
# pda : pda
# mengalah : kalah
# sepengalaman : alam
# lingkungan : lingkung
# kerja : kerja
# alhamdulillah : alhamdulillah
# buka : buka
# negriku : negriku
# hebatt : hebatt
# mengerikan : keri
# hidup : hidup
# ngerusak : ngerusak
# mental : mental
# semangatt : semangatt
# dukung : dukung
# kamuu : kamuu
# kaset : kaset
# celah : celah
# abuse : abuse
# of : of
# power : power
# menerima : terima
# kalah : kalah
# menolak : tolak
# sensei : sensei
# gugur : gugur
# nn : nn
# dimention : dimention
# dibahas : bahas
# berlaku : laku
# pks : pks
# ormas : ormas
# temennya : temennya
# sumpah : sumpah
# dituduh : tuduh
# pencemaran : cemar
# sedih : sedih
# adik : adik
# kawan : kawan
# goda : goda
# pelakor : pelakor
# menyakiti : sakit
# butuh : butuh
# kiyai : kiyai
# terjd : terjd
# tp : tp
# pelakunya : laku
# kucilkan : kucil
# kapok : kapok
# cc : cc
# tv : tv
# akurat : akurat
# menempuh : tempuh
# menjamin : jamin
# kelak : kelak
# bersekolah : sekolah
# tampar : tampar
# seberat : berat
# beratnya : berat
# lemah : lemah
# baga : baga
# bedebah : bedebah
# musnah : musnah
# sangean : sangean
# langganan : langgan
# psk : psk
# cookk : cookk
# horni : horni
# pelacur : lacur
# nyet : nyet
# mnyampaikan : mnyampaikan
# pengalaman : alam
# jatuh : jatuh
# bertolak : tolak
# mengejutkan : kejut
# sebgai : sebgai
# panutan : panutan
# auratnya : aurat
# dijaga : jaga
# pelechan : pelechan
# mandang : mandang
# berpakain : berpakain
# lecehin : lecehin
# seragam : seragam
# mengundang : undang
# tersangka : sangka
# dilawan : lawan
# ngapaib : ngapaib
# entengnya : enteng
# seenteng : enteng
# perasaan : asa
# nyudutin : nyudutin
# its : its
# shame : shame
# on : on
# you : you
# why : why
# university : university
# level : level
# lecture : lecture
# still : still
# doing : doing
# wrong : wrong
# thing : thing
# live : live
# and : and
# to : to
# do : do
# anything : anything
# else : else
# knpa : knpa
# sakit : sakit
# kejiwaanya : kejiwaanya
# usulan : usul
# dipisahkan : pisah
# gender : gender
# syariat : syariat
# skripsinya : skripsi
# cabul : cabul
# dikit : dikit
# ngaceng : ngaceng
# melampiaskan : lampias
# dikepala : kepala
# berkeliaran : liar
# kuat : kuat
# memberatkan : berat
# seumur : umur
# curhatan : curhatan
# yaallah : yaallah
# menentukan : tentu
# berkualitas : kualitas
# solusi : solusi
# kontenin : kontenin
# basmi : basmi
# palsu : palsu
# ato : ato
# sebejatnya : bejat
# taksir : taksir
# tinggalin : tinggalin
# harga : harga
# menghargai : harga
# beradap : adap
# iblispun : iblis
# ilmunya : ilmu
# syekh : syekh
# abdul : abdul
# qadir : qadir
# jailani : jailani
# murid : murid
# menghormati : hormat
# ketiak : ketiak
# bersikap : sikap
# ditindak : tindak
# lanjuti : lanjut
# pls : pls
# dihadapin : dihadapin
# petinggi : petinggi
# diusut : usut
# pelapor : lapor
# dijadiin : dijadiin
# ketat : ketat
# seleksinya : seleksi
# ajarin : ajarin
# seksualitas : seksualitas
# sekian : sekian
# topik : topik
# angkat : angkat
# khalayak : khalayak
# kedepannya : depan
# mantap : mantap
# nadiem : nadiem
# makarim : makarim
# terhormat : hormat
# inspektorat : inspektorat
# kemendikbud : kemendikbud
# meng : meng
# audit : audit
# perjalanan : jalan
# dinas : dinas
# cerai : cerai
# penyebabnya : sebab
# dokumen : dokumen
# proses : proses
# cerainya : cerai
# modus : modus
# honeymoon : honeymoon
# sangsi : sangsi
# seberatnya : berat
# mengganggu : ganggu
# tangga : tangga
# pegawai : pegawai
# sipil : sipil
# saptu : saptu
# minggu : minggu
# yth : yth
# kontak : kontak
# email : email
# pengaduan : adu
# senang : senang
# highlight : highlight
# masalh : masalh
# kebobrokan : bobrok
# bertindak : tindak
# semena : semena
# mena : mena
# kuasa : kuasa
# bayangin : bayangin
# senyume : senyume
# iku : iku
# beroktak : beroktak
# berpikirnya : pikir
# minim : minim
# lolos : lolos
# wajibkan : wajib
# sulitkah : sulit
# plis : plis
# hargai : harga
# oy : oy
# maunya : mau
# hah : hah
# kesini : kesini
# pedofil : pedofil
# merajalela : rajalela
# ngelakuinya : ngelakuinya
# segampang : gampang
# ngetik : ngetik
# asli : asli
# dengernya : dengernya
# beradab : adab
# bersyukur : syukur
# dosenku : dosen
# berperasaan : rasa
# walau pun : walau pun
# jahat : jahat
# ngasih : ngasih
# sutradara : sutradara
# berdasarkan : dasar
# kisah : kisah
# bergelar : gelar
# kuatir : kuatir
# berpihak : pihak
# mbanya : mbanya
# gabisa : gabisa
# berjalan : jalan
# perbaiki : baik
# pengangguran : anggur
# berkompetisi : kompetisi
# pelatihan : latih
# sediakan : sedia
# wna : wna
# pemerataan : perata
# pembangunan : bangun
# tol : tol
# lintas : lintas
# kecamatan : camat
# pedalaman : dalam
# sejahterakan : sejahtera
# honor : honor
# mas : mas
# kemendikbudristekdikti : kemendikbudristekdikti
# menggoda : goda
# mgkin : mgkin
# jiwa : jiwa
# brrti : brrti
# pliss : pliss
# gaboleh : gaboleh
# berduaan : dua
# sm : sm
# dielus : elus
# uin : uin
# utamanya : utama
# dirimu : diri
# berharga : harga
# dibanding : banding
# ipk : ipk
# kampusmu : kampus
# wisuda : wisuda
# bareng : bareng
# dapet : dapet
# kerjaan : kerja
# seadanya : ada
# diperjuangkan : juang
# tawarkan : tawar
# kehormatanmu : hormat
# trendingkann : trendingkann
# team : team
# anjirr : anjirr
# dengerin : dengerin
# deg : deg
# gemeteran : gemeteran
# muhamadiyah : muhamadiyah
# pengecut : kecut
# pecah : pecah
# membayangkan : bayang
# adil : adil
# kehidupan : hidup
# ganteng : ganteng
# melegalkan : legal
# illegal : illegal
# gapernah : gapernah
# logikanya : logika
# dungu : dungu
# ngelawan : ngelawan
# goyang : goyang
# melaporkan : lapor
# kasusnya : kasus
# pengambil : ambil
# keputusan : putus
# struktur : struktur
# setara : tara
# struktural : struktural
# ajak : ajak
# mendampingi : damping
# menguatkan : kuat
# tekanan : tekan
# menunjukan : tunjuk
# skeptis : skeptis
# kebebalan : bebal
# dipertontonkan : tonton
# rejim : rejim
# sekeras : keras
# teriakan : ria
# protes : protes
# dihiraukan : hirau
# melecehlan : melecehlan
# iya : iya
# ngeliat : ngeliat
# seinget : seinget
# kronologinya : kronologi
# diraba : raba
# pahanya : paha
# inisial : inisial
# ngajar : ngajar
# jabat : jabat
# pandu : pandu
# pramuka : pramuka
# acara : acara
# malem : malem
# tanganya : tanganya
# dicolek : colek
# ditengah : tengah
# olah : olah
# raga : raga
# praktek : praktek
# terlentang : lentang
# lari : lari
# ceritanya : cerita
# rileksasi : rileksasi
# baring : baring
# tarik : tarik
# nafas : nafas
# pemandangan : pandang
# indah : indah
# dichat : dichat
# menjerumus : jerumus
# ajakan : aja
# kencan : kencan
# jadehh : jadehh
# pokoknya : pokok
# dimanapun : mana
# rentan : rentan
# yuk : yuk
# nambah : nambah
# menyaksikan : saksi
# komem : komem
# dibawah : bawah
# please : please
# healingnya : healingnya
# publikasi : publikasi
# sepenuhnya : sepenuh
# kediri : diri
# gara : gara
# pornhub : pornhub
# genre : genre
# teen : teen
# school : school
# teacher : teacher
# office : office
# hhe : hhe
# pintar : pintar
# rekan : rekan
# prodi : prodi
# kompak : kompak
# peringatan : ingat
# bicara : bicara
# membela : bela
# berjuang : juang
# acaranya : acara
# worth : worth
# it : it
# watch : watch
# ngak : ngak
# pkl : pkl
# smester : smester
# istansi : istansi
# notabene : notabene
# pembimbung : pembimbung
# pklku : pklku
# manggil : manggil
# ruangannya : ruang
# bikinin : bikinin
# badanku : badan
# dipegang : pegang
# entar : entar
# dikasi : kasi
# depresi : depresi
# attack : attack
# laptop : laptop
# bul : bul
# pengakuannya : aku
# bantu : bantu
# bertemu : temu
# sukai : suka
# nyaman : nyaman
# maybe : maybe
# should : should
# we : we
# take : take
# self : self
# defense : defense
# class : class
# hii : hii
# ngira : ngira
# mahasiswanya : mahasiswa
# enggak : enggak
# kelakuannya : laku
# kegitu : kegitu
# seberani : berani
# nekad : nekad
# sagne : sagne
# smpai : smpai
# tebas : tebas
# mandau : mandau
# kalimantan : kalimantan
# flashback : flashback
# prilakunya : prilakunya
# kerekam : rekam
# memori : memori
# koq : koq
# ribut : ribut
# enak : enak
# kecuali : kecuali
# unsur : unsur
# penganiayaan : aniaya
# dogma : dogma
# ajaran : ajar
# sesat : sesat
# bidadari : bidadari
# disiapkan : siap
# sorga : sorga
# ahlaq : ahlaq
# tingkatan : tingkat
# dripada : dripada
# s : s
# proffesor : proffesor
# serendah : serendah
# berahlaq : berahlaq
# sikopat : sikopat
# pingin : pingin
# mekkah : mek
# mampir : mampir
# kewenangan : wenang
# potensi : potensi
# dilencengkan : lenceng
# individu : individu
# unggullah : unggul
# menyemat : semat
# kurangajar : kurangajar
# dibalik : balik
# deketin : deketin
# tampan : tampan
# ibarah : ibarah
# mobil : mobil
# motor : motor
# disalahkan : salah
# dihujat : hujat
# duluan : duluan
# plakunya : plakunya
# cerdas : cerdas
# kedudukan : duduk
# bukanya : buka
# menuduh : tuduh
# suda : suda
# nha : nha
# kota : kota
# sklh : sklh
# ekskul : ekskul
# jalur : jalur
# damai : damai
# gmn : gmn
# ceritain : ceritain
# embernya : ember
# kayanya : kaya
# ember : ember
# milih : milih
# hidung : hidung
# belang : belang
# medum : medum
# hina : hina
# youtube : youtube
# nyantai : nyantai
# doyan : doyan
# diemin : diemin
# duduk : duduk
# ganjar : ganjar
# risma : risma
# kantung : kantung
# buayanya : buaya
# ninggalin : ninggalin
# mengajar : ajar
# jilid : jilid
# mentalku : mental
# kelompok : kelompok
# harm : harm
# nyangka : nyangka
# cinta : cinta
# bertopeng : topeng
# tersebar : sebar
# serem : rem
# ihh : ihh
# nyadar : nyadar
# umur : umur
# menyulitkan : sulit
# situasi : situasi
# cokk : cokk
# walopun : walopun
# ajarnya : ajar
# tergambar : gambar
# menghukum : hukum
# memerkosa : perkosa
# keji : keji
# ayolah : ayo
# badan : badan
# pemerkosa : perkosa
# pembunuh : bunuh
# negera : negera
# sahabat : sahabat
# lakukan : laku
# sexual : sexual
# diancam : ancam
# tersedu : sedu
# dengar : dengar
# membujuk : bujuk
# ngelapor : ngelapor
# ditutut : tutut
# terulang : ulang
# ungkit : ungkit
# down : down
# menjijikan : jijik
# biadabb : biadabb
# kebayang : bayang
# keberanian : berani
# kejadiann : kejadiann
# ganjaran : ganjar
# spadan : spadan
# berprestasi : prestasi
# menakutkan : takut
# kekampus : kampus
# jahanam : jahanam
# dikasih : kasih
# dibikin : bikin
# meme : meme
# bang : bang
# nyonya : nyonya
# tuan : tuan
# wani : wani
# piroo : piroo
# https : https
# youtu : youtu
# be : be
# fwqjp : fwqjp
# fthm : fthm
# nyakitin : nyakitin
# korbannya : korban
# disalahin : disalahin
# tersakiti : sakit
# bercerita : cerita
# videokah : video
# hehee : hehee
# ikutan : ikut
# gemeter : gemeter
# kesaksiannya : saksi
# niatnya : niat
# perlakuan : laku
# {'jebak': 'jebak', 'matta': 'matta', 'dosen': 'dosen', 'paha': 'paha', 'mulus': 'mulus', 'ketahuan': 'tahu', 'predator': 'predator', 'makanyaa': 'makanyaa', 'gak': 'gak', 'kuliah': 'kuliah', 'mending': 'mending', 'kayak': 'kayak', 'goa': 'goa', 'mengangkat': 'angkat', 'senjata': 'senjata', 'dn': 'dn', 'menjaga': 'jaga', 'persatuan': 'satu', 'bangsa': 'bangsa', 'negara': 'negara', 'mikir': 'mikir', 'klw': 'klw', 'itwuu': 'itwuu', 'membuang': 'buang', 'buang': 'buang', 'bayangkan': 'bayang', 'lu': 'lu', 'lihat': 'lihat', 'sii': 'sii', 'pemalas': 'malas', 'contoh': 'contoh', 'abang': 'abang', 'cuman': 'cuman', 'ketemu': 'ketemu', 'susah': 'susah', 'payah': 'payah', 'aoa': 'aoa', 'ndak': 'ndak', 'perduli': 'duli', 'kasian': 'kasi', 'capek': 'capek', 'kripsi': 'kripsi', 'haduhh': 'haduhh', 'seandainyaa': 'seandainyaa', 'universiti': 'universiti', 'asrama': 'asrama', 'militer': 'militer', 'auti': 'auti', 'tijak': 'tijak', 'twuu': 'twuu', 'manusia': 'manusia', 'ad': 'ad', 'ampun': 'ampun', 'udah': 'udah', 'permainkan': 'main', 'lbh': 'lbh', 'bae': 'bae', 'pilih': 'pilih', 'kuliahan': 'kuliah', 'sejenis': 'jenis', 'kampus': 'kampus', 'kedinasan': 'dinas', 'disiplin': 'disiplin', 'paksa': 'paksa', 'males': 'males', 'berbuat': 'buat', 'pemimpin': 'pimpin', 'nyaa': 'nyaa', 'komandan': 'komandan', 'ttp': 'ttp', 'tendang': 'tendang', 'ditampar': 'tampar', 'menyuruh': 'suruh', 'bermental': 'mental', 'org': 'org', 'bodoh': 'bodoh', 'menampar': 'tampar', 'jga': 'jga', 'mengendalikan': 'kendali', 'psikologi': 'psikologi', 'bsa': 'bsa', 'mnjdi': 'mnjdi', 'pemberani': 'berani', 'melawan': 'lawan', 'saran': 'saran', 'aq': 'aq', 'msk': 'msk', 'tni': 'tni', 'polri': 'polri', 'pilihlahh': 'pilihlahh', 'akpol': 'akpol', 'akmil': 'akmil', 'tamat': 'tamat', 'merasakan': 'rasa', 'pemuda': 'pemuda', 'pemudi': 'pemudi', 'terbaik': 'baik', 'as': 'as', 'salam': 'salam', 'media': 'media', 'pertunjukan': 'tunjuk', 'film': 'film', 'menceritakan': 'cerita', 'percintaan': 'cinta', 'berfikir': 'berfikir', 'religious': 'religious', 'ketakwaan': 'takwa', 'berpuasa': 'puasa', 'senen': 'senen', 'kamis': 'kamis', 'pintu': 'pintu', 'gerbangnya': 'gerbang', 'kasis': 'kas', 'menjelek': 'jelek', 'jelekkan': 'jelek', 'aa': 'aa', 'gym': 'gym', 'nastiar': 'nastiar', 'memiliki': 'milik', 'isteri': 'isteri', 'suku': 'suku', 'memilih': 'pilih', 'tenaga': 'tenaga', 'pendidik': 'didik', 'berpengalaman': 'alam', 'dalem': 'dalem', 'berpacaran': 'pacar', 'belajar': 'ajar', 'berguru': 'guru', 'guru': 'guru', 'salah': 'salah', 'fokus': 'fokus', 'ke pada': 'ke pada', 'menyalahkan': 'salah', 'peri laku': 'peri laku', 'burukk': 'burukk', 'don': 'don', 'juan': 'juan', 'publik': 'publik', 'figur': 'figur', 'menyambung': 'sambung', 'lagu': 'lagu', 'baju': 'baju', 'alhamdulilallah': 'alhamdulilallah', 'untk': 'untk', 'pake': 'pake', 'hr': 'hr', 'raya': 'raya', 'fitri': 'fitri', 'pacar': 'pacar', 'punyap': 'punyap', 'un': 'un', 'puasa': 'puasa', 'syawalnya': 'syawal', 'pamerin': 'pamerin', 'punyapun': 'punya', 'kamisnya': 'kamis', 'selamat': 'selamat', 'menerapkandisiplin': 'menerapkandisiplin', 'merdeka': 'merdeka', 'liberty': 'liberty', 'wassalamu': 'wassalamu', 'alaikum': 'alaikum', 'wr': 'wr', 'wb': 'wb', 'ga': 'ga', 'ush': 'ush', 'dipanggil': 'panggil', 'beliau': 'beliau', 'sex': 'sex', 'dihormati': 'hormat', 'terkadang': 'terkadang', 'heran': 'heran', 'ditempat': 'tempat', 'menuntut': 'tuntut', 'ilmu': 'ilmu', 'pelecehan': 'leceh', 'negri': 'negri', 'kaya': 'kaya', 'adat': 'adat', 'istiadat': 'istiadat', 'alamnya': 'alam', 'apologize': 'apologize', 'sopan': 'sopan', 'kenyataan': 'nyata', 'bebas': 'bebas', 'oey': 'oey', 'wkk': 'wkk', 'hikss': 'hikss', 'sukses': 'sukses', 'mba': 'mba', 'njwa': 'njwa', 'update': 'update', 'dosennya': 'dosen', 'divonis': 'vonis', 'pengadilan': 'adil', 'iblis': 'iblis', 'cosplay': 'cosplay', 'tonjok': 'tonjok', 'sy': 'sy', 'mhn': 'mhn', 'nazwa': 'nazwa', 'supir': 'supir', 'perusahaan': 'usaha', 'nanya': 'nanya', 'emng': 'emng', 'upah': 'upah', 'khusus': 'khu ...
# ------------------------

# %%
df['STEMMER'] = df['STOP_REMOVAL'].apply(get_stemmed_term)
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif
# 5                   bebas sekarang oey wkk hmm hikss  positif
# 6                              sukses terus mba njwa  positif
# 7  update aja ni dosennya divonis bebas sama peng...  positif
# 8                         ketika iblis cosplay dosen  negatif
# 9                         gua tonjok kalau jadi dia   negatif
#
#                                         TOKENIZATION  \
# 0  [jebak, matta, dosen, dgn, paha, mulus, pasti,...
# 1  [makanyaa, gak, usah, kuliah, mending, kayak, ...
# 2  [as, salam, sebagian, besar, nyaris, lbh, dari...
# 3  [org, org, kayak, ini, ga, ush, dipanggil, bel...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5            [bebas, sekarang, oey, wkk, hmm, hikss]
# 6                         [sukses, terus, mba, njwa]
# 7  [update, aja, ni, dosennya, divonis, bebas, sa...
# 8                    [ketika, iblis, cosplay, dosen]
# 9                      [goa, tonjok, klw, jadi, dia]
#
#                                         STOP_REMOVAL  \
# 0  [jebak, matta, dosen, paha, mulus, ketahuan, d...
# 1  [makanyaa, gak, kuliah, mending, kayak, goa, m...
# 2  [as, salam, lbh, media, pertunjukan, film, men...
# 3  [org, org, kayak, ga, ush, dipanggil, beliau, ...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5                           [bebas, oey, wkk, hikss]
# 6                                [sukses, mba, njwa]
# 7     [update, dosennya, divonis, bebas, pengadilan]
# 8                            [iblis, cosplay, dosen]
# 9                                 [goa, tonjok, klw]
#
#                                              STEMMER
# 0  [jebak, matta, dosen, paha, mulus, tahu, dosen...
# 1  [makanyaa, gak, kuliah, mending, kayak, goa, a...
# 2  [as, salam, lbh, media, tunjuk, film, cerita, ...
# 3  [org, org, kayak, ga, ush, panggil, beliau, pr...
# 4  [terkadang, aq, heran, tempat, tuntut, ilmu, l...
# 5                           [bebas, oey, wkk, hikss]
# 6                                [sukses, mba, njwa]
# 7                [update, dosen, vonis, bebas, adil]
# 8                            [iblis, cosplay, dosen]
# 9                                 [goa, tonjok, klw]

# %%
def fit_stemmer(text):
     text = np.array(text)
     text = ' '.join(text)
     return text

df['Komentar_Final'] = df['STEMMER'].apply(lambda x: fit_stemmer(x))
df.head(10)
# Out:
#                                             Komentar    Label  \
# 0  jebak matta dosen dengan paha mulus pasti keta...  negatif
# 1  makanyaa gak usah kuliah mending kayak gua men...  negatif
# 2  as salam sebagian besar nyaris lebih dari  med...  negatif
# 3  orang orang seperti ini ga ush dipanggil belia...  negatif
# 4  terkadang saya heran ditempat menuntut ilmu te...  positif
# 5                   bebas sekarang oey wkk hmm hikss  positif
# 6                              sukses terus mba njwa  positif
# 7  update aja ni dosennya divonis bebas sama peng...  positif
# 8                         ketika iblis cosplay dosen  negatif
# 9                         gua tonjok kalau jadi dia   negatif
#
#                                         TOKENIZATION  \
# 0  [jebak, matta, dosen, dgn, paha, mulus, pasti,...
# 1  [makanyaa, gak, usah, kuliah, mending, kayak, ...
# 2  [as, salam, sebagian, besar, nyaris, lbh, dari...
# 3  [org, org, kayak, ini, ga, ush, dipanggil, bel...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5            [bebas, sekarang, oey, wkk, hmm, hikss]
# 6                         [sukses, terus, mba, njwa]
# 7  [update, aja, ni, dosennya, divonis, bebas, sa...
# 8                    [ketika, iblis, cosplay, dosen]
# 9                      [goa, tonjok, klw, jadi, dia]
#
#                                         STOP_REMOVAL  \
# 0  [jebak, matta, dosen, paha, mulus, ketahuan, d...
# 1  [makanyaa, gak, kuliah, mending, kayak, goa, m...
# 2  [as, salam, lbh, media, pertunjukan, film, men...
# 3  [org, org, kayak, ga, ush, dipanggil, beliau, ...
# 4  [terkadang, aq, heran, ditempat, menuntut, ilm...
# 5                           [bebas, oey, wkk, hikss]
# 6                                [sukses, mba, njwa]
# 7     [update, dosennya, divonis, bebas, pengadilan]
# 8                            [iblis, cosplay, dosen]
# 9                                 [goa, tonjok, klw]
#
#                                              STEMMER  \
# 0  [jebak, matta, dosen, paha, mulus, tahu, dosen...
# 1  [makanyaa, gak, kuliah, mending, kayak, goa, a...
# 2  [as, salam, lbh, media, tunjuk, film, cerita, ...
# 3  [org, org, kayak, ga, ush, panggil, beliau, pr...
# 4  [terkadang, aq, heran, tempat, tuntut, ilmu, l...
# 5                           [bebas, oey, wkk, hikss]
# 6                                [sukses, mba, njwa]
# 7                [update, dosen, vonis, bebas, adil]
# 8                            [iblis, cosplay, dosen]
# 9                                 [goa, tonjok, klw]
#
#                                       Komentar_Final
# 0   jebak matta dosen paha mulus tahu dosen predator
# 1  makanyaa gak kuliah mending kayak goa angkat s...
# 2  as salam lbh media tunjuk film cerita cinta or...
# 3  org org kayak ga ush panggil beliau predator s...
# 4  terkadang aq heran tempat tuntut ilmu leceh ne...
# 5                                bebas oey wkk hikss
# 6                                    sukses mba njwa
# 7                      update dosen vonis bebas adil
# 8                                iblis cosplay dosen
# 9                                     goa tonjok klw

# %%
df.to_csv(r'PreProcessingnajwa.csv')

# %%
import pickle
pickle.dump(stopword,
            open('stopword.pkl', 'wb'),
            protocol=4)

# %%
import pickle
pickle.dump(kamus_katabaku,
            open('kamus_katabaku.pkl', 'wb'),
            protocol=4)
