# %%
import pandas as pd
import re
import numpy as np
import joblib
import pickle
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('PreProcessing.csv')
df.tail(20)
# Out:
#      Unnamed: 0                                           Komentar    Label  \
# 247         247  mentri juga harus musyawarah ma mui nu muhamdi...  negatif
# 248         248   efek menteri asal comot gak jelas mungkin gak...  negatif
# 249         249  permendikbudristek ini udah pantas di terapkan...  positif
# 250         250  ini bikin ruu jangan disamain kyk bikin apps d...   netral
# 251         251  real bgt kekerasan seksual dikampus sdh darura...  positif
# 252         252  ojk ga berani tutup pinjol yg legal pdhl prakt...   netral
# 253         253  kalau tubuhmu di bungkus seperti permen lollip...   netral
# 254         254  semangat itu kita hargai ttp mslhx adh norma y...  negatif
# 255         255  udah diperintahkan beliau pak presiden jokowi ...  positif
# 256         256  kali ini mahasiswa menolak di tunggangi ulama ...  negatif
# 257         257  klo begitu supaya tidak terjadi hal hal yg tid...   netral
# 258         258  ngenyel banget sih para kadrun ama permendikbu...  positif
# 259         259        mengapa tokoh wanitanya diam terus ada apa    netral
# 260         260  makanya hrs nya kl terjadi kekerasan sex pd wa...   netral
# 261         261                                              dajal  negatif
# 262         262                           munkin makarim sukak sex  negatif
# 263         263          banyak bacot nadiem jelas salah ngeyel lo  negatif
# 264         264  tujuannya baik tapi bagaimana mas mentri menja...   netral
# 265         265  judulnya bagus isinya melegalkan kekerasan tol...  negatif
# 266         266  pendapat saya zina atas sadar suka sama suka t...   netral
#
#                                           TOKENIZATION  \
# 247  ['mentri', 'jga', 'hrs', 'musyawarah', 'ma', '...
# 248  ['efek', 'mentri', 'asal', 'comot', 'gak', 'je...
# 249  ['permendikbudristek', 'ini', 'udah', 'pantas'...
# 250  ['ini', 'bikin', 'ruu', 'jngan', 'disamain', '...
# 251  ['riil', 'bgt', 'kekerasan', 'seksual', 'dikam...
# 252  ['ojk', 'ga', 'berani', 'tutup', 'pinjol', 'yg...
# 253  ['klw', 'tubuhmu', 'di', 'bungkus', 'kayak', '...
# 254  ['semangat', 'itu', 'kita', 'hargai', 'ttp', '...
# 255  ['udah', 'diperintahkan', 'beliau', 'pak', 'pr...
# 256  ['kali', 'ini', 'mahasiswa', 'menolak', 'di', ...
# 257  ['klo', 'begitu', 'supaya', 'ndak', 'terjadi',...
# 258  ['ngenyel', 'bgt', 'sih', 'para', 'kadrun', 'a...
# 259  ['mengapa', 'tokoh', 'wanitanya', 'diem', 'ter...
# 260  ['makanya', 'hrs', 'nya', 'kl', 'terjadi', 'ke...
# 261                                          ['dajal']
# 262              ['munkin', 'makarim', 'sukak', 'sex']
# 263  ['byk', 'bacot', 'nadiem', 'jelas', 'salah', '...
# 264  ['tujuannya', 'bae', 'tapi', 'bagai mana', 'ma...
# 265  ['judulnya', 'oke', 'isinya', 'melegalkan', 'k...
# 266  ['pendapat', 'aq', 'zinah', 'atas', 'sadar', '...
#
#                                           STOP_REMOVAL  \
# 247  ['mentri', 'jga', 'hrs', 'musyawarah', 'ma', '...
# 248  ['efek', 'mentri', 'comot', 'gak', 'gak', 'org...
# 249  ['permendikbudristek', 'udah', 'terapkan', 'kl...
# 250  ['ruu', 'jngan', 'disamain', 'kyk', 'apps', 'p...
# 251  ['riil', 'bgt', 'kekerasan', 'seksual', 'dikam...
# 252  ['ojk', 'ga', 'berani', 'tutup', 'pinjol', 'le...
# 253  ['klw', 'tubuhmu', 'bungkus', 'kayak', 'permen...
# 254  ['semangat', 'hargai', 'ttp', 'mslhx', 'adh', ...
# 255  ['udah', 'diperintahkan', 'beliau', 'presiden'...
# 256  ['kali', 'mahasiswa', 'menolak', 'tunggangi', ...
# 257  ['ndak', 'ndak', 'dipisah', 'kelas', 'khusus',...
# 258  ['ngenyel', 'bgt', 'kadrun', 'ama', 'permendik...
# 259              ['tokoh', 'wanitanya', 'diem', 'aoa']
# 260  ['hrs', 'kl', 'kekerasan', 'sex', 'pd', 'wanit...
# 261                                          ['dajal']
# 262              ['munkin', 'makarim', 'sukak', 'sex']
# 263  ['byk', 'bacot', 'nadiem', 'salah', 'ngeyel', ...
# 264  ['tujuannya', 'bae', 'bagai mana', 'mas', 'men...
# 265  ['judulnya', 'oke', 'isinya', 'melegalkan', 'k...
# 266  ['pendapat', 'aq', 'zinah', 'sadar', 'suka', '...
#
#                                                STEMMER  \
# 247  ['tri', 'jga', 'hrs', 'musyawarah', 'ma', 'mui...
# 248  ['efek', 'tri', 'comot', 'gak', 'gak', 'org', ...
# 249  ['permendikbudristek', 'udah', 'terap', 'klu',...
# 250  ['ruu', 'jngan', 'disamain', 'kyk', 'apps', 't...
# 251  ['riil', 'bgt', 'keras', 'seksual', 'kampus', ...
# 252  ['ojk', 'ga', 'berani', 'tutup', 'pinjol', 'le...
# 253  ['klw', 'tubuh', 'bungkus', 'kayak', 'permen',...
# 254  ['semangat', 'harga', 'ttp', 'mslhx', 'adh', '...
# 255  ['udah', 'perintah', 'beliau', 'presiden', 'jo...
# 256  ['kali', 'mahasiswa', 'tolak', 'tunggang', 'ul...
# 257  ['ndak', 'ndak', 'pisah', 'kelas', 'khusus', '...
# 258  ['ngenyel', 'bgt', 'kadrun', 'ama', 'permendik...
# 259                 ['tokoh', 'wanita', 'diem', 'aoa']
# 260  ['hrs', 'kl', 'keras', 'sex', 'pd', 'wanita', ...
# 261                                          ['dajal']
# 262              ['munkin', 'makarim', 'sukak', 'sex']
# 263  ['byk', 'bacot', 'nadiem', 'salah', 'ngeyel', ...
# 264  ['tuju', 'bae', 'bagai mana', 'mas', 'tri', 'f...
# 265  ['judul', 'oke', 'isi', 'legal', 'keras', 'tlg...
# 266  ['dapat', 'aq', 'zinah', 'sadar', 'suka', 'suk...
#
#                                         Komentar_Final
# 247  tri jga hrs musyawarah ma mui nu muhamdiah dea...
# 248        efek tri comot gak gak org pandai indonesia
# 249  permendikbudristek udah terap klu paksa dn ker...
# 250  ruu jngan disamain kyk apps tuju install apps ...
# 251  riil bgt keras seksual kampus darurat knp oknu...
# 252  ojk ga berani tutup pinjol legal pdhl praktek ...
# 253  klw tubuh bungkus kayak permen lollipop gak gi...
# 254  semangat harga ttp mslhx adh norma tulis frase...
# 255  udah perintah beliau presiden jokowi tanggung ...
# 256  kali mahasiswa tolak tunggang ulama kadron ota...
# 257  ndak ndak pisah kelas khusus laki laki dn kela...
# 258  ngenyel bgt kadrun ama permendikbud tuju udah ...
# 259                              tokoh wanita diem aoa
# 260  hrs kl keras sex pd wanita apa alesanya kl buk...
# 261                                              dajal
# 262                           munkin makarim sukak sex
# 263                   byk bacot nadiem salah ngeyel lo
# 264  tuju bae bagai mana mas tri frase dalem permen...
# 265  judul oke isi legal keras tlg baca isi teliti tri
# 266  dapat aq zinah sadar suka suka tekan keras per...

# %%
import seaborn as sns
colors = ['#FF0000', '#FFFF00', '#008000']
sns.set(style="dark")
df['Label'].value_counts().plot.bar(color = colors, figsize = (7, 5))
# Out:
# <AxesSubplot:>

# %%
positive_words =' '.join([text for text in df['Komentar'][total_data[sentiment] == 1]])
wordcloud = WordCloud(width=800, height=500, random_state=21,
            max_font_size=110,background_color="rgba(255, 255, 255, 0)"
            , mode="RGBA").generate(positive_words)
plt.figure(dpi=600)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title("Most Used Positive Words")
plt.savefig('assets/positive_words.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 positive_words =' '.join([text for text in df['Komentar'][total_data[sentiment] == 1]])
#       2 wordcloud = WordCloud(width=800, height=500, random_state=21,
#       3             max_font_size=110,background_color="rgba(255, 255, 255, 0)"
#       4             , mode="RGBA").generate(positive_words)
#       5 plt.figure(dpi=600)
#
# NameError: name 'total_data' is not defined

# %%
def convert(polarity):
    if polarity == "Positif":
        return 1
    elif polarity == "Netral":
        return 0
    else:
        return -1

# %%
df['polarity'] = df['Label'].apply(convert)

# %%
x = df['Komentar_Final']
y = df['polarity']

# %%
#vectorizer = CountVectorizer()
#X = vectorizer.fit_transform(df['isi'])

bow_transformer = CountVectorizer()
print(df['Komentar_Final'].shape)
X = bow_transformer.fit_transform(df['Komentar_Final'])

print(X.toarray())
print('Shape of Sparse Matrix: ', X.shape)
print('Amount of Non-Zero Occurrences: ', X.nnz)

#TFIDF Transform
tf_transform = TfidfTransformer(use_idf=False).fit(X)
X = tf_transform.transform(X)
print(X.shape)

# %%
density = (100.0 * X.nnz / (X.shape[0] * X.shape[1]))
print('Density: {}'.format((density)))

# %%
# !pip3 install numpy --upgrade
